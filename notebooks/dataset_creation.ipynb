# %%
import numpy as np

def extract_features_from_mediapipe(hand_landmarks, handedness_label):
    """
    Превращает MediaPipe hand_landmarks и handedness_label
    в вектор признаков того же формата, что использовался для обучения:
    x0,y0,z0,...,x20,y20,z20,is_right_hand

    Args:
        hand_landmarks: один объект hand_landmarks из MediaPipe.
        handedness_label: "Right" или "Left"

    Returns:
        np.array shape (1,64) готовый для scaler/model
    """
    is_right = 1 if handedness_label == "Right" else 0

    # Wrist для нормализации
    wrist = hand_landmarks.landmark[0]
    wx, wy, wz = wrist.x, wrist.y, wrist.z

    # Масштаб — максимальная дистанция от запястья
    distances = [np.linalg.norm([lm.x - wx, lm.y - wy, lm.z - wz])
                 for lm in hand_landmarks.landmark]
    scale = max(distances) if max(distances) > 1e-6 else 1e-6

    coords = []
    for lm in hand_landmarks.landmark:
        coords.extend([
            (lm.x - wx) / scale,
            (lm.y - wy) / scale,
            (lm.z - wz) / scale
        ])

    coords.append(is_right)

    return np.array(coords, dtype=np.float32).reshape(1, -1)

# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
import os
import time
import copy

def capture_hands_to_csv(
    output_csv,
    gesture_label,
    max_samples=100,
    capture_interval=0.1,
    frame_width=640,
    frame_height=480,
):
    """
    Сбор данных жестов рук.
    - Координаты совпадают с MediaPipe (не зеркальные).
    - Левую и правую руку MediaPipe определяет корректно.
    - Пользователь видит изображение без зеркального эффекта.
    """

    mp_hands = mp.solutions.hands
    mp_drawing = mp.solutions.drawing_utils

    hands = mp_hands.Hands(
        static_image_mode=True,
        max_num_hands=1,
        min_detection_confidence=0.9,
        min_tracking_confidence=0.7
    )

    rows = []
    count = 0
    last_capture_time = 0

    cap = cv2.VideoCapture(0)
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, frame_width)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, frame_height)

    if not cap.isOpened():
        print("!!! Unable to access camera")
        return

    print(f"Camera ready. Capturing every {capture_interval}s. Press 'q' to quit.")

    while cap.isOpened() and count < max_samples:
        success, frame = cap.read()
        if not success:
            print("!!! Can't read frame")
            break

        success, frame = cap.read()
        if not success:
            break

            # Берём кадр с камеры
        success, frame = cap.read()
        if not success:
            break

        # Зеркалим горизонтально (flipCode=1)
        frame_mirrored = cv2.flip(frame, 1)

        # Передаём зеркальный кадр в MediaPipe
        image_rgb = cv2.cvtColor(frame_mirrored, cv2.COLOR_BGR2RGB)
        result = hands.process(image_rgb)


        # --- Кадр для отображения пользователю (зеркальное отображение) ---
        frame_flipped = cv2.flip(frame, 1)

        # Рисуем landmarks на зеркальном кадре для пользователя
        if result.multi_hand_landmarks:
            for hand_landmarks in result.multi_hand_landmarks:
                mp.solutions.drawing_utils.draw_landmarks(
                    frame_flipped, hand_landmarks, mp_hands.HAND_CONNECTIONS
                )

        cv2.imshow("Hand Capture", frame_flipped)


        label = "None"
        if result.multi_hand_landmarks and result.multi_handedness:
            hand_landmarks = result.multi_hand_landmarks[0]
            label = result.multi_handedness[0].classification[0].label
            is_right = 1 if label == "Right" else 0

            coords = []
            wrist_x = hand_landmarks.landmark[0].x
            wrist_y = hand_landmarks.landmark[0].y
            wrist_z = hand_landmarks.landmark[0].z

            # Масштаб руки для нормализации
            distances = [np.linalg.norm([
                lm.x - wrist_x,
                lm.y - wrist_y,
                lm.z - wrist_z
            ]) for lm in hand_landmarks.landmark]
            scale = max(distances)

            for lm in hand_landmarks.landmark:
                x, y, z = lm.x, lm.y, lm.z
                x = (x - wrist_x) / scale
                y = (y - wrist_y) / scale
                z = (z - wrist_z) / scale
                coords.extend([x, y, z])

            rows.append(coords + [gesture_label, is_right])
            count += 1
            last_capture_time = time.time()
            print(f"✅ Sample {count}/{max_samples} captured ({label} hand, gesture: {gesture_label})")

            # Рисуем руку для пользователя
            # --- Создаем зеркальные landmarks для отображения ---
            # flipped_landmarks = copy.deepcopy(hand_landmarks)
            # for lm in flipped_landmarks.landmark:
            #     lm.x = 1 - lm.x
            # mp_drawing.draw_landmarks(frame_flipped, flipped_landmarks, mp_hands.HAND_CONNECTIONS)


        # Показываем изображение с корректной ориентацией
        text = f"{label} hand | Gesture: {gesture_label}"
        cv2.putText(frame_flipped, text, (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        cv2.imshow("Hand Capture", frame_flipped)

        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break

        # Ждём до следующего снимка
        while time.time() - last_capture_time < capture_interval:
            time.sleep(0.01)

    cap.release()
    cv2.destroyAllWindows()
    hands.close()

    if not rows:
        print("No samples recorded.")
        return

    # Сохраняем CSV
    columns = [f"{axis}{i}" for i in range(21) for axis in ("x", "y", "z")] + ["gesture", "is_right_hand"]
    df = pd.DataFrame(rows, columns=columns)
    os.makedirs(os.path.dirname(output_csv), exist_ok=True)

    if os.path.exists(output_csv):
        df_existing = pd.read_csv(output_csv)
        df = pd.concat([df_existing, df], ignore_index=True)

    df.to_csv(output_csv, index=False)
    print(f"\nCSV saved: {output_csv} ({len(df)} total rows)")

# %%
gesture_label="question" 
output_csv = '../data/raw/upd_question.csv'

capture_hands_to_csv(
        output_csv=output_csv,
        gesture_label=gesture_label,
        max_samples=500,
        capture_interval=0.2
    )
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763296535.449151   95639 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763296535.459221   95713 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-34-generic)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1763296535.514218   95689 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1763296535.540836   95688 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera ready. Capturing every 0.2s. Press 'q' to quit.
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/fateee/Desktop/ulyana/Hand-Gesture-Recognition/.venv/lib/python3.12/site-packages/cv2/qt/plugins"
# W0000 00:00:1763296536.067726   95688 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# ✅ Sample 1/500 captured (Right hand, gesture: question)
# ✅ Sample 2/500 captured (Right hand, gesture: question)
# ✅ Sample 3/500 captured (Right hand, gesture: question)
# ✅ Sample 4/500 captured (Right hand, gesture: question)
# ✅ Sample 5/500 captured (Right hand, gesture: question)
# ✅ Sample 6/500 captured (Right hand, gesture: question)
# ✅ Sample 7/500 captured (Right hand, gesture: question)
# ✅ Sample 8/500 captured (Right hand, gesture: question)
# ✅ Sample 9/500 captured (Right hand, gesture: question)
# ✅ Sample 10/500 captured (Right hand, gesture: question)
# ✅ Sample 11/500 captured (Right hand, gesture: question)
# ✅ Sample 12/500 captured (Right hand, gesture: question)
# ✅ Sample 13/500 captured (Right hand, gesture: question)
# ✅ Sample 14/500 captured (Right hand, gesture: question)
# ✅ Sample 15/500 captured (Right hand, gesture: question)
# ✅ Sample 16/500 captured (Right hand, gesture: question)
# ✅ Sample 17/500 captured (Right hand, gesture: question)
# ✅ Sample 18/500 captured (Right hand, gesture: question)
# ✅ Sample 19/500 captured (Right hand, gesture: question)
# ✅ Sample 20/500 captured (Right hand, gesture: question)
# ✅ Sample 21/500 captured (Right hand, gesture: question)
# ✅ Sample 22/500 captured (Right hand, gesture: question)
# ✅ Sample 23/500 captured (Right hand, gesture: question)
# ✅ Sample 24/500 captured (Right hand, gesture: question)
# ✅ Sample 25/500 captured (Right hand, gesture: question)
# ✅ Sample 26/500 captured (Right hand, gesture: question)
# ✅ Sample 27/500 captured (Right hand, gesture: question)
# ✅ Sample 28/500 captured (Right hand, gesture: question)
# ✅ Sample 29/500 captured (Right hand, gesture: question)
# ✅ Sample 30/500 captured (Right hand, gesture: question)
# ✅ Sample 31/500 captured (Right hand, gesture: question)
# ✅ Sample 32/500 captured (Right hand, gesture: question)
# ✅ Sample 33/500 captured (Right hand, gesture: question)
# ✅ Sample 34/500 captured (Right hand, gesture: question)
# ✅ Sample 35/500 captured (Right hand, gesture: question)
# ✅ Sample 36/500 captured (Right hand, gesture: question)
# ✅ Sample 37/500 captured (Right hand, gesture: question)
# ✅ Sample 38/500 captured (Right hand, gesture: question)
# ✅ Sample 39/500 captured (Right hand, gesture: question)
# ✅ Sample 40/500 captured (Right hand, gesture: question)
# ✅ Sample 41/500 captured (Right hand, gesture: question)
# ✅ Sample 42/500 captured (Right hand, gesture: question)
# ✅ Sample 43/500 captured (Right hand, gesture: question)
# ✅ Sample 44/500 captured (Right hand, gesture: question)
# ✅ Sample 45/500 captured (Right hand, gesture: question)
# ✅ Sample 46/500 captured (Right hand, gesture: question)
# ✅ Sample 47/500 captured (Right hand, gesture: question)
# ✅ Sample 48/500 captured (Right hand, gesture: question)
# ✅ Sample 49/500 captured (Right hand, gesture: question)
# ✅ Sample 50/500 captured (Right hand, gesture: question)
# ✅ Sample 51/500 captured (Right hand, gesture: question)
# ✅ Sample 52/500 captured (Right hand, gesture: question)
# ✅ Sample 53/500 captured (Right hand, gesture: question)
# ✅ Sample 54/500 captured (Right hand, gesture: question)
# ✅ Sample 55/500 captured (Right hand, gesture: question)
# ✅ Sample 56/500 captured (Right hand, gesture: question)
# ✅ Sample 57/500 captured (Right hand, gesture: question)
# ✅ Sample 58/500 captured (Right hand, gesture: question)
# ✅ Sample 59/500 captured (Right hand, gesture: question)
# ✅ Sample 60/500 captured (Right hand, gesture: question)
# ✅ Sample 61/500 captured (Right hand, gesture: question)
# ✅ Sample 62/500 captured (Right hand, gesture: question)
# ✅ Sample 63/500 captured (Right hand, gesture: question)
# ✅ Sample 64/500 captured (Right hand, gesture: question)
# ✅ Sample 65/500 captured (Right hand, gesture: question)
# ✅ Sample 66/500 captured (Right hand, gesture: question)
# ✅ Sample 67/500 captured (Right hand, gesture: question)
# ✅ Sample 68/500 captured (Right hand, gesture: question)
# ✅ Sample 69/500 captured (Right hand, gesture: question)
# ✅ Sample 70/500 captured (Right hand, gesture: question)
# ✅ Sample 71/500 captured (Right hand, gesture: question)
# ✅ Sample 72/500 captured (Right hand, gesture: question)
# ✅ Sample 73/500 captured (Right hand, gesture: question)
# ✅ Sample 74/500 captured (Right hand, gesture: question)
# ✅ Sample 75/500 captured (Right hand, gesture: question)
# ✅ Sample 76/500 captured (Right hand, gesture: question)
# ✅ Sample 77/500 captured (Right hand, gesture: question)
# ✅ Sample 78/500 captured (Right hand, gesture: question)
# ✅ Sample 79/500 captured (Right hand, gesture: question)
# ✅ Sample 80/500 captured (Right hand, gesture: question)
# ✅ Sample 81/500 captured (Right hand, gesture: question)
# ✅ Sample 82/500 captured (Right hand, gesture: question)
# ✅ Sample 83/500 captured (Right hand, gesture: question)
# ✅ Sample 84/500 captured (Right hand, gesture: question)
# ✅ Sample 85/500 captured (Right hand, gesture: question)
# ✅ Sample 86/500 captured (Right hand, gesture: question)
# ✅ Sample 87/500 captured (Right hand, gesture: question)
# ✅ Sample 88/500 captured (Right hand, gesture: question)
# ✅ Sample 89/500 captured (Right hand, gesture: question)
# ✅ Sample 90/500 captured (Right hand, gesture: question)
# ✅ Sample 91/500 captured (Right hand, gesture: question)
# ✅ Sample 92/500 captured (Right hand, gesture: question)
# ✅ Sample 93/500 captured (Right hand, gesture: question)
# ✅ Sample 94/500 captured (Right hand, gesture: question)
# ✅ Sample 95/500 captured (Right hand, gesture: question)
# ✅ Sample 96/500 captured (Right hand, gesture: question)
# ✅ Sample 97/500 captured (Right hand, gesture: question)
# ✅ Sample 98/500 captured (Right hand, gesture: question)
# ✅ Sample 99/500 captured (Right hand, gesture: question)
# ✅ Sample 100/500 captured (Right hand, gesture: question)
# ✅ Sample 101/500 captured (Right hand, gesture: question)
# ✅ Sample 102/500 captured (Right hand, gesture: question)
# ✅ Sample 103/500 captured (Right hand, gesture: question)
# ✅ Sample 104/500 captured (Right hand, gesture: question)
# ✅ Sample 105/500 captured (Right hand, gesture: question)
# ✅ Sample 106/500 captured (Right hand, gesture: question)
# ✅ Sample 107/500 captured (Right hand, gesture: question)
# ✅ Sample 108/500 captured (Right hand, gesture: question)
# ✅ Sample 109/500 captured (Right hand, gesture: question)
# ✅ Sample 110/500 captured (Right hand, gesture: question)
# ✅ Sample 111/500 captured (Right hand, gesture: question)
# ✅ Sample 112/500 captured (Right hand, gesture: question)
# ✅ Sample 113/500 captured (Right hand, gesture: question)
# ✅ Sample 114/500 captured (Right hand, gesture: question)
# ✅ Sample 115/500 captured (Right hand, gesture: question)
# ✅ Sample 116/500 captured (Right hand, gesture: question)
# ✅ Sample 117/500 captured (Right hand, gesture: question)
# ✅ Sample 118/500 captured (Right hand, gesture: question)
# ✅ Sample 119/500 captured (Right hand, gesture: question)
# ✅ Sample 120/500 captured (Right hand, gesture: question)
# ✅ Sample 121/500 captured (Right hand, gesture: question)
# ✅ Sample 122/500 captured (Right hand, gesture: question)
# ✅ Sample 123/500 captured (Right hand, gesture: question)
# ✅ Sample 124/500 captured (Right hand, gesture: question)
# ✅ Sample 125/500 captured (Right hand, gesture: question)
# ✅ Sample 126/500 captured (Right hand, gesture: question)
# ✅ Sample 127/500 captured (Right hand, gesture: question)
# ✅ Sample 128/500 captured (Right hand, gesture: question)
# ✅ Sample 129/500 captured (Right hand, gesture: question)
# ✅ Sample 130/500 captured (Right hand, gesture: question)
# ✅ Sample 131/500 captured (Right hand, gesture: question)
# ✅ Sample 132/500 captured (Right hand, gesture: question)
# ✅ Sample 133/500 captured (Right hand, gesture: question)
# ✅ Sample 134/500 captured (Right hand, gesture: question)
# ✅ Sample 135/500 captured (Right hand, gesture: question)
# ✅ Sample 136/500 captured (Right hand, gesture: question)
# ✅ Sample 137/500 captured (Right hand, gesture: question)
# ✅ Sample 138/500 captured (Right hand, gesture: question)
# ✅ Sample 139/500 captured (Right hand, gesture: question)
# ✅ Sample 140/500 captured (Right hand, gesture: question)
# ✅ Sample 141/500 captured (Right hand, gesture: question)
# ✅ Sample 142/500 captured (Right hand, gesture: question)
# ✅ Sample 143/500 captured (Right hand, gesture: question)
# ✅ Sample 144/500 captured (Right hand, gesture: question)
# ✅ Sample 145/500 captured (Right hand, gesture: question)
# ✅ Sample 146/500 captured (Right hand, gesture: question)
# ✅ Sample 147/500 captured (Right hand, gesture: question)
# ✅ Sample 148/500 captured (Right hand, gesture: question)
# ✅ Sample 149/500 captured (Right hand, gesture: question)
# ✅ Sample 150/500 captured (Right hand, gesture: question)
# ✅ Sample 151/500 captured (Right hand, gesture: question)
# ✅ Sample 152/500 captured (Right hand, gesture: question)
# ✅ Sample 153/500 captured (Right hand, gesture: question)
# ✅ Sample 154/500 captured (Right hand, gesture: question)
# ✅ Sample 155/500 captured (Right hand, gesture: question)
# ✅ Sample 156/500 captured (Right hand, gesture: question)
# ✅ Sample 157/500 captured (Right hand, gesture: question)
# ✅ Sample 158/500 captured (Right hand, gesture: question)
# ✅ Sample 159/500 captured (Right hand, gesture: question)
# ✅ Sample 160/500 captured (Right hand, gesture: question)
# ✅ Sample 161/500 captured (Right hand, gesture: question)
# ✅ Sample 162/500 captured (Right hand, gesture: question)
# ✅ Sample 163/500 captured (Right hand, gesture: question)
# ✅ Sample 164/500 captured (Right hand, gesture: question)
# ✅ Sample 165/500 captured (Right hand, gesture: question)
# ✅ Sample 166/500 captured (Right hand, gesture: question)
# ✅ Sample 167/500 captured (Right hand, gesture: question)
# ✅ Sample 168/500 captured (Right hand, gesture: question)
# ✅ Sample 169/500 captured (Right hand, gesture: question)
# ✅ Sample 170/500 captured (Right hand, gesture: question)
# ✅ Sample 171/500 captured (Right hand, gesture: question)
# ✅ Sample 172/500 captured (Right hand, gesture: question)
# ✅ Sample 173/500 captured (Right hand, gesture: question)
# ✅ Sample 174/500 captured (Right hand, gesture: question)
# ✅ Sample 175/500 captured (Right hand, gesture: question)
# ✅ Sample 176/500 captured (Right hand, gesture: question)
# ✅ Sample 177/500 captured (Right hand, gesture: question)
# ✅ Sample 178/500 captured (Right hand, gesture: question)
# ✅ Sample 179/500 captured (Right hand, gesture: question)
# ✅ Sample 180/500 captured (Right hand, gesture: question)
# ✅ Sample 181/500 captured (Right hand, gesture: question)
# ✅ Sample 182/500 captured (Right hand, gesture: question)
# ✅ Sample 183/500 captured (Right hand, gesture: question)
# ✅ Sample 184/500 captured (Right hand, gesture: question)
# ✅ Sample 185/500 captured (Right hand, gesture: question)
# ✅ Sample 186/500 captured (Right hand, gesture: question)
# ✅ Sample 187/500 captured (Right hand, gesture: question)
# ✅ Sample 188/500 captured (Right hand, gesture: question)
# ✅ Sample 189/500 captured (Right hand, gesture: question)
# ✅ Sample 190/500 captured (Right hand, gesture: question)
# ✅ Sample 191/500 captured (Right hand, gesture: question)
# ✅ Sample 192/500 captured (Right hand, gesture: question)
# ✅ Sample 193/500 captured (Right hand, gesture: question)
# ✅ Sample 194/500 captured (Right hand, gesture: question)
# ✅ Sample 195/500 captured (Right hand, gesture: question)
# ✅ Sample 196/500 captured (Right hand, gesture: question)
# ✅ Sample 197/500 captured (Right hand, gesture: question)
# ✅ Sample 198/500 captured (Right hand, gesture: question)
# ✅ Sample 199/500 captured (Right hand, gesture: question)
# ✅ Sample 200/500 captured (Right hand, gesture: question)
# ✅ Sample 201/500 captured (Right hand, gesture: question)
# ✅ Sample 202/500 captured (Right hand, gesture: question)
# ✅ Sample 203/500 captured (Right hand, gesture: question)
# ✅ Sample 204/500 captured (Right hand, gesture: question)
# ✅ Sample 205/500 captured (Right hand, gesture: question)
# ✅ Sample 206/500 captured (Right hand, gesture: question)
# ✅ Sample 207/500 captured (Right hand, gesture: question)
# ✅ Sample 208/500 captured (Right hand, gesture: question)
# ✅ Sample 209/500 captured (Right hand, gesture: question)
# ✅ Sample 210/500 captured (Right hand, gesture: question)
# ✅ Sample 211/500 captured (Right hand, gesture: question)
# ✅ Sample 212/500 captured (Right hand, gesture: question)
# ✅ Sample 213/500 captured (Right hand, gesture: question)
# ✅ Sample 214/500 captured (Right hand, gesture: question)
# ✅ Sample 215/500 captured (Right hand, gesture: question)
# ✅ Sample 216/500 captured (Right hand, gesture: question)
# ✅ Sample 217/500 captured (Right hand, gesture: question)
# ✅ Sample 218/500 captured (Right hand, gesture: question)
# ✅ Sample 219/500 captured (Right hand, gesture: question)
# ✅ Sample 220/500 captured (Right hand, gesture: question)
# ✅ Sample 221/500 captured (Right hand, gesture: question)
# ✅ Sample 222/500 captured (Right hand, gesture: question)
# ✅ Sample 223/500 captured (Right hand, gesture: question)
# ✅ Sample 224/500 captured (Right hand, gesture: question)
# ✅ Sample 225/500 captured (Right hand, gesture: question)
# ✅ Sample 226/500 captured (Right hand, gesture: question)
# ✅ Sample 227/500 captured (Right hand, gesture: question)
# ✅ Sample 228/500 captured (Right hand, gesture: question)
# ✅ Sample 229/500 captured (Right hand, gesture: question)
# ✅ Sample 230/500 captured (Right hand, gesture: question)
# ✅ Sample 231/500 captured (Right hand, gesture: question)
# ✅ Sample 232/500 captured (Right hand, gesture: question)
# ✅ Sample 233/500 captured (Right hand, gesture: question)
# ✅ Sample 234/500 captured (Right hand, gesture: question)
# ✅ Sample 235/500 captured (Right hand, gesture: question)
# ✅ Sample 236/500 captured (Right hand, gesture: question)
# ✅ Sample 237/500 captured (Right hand, gesture: question)
# ✅ Sample 238/500 captured (Right hand, gesture: question)
# ✅ Sample 239/500 captured (Right hand, gesture: question)
# ✅ Sample 240/500 captured (Right hand, gesture: question)
# ✅ Sample 241/500 captured (Right hand, gesture: question)
# ✅ Sample 242/500 captured (Right hand, gesture: question)
# ✅ Sample 243/500 captured (Right hand, gesture: question)
# ✅ Sample 244/500 captured (Right hand, gesture: question)
# ✅ Sample 245/500 captured (Right hand, gesture: question)
# ✅ Sample 246/500 captured (Right hand, gesture: question)
# ✅ Sample 247/500 captured (Right hand, gesture: question)
# ✅ Sample 248/500 captured (Right hand, gesture: question)
# ✅ Sample 249/500 captured (Right hand, gesture: question)
# ✅ Sample 250/500 captured (Right hand, gesture: question)
# ✅ Sample 251/500 captured (Right hand, gesture: question)
# ✅ Sample 252/500 captured (Right hand, gesture: question)
# ✅ Sample 253/500 captured (Right hand, gesture: question)
# ✅ Sample 254/500 captured (Right hand, gesture: question)
# ✅ Sample 255/500 captured (Right hand, gesture: question)
# ✅ Sample 256/500 captured (Right hand, gesture: question)
# ✅ Sample 257/500 captured (Right hand, gesture: question)
# ✅ Sample 258/500 captured (Right hand, gesture: question)
# ✅ Sample 259/500 captured (Right hand, gesture: question)
# ✅ Sample 260/500 captured (Right hand, gesture: question)
# ✅ Sample 261/500 captured (Right hand, gesture: question)
# ✅ Sample 262/500 captured (Right hand, gesture: question)
# ✅ Sample 263/500 captured (Right hand, gesture: question)
# ✅ Sample 264/500 captured (Right hand, gesture: question)
# ✅ Sample 265/500 captured (Right hand, gesture: question)
# ✅ Sample 266/500 captured (Right hand, gesture: question)
# ✅ Sample 267/500 captured (Right hand, gesture: question)
# ✅ Sample 268/500 captured (Right hand, gesture: question)
# ✅ Sample 269/500 captured (Right hand, gesture: question)
# ✅ Sample 270/500 captured (Right hand, gesture: question)
# ✅ Sample 271/500 captured (Right hand, gesture: question)
# ✅ Sample 272/500 captured (Right hand, gesture: question)
# ✅ Sample 273/500 captured (Right hand, gesture: question)
# ✅ Sample 274/500 captured (Right hand, gesture: question)
# ✅ Sample 275/500 captured (Right hand, gesture: question)
# ✅ Sample 276/500 captured (Right hand, gesture: question)
# ✅ Sample 277/500 captured (Right hand, gesture: question)
# ✅ Sample 278/500 captured (Right hand, gesture: question)
# ✅ Sample 279/500 captured (Right hand, gesture: question)
# ✅ Sample 280/500 captured (Right hand, gesture: question)
# ✅ Sample 281/500 captured (Right hand, gesture: question)
# ✅ Sample 282/500 captured (Right hand, gesture: question)
# ✅ Sample 283/500 captured (Right hand, gesture: question)
# ✅ Sample 284/500 captured (Right hand, gesture: question)
# ✅ Sample 285/500 captured (Right hand, gesture: question)
# ✅ Sample 286/500 captured (Right hand, gesture: question)
# ✅ Sample 287/500 captured (Right hand, gesture: question)
# ✅ Sample 288/500 captured (Right hand, gesture: question)
# ✅ Sample 289/500 captured (Right hand, gesture: question)
# ✅ Sample 290/500 captured (Right hand, gesture: question)
# ✅ Sample 291/500 captured (Right hand, gesture: question)
# ✅ Sample 292/500 captured (Right hand, gesture: question)
# ✅ Sample 293/500 captured (Right hand, gesture: question)
# ✅ Sample 294/500 captured (Right hand, gesture: question)
# ✅ Sample 295/500 captured (Right hand, gesture: question)
# ✅ Sample 296/500 captured (Right hand, gesture: question)
# ✅ Sample 297/500 captured (Right hand, gesture: question)
# ✅ Sample 298/500 captured (Right hand, gesture: question)
# ✅ Sample 299/500 captured (Right hand, gesture: question)
# ✅ Sample 300/500 captured (Right hand, gesture: question)
# ✅ Sample 301/500 captured (Right hand, gesture: question)
# ✅ Sample 302/500 captured (Right hand, gesture: question)
# ✅ Sample 303/500 captured (Right hand, gesture: question)
# ✅ Sample 304/500 captured (Right hand, gesture: question)
# ✅ Sample 305/500 captured (Right hand, gesture: question)
# ✅ Sample 306/500 captured (Right hand, gesture: question)
# ✅ Sample 307/500 captured (Right hand, gesture: question)
# ✅ Sample 308/500 captured (Right hand, gesture: question)
# ✅ Sample 309/500 captured (Left hand, gesture: question)
# ✅ Sample 310/500 captured (Left hand, gesture: question)
# ✅ Sample 311/500 captured (Left hand, gesture: question)
# ✅ Sample 312/500 captured (Left hand, gesture: question)
# ✅ Sample 313/500 captured (Left hand, gesture: question)
# ✅ Sample 314/500 captured (Left hand, gesture: question)
# ✅ Sample 315/500 captured (Left hand, gesture: question)
# ✅ Sample 316/500 captured (Left hand, gesture: question)
# ✅ Sample 317/500 captured (Left hand, gesture: question)
# ✅ Sample 318/500 captured (Left hand, gesture: question)
# ✅ Sample 319/500 captured (Left hand, gesture: question)
# ✅ Sample 320/500 captured (Left hand, gesture: question)
# ✅ Sample 321/500 captured (Left hand, gesture: question)
# ✅ Sample 322/500 captured (Left hand, gesture: question)
# ✅ Sample 323/500 captured (Left hand, gesture: question)
# ✅ Sample 324/500 captured (Left hand, gesture: question)
# ✅ Sample 325/500 captured (Left hand, gesture: question)
# ✅ Sample 326/500 captured (Left hand, gesture: question)
# ✅ Sample 327/500 captured (Left hand, gesture: question)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 gesture_label="question"
#       2 output_csv = '../data/raw/upd_question.csv'
# ----> 4 capture_hands_to_csv(
#       5         output_csv=output_csv,
#       6         gesture_label=gesture_label,
#       7         max_samples=500,
#       8         capture_interval=0.2
#       9     )
#
# Cell In[3], line 59, in capture_hands_to_csv(output_csv, gesture_label, max_samples, capture_interval, frame_width, frame_height)
#      56     break
#      58     # Берём кадр с камеры
# ---> 59 success, frame = cap.read()
#      60 if not success:
#      61     break
#
# KeyboardInterrupt:

# %%
gesture_label="if" 
output_csv = '../data/raw/upd_if.csv'

capture_hands_to_csv(
        output_csv=output_csv,
        gesture_label=gesture_label,
        max_samples=500,
        capture_interval=0.2
    )
# Out:
# I0000 00:00:1763296159.446309   64322 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763296159.449842   95284 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-34-generic)
# W0000 00:00:1763296159.474132   95266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1763296159.485162   95278 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera ready. Capturing every 0.2s. Press 'q' to quit.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 4
#       1 gesture_label="if"
#       2 output_csv = '../data/raw/upd_if.csv'
# ----> 4 capture_hands_to_csv(
#       5         output_csv=output_csv,
#       6         gesture_label=gesture_label,
#       7         max_samples=500,
#       8         capture_interval=0.2
#       9     )
#
# Cell In[48], line 89, in capture_hands_to_csv(output_csv, gesture_label, max_samples, capture_interval, frame_width, frame_height)
#      86 hand_landmarks = result.multi_hand_landmarks[0]
#      87 label = result.multi_handedness[0].classification[0].label
# ---> 89 features = extract_features_from_mediapipe(lm, label)
#      91 is_right = 1 if label == "Right" else 0
#      93 # if is_right == 0:  # левая рука
#      94 #     for lm in hand_landmarks.landmark:
#      95 #         lm.x = 1 - lm.x
#
# NameError: name 'lm' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
gesture_label="civilian" 
output_csv = '../data/raw/upd_civilian.csv'

capture_hands_to_csv(
        output_csv=output_csv,
        gesture_label=gesture_label,
        max_samples=500,
        capture_interval=0.2
    )
# Out:
# I0000 00:00:1763285486.554687   64322 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763285486.558430   84668 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-34-generic)
# W0000 00:00:1763285486.580510   84653 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1763285486.596319   84662 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera ready. Capturing every 0.2s. Press 'q' to quit.
# ✅ Sample 1/500 captured (Left hand, gesture: civilian)
# ✅ Sample 2/500 captured (Left hand, gesture: civilian)
# ✅ Sample 3/500 captured (Left hand, gesture: civilian)
# ✅ Sample 4/500 captured (Left hand, gesture: civilian)
# ✅ Sample 5/500 captured (Left hand, gesture: civilian)
# ✅ Sample 6/500 captured (Left hand, gesture: civilian)
# ✅ Sample 7/500 captured (Left hand, gesture: civilian)
# ✅ Sample 8/500 captured (Left hand, gesture: civilian)
# ✅ Sample 9/500 captured (Left hand, gesture: civilian)
# ✅ Sample 10/500 captured (Left hand, gesture: civilian)
# ✅ Sample 11/500 captured (Left hand, gesture: civilian)
# ✅ Sample 12/500 captured (Left hand, gesture: civilian)
# ✅ Sample 13/500 captured (Left hand, gesture: civilian)
# ✅ Sample 14/500 captured (Left hand, gesture: civilian)
# ✅ Sample 15/500 captured (Left hand, gesture: civilian)
# ✅ Sample 16/500 captured (Left hand, gesture: civilian)
# ✅ Sample 17/500 captured (Left hand, gesture: civilian)
# ✅ Sample 18/500 captured (Left hand, gesture: civilian)
# ✅ Sample 19/500 captured (Left hand, gesture: civilian)
# ✅ Sample 20/500 captured (Left hand, gesture: civilian)
# ✅ Sample 21/500 captured (Left hand, gesture: civilian)
# ✅ Sample 22/500 captured (Left hand, gesture: civilian)
# ✅ Sample 23/500 captured (Left hand, gesture: civilian)
# ✅ Sample 24/500 captured (Left hand, gesture: civilian)
# ✅ Sample 25/500 captured (Left hand, gesture: civilian)
# ✅ Sample 26/500 captured (Left hand, gesture: civilian)
# ✅ Sample 27/500 captured (Left hand, gesture: civilian)
# ✅ Sample 28/500 captured (Left hand, gesture: civilian)
# ✅ Sample 29/500 captured (Left hand, gesture: civilian)
# ✅ Sample 30/500 captured (Left hand, gesture: civilian)
# ✅ Sample 31/500 captured (Left hand, gesture: civilian)
# ✅ Sample 32/500 captured (Left hand, gesture: civilian)
# ✅ Sample 33/500 captured (Left hand, gesture: civilian)
# ✅ Sample 34/500 captured (Left hand, gesture: civilian)
# ✅ Sample 35/500 captured (Left hand, gesture: civilian)
# ✅ Sample 36/500 captured (Left hand, gesture: civilian)
# ✅ Sample 37/500 captured (Left hand, gesture: civilian)
# ✅ Sample 38/500 captured (Left hand, gesture: civilian)
# ✅ Sample 39/500 captured (Left hand, gesture: civilian)
# ✅ Sample 40/500 captured (Left hand, gesture: civilian)
# ✅ Sample 41/500 captured (Left hand, gesture: civilian)
# ✅ Sample 42/500 captured (Left hand, gesture: civilian)
# ✅ Sample 43/500 captured (Left hand, gesture: civilian)
# ✅ Sample 44/500 captured (Left hand, gesture: civilian)
# ✅ Sample 45/500 captured (Left hand, gesture: civilian)
# ✅ Sample 46/500 captured (Left hand, gesture: civilian)
# ✅ Sample 47/500 captured (Left hand, gesture: civilian)
# ✅ Sample 48/500 captured (Left hand, gesture: civilian)
# ✅ Sample 49/500 captured (Left hand, gesture: civilian)
# ✅ Sample 50/500 captured (Left hand, gesture: civilian)
# ✅ Sample 51/500 captured (Left hand, gesture: civilian)
# ✅ Sample 52/500 captured (Left hand, gesture: civilian)
# ✅ Sample 53/500 captured (Left hand, gesture: civilian)
# ✅ Sample 54/500 captured (Left hand, gesture: civilian)
# ✅ Sample 55/500 captured (Left hand, gesture: civilian)
# ✅ Sample 56/500 captured (Left hand, gesture: civilian)
# ✅ Sample 57/500 captured (Left hand, gesture: civilian)
# ✅ Sample 58/500 captured (Left hand, gesture: civilian)
# ✅ Sample 59/500 captured (Left hand, gesture: civilian)
# ✅ Sample 60/500 captured (Left hand, gesture: civilian)
# ✅ Sample 61/500 captured (Left hand, gesture: civilian)
# ✅ Sample 62/500 captured (Left hand, gesture: civilian)
# ✅ Sample 63/500 captured (Left hand, gesture: civilian)
# ✅ Sample 64/500 captured (Left hand, gesture: civilian)
# ✅ Sample 65/500 captured (Left hand, gesture: civilian)
# ✅ Sample 66/500 captured (Left hand, gesture: civilian)
# ✅ Sample 67/500 captured (Left hand, gesture: civilian)
# ✅ Sample 68/500 captured (Left hand, gesture: civilian)
# ✅ Sample 69/500 captured (Left hand, gesture: civilian)
# ✅ Sample 70/500 captured (Left hand, gesture: civilian)
# ✅ Sample 71/500 captured (Left hand, gesture: civilian)
# ✅ Sample 72/500 captured (Left hand, gesture: civilian)
# ✅ Sample 73/500 captured (Left hand, gesture: civilian)
# ✅ Sample 74/500 captured (Left hand, gesture: civilian)
# ✅ Sample 75/500 captured (Left hand, gesture: civilian)
# ✅ Sample 76/500 captured (Left hand, gesture: civilian)
# ✅ Sample 77/500 captured (Left hand, gesture: civilian)
# ✅ Sample 78/500 captured (Left hand, gesture: civilian)
# ✅ Sample 79/500 captured (Left hand, gesture: civilian)
# ✅ Sample 80/500 captured (Left hand, gesture: civilian)
# ✅ Sample 81/500 captured (Left hand, gesture: civilian)
# ✅ Sample 82/500 captured (Left hand, gesture: civilian)
# ✅ Sample 83/500 captured (Left hand, gesture: civilian)
# ✅ Sample 84/500 captured (Left hand, gesture: civilian)
# ✅ Sample 85/500 captured (Left hand, gesture: civilian)
# ✅ Sample 86/500 captured (Left hand, gesture: civilian)
# ✅ Sample 87/500 captured (Left hand, gesture: civilian)
# ✅ Sample 88/500 captured (Left hand, gesture: civilian)
# ✅ Sample 89/500 captured (Left hand, gesture: civilian)
# ✅ Sample 90/500 captured (Left hand, gesture: civilian)
# ✅ Sample 91/500 captured (Left hand, gesture: civilian)
# ✅ Sample 92/500 captured (Left hand, gesture: civilian)
# ✅ Sample 93/500 captured (Left hand, gesture: civilian)
# ✅ Sample 94/500 captured (Left hand, gesture: civilian)
# ✅ Sample 95/500 captured (Left hand, gesture: civilian)
# ✅ Sample 96/500 captured (Left hand, gesture: civilian)
# ✅ Sample 97/500 captured (Left hand, gesture: civilian)
# ✅ Sample 98/500 captured (Left hand, gesture: civilian)
# ✅ Sample 99/500 captured (Left hand, gesture: civilian)
# ✅ Sample 100/500 captured (Left hand, gesture: civilian)
# ✅ Sample 101/500 captured (Left hand, gesture: civilian)
# ✅ Sample 102/500 captured (Left hand, gesture: civilian)
# ✅ Sample 103/500 captured (Left hand, gesture: civilian)
# ✅ Sample 104/500 captured (Left hand, gesture: civilian)
# ✅ Sample 105/500 captured (Left hand, gesture: civilian)
# ✅ Sample 106/500 captured (Left hand, gesture: civilian)
# ✅ Sample 107/500 captured (Left hand, gesture: civilian)
# ✅ Sample 108/500 captured (Left hand, gesture: civilian)
# ✅ Sample 109/500 captured (Left hand, gesture: civilian)
# ✅ Sample 110/500 captured (Left hand, gesture: civilian)
# ✅ Sample 111/500 captured (Left hand, gesture: civilian)
# ✅ Sample 112/500 captured (Left hand, gesture: civilian)
# ✅ Sample 113/500 captured (Left hand, gesture: civilian)
# ✅ Sample 114/500 captured (Left hand, gesture: civilian)
# ✅ Sample 115/500 captured (Left hand, gesture: civilian)
# ✅ Sample 116/500 captured (Left hand, gesture: civilian)
# ✅ Sample 117/500 captured (Left hand, gesture: civilian)
# ✅ Sample 118/500 captured (Left hand, gesture: civilian)
# ✅ Sample 119/500 captured (Left hand, gesture: civilian)
# ✅ Sample 120/500 captured (Left hand, gesture: civilian)
# ✅ Sample 121/500 captured (Left hand, gesture: civilian)
# ✅ Sample 122/500 captured (Left hand, gesture: civilian)
# ✅ Sample 123/500 captured (Left hand, gesture: civilian)
# ✅ Sample 124/500 captured (Left hand, gesture: civilian)
# ✅ Sample 125/500 captured (Left hand, gesture: civilian)
# ✅ Sample 126/500 captured (Left hand, gesture: civilian)
# ✅ Sample 127/500 captured (Left hand, gesture: civilian)
# ✅ Sample 128/500 captured (Left hand, gesture: civilian)
# ✅ Sample 129/500 captured (Left hand, gesture: civilian)
# ✅ Sample 130/500 captured (Left hand, gesture: civilian)
# ✅ Sample 131/500 captured (Left hand, gesture: civilian)
# ✅ Sample 132/500 captured (Left hand, gesture: civilian)
# ✅ Sample 133/500 captured (Left hand, gesture: civilian)
# ✅ Sample 134/500 captured (Left hand, gesture: civilian)
# ✅ Sample 135/500 captured (Left hand, gesture: civilian)
# ✅ Sample 136/500 captured (Left hand, gesture: civilian)
# ✅ Sample 137/500 captured (Left hand, gesture: civilian)
# ✅ Sample 138/500 captured (Left hand, gesture: civilian)
# ✅ Sample 139/500 captured (Left hand, gesture: civilian)
# ✅ Sample 140/500 captured (Left hand, gesture: civilian)
# ✅ Sample 141/500 captured (Left hand, gesture: civilian)
# ✅ Sample 142/500 captured (Left hand, gesture: civilian)
# ✅ Sample 143/500 captured (Left hand, gesture: civilian)
# ✅ Sample 144/500 captured (Left hand, gesture: civilian)
# ✅ Sample 145/500 captured (Left hand, gesture: civilian)
# ✅ Sample 146/500 captured (Left hand, gesture: civilian)
# ✅ Sample 147/500 captured (Left hand, gesture: civilian)
# ✅ Sample 148/500 captured (Left hand, gesture: civilian)
# ✅ Sample 149/500 captured (Left hand, gesture: civilian)
# ✅ Sample 150/500 captured (Left hand, gesture: civilian)
# ✅ Sample 151/500 captured (Left hand, gesture: civilian)
# ✅ Sample 152/500 captured (Left hand, gesture: civilian)
# ✅ Sample 153/500 captured (Left hand, gesture: civilian)
# ✅ Sample 154/500 captured (Left hand, gesture: civilian)
# ✅ Sample 155/500 captured (Left hand, gesture: civilian)
# ✅ Sample 156/500 captured (Left hand, gesture: civilian)
# ✅ Sample 157/500 captured (Left hand, gesture: civilian)
# ✅ Sample 158/500 captured (Left hand, gesture: civilian)
# ✅ Sample 159/500 captured (Left hand, gesture: civilian)
# ✅ Sample 160/500 captured (Left hand, gesture: civilian)
# ✅ Sample 161/500 captured (Left hand, gesture: civilian)
# ✅ Sample 162/500 captured (Left hand, gesture: civilian)
# ✅ Sample 163/500 captured (Left hand, gesture: civilian)
# ✅ Sample 164/500 captured (Left hand, gesture: civilian)
# ✅ Sample 165/500 captured (Left hand, gesture: civilian)
# ✅ Sample 166/500 captured (Left hand, gesture: civilian)
# ✅ Sample 167/500 captured (Left hand, gesture: civilian)
# ✅ Sample 168/500 captured (Left hand, gesture: civilian)
# ✅ Sample 169/500 captured (Left hand, gesture: civilian)
# ✅ Sample 170/500 captured (Left hand, gesture: civilian)
# ✅ Sample 171/500 captured (Left hand, gesture: civilian)
# ✅ Sample 172/500 captured (Left hand, gesture: civilian)
# ✅ Sample 173/500 captured (Left hand, gesture: civilian)
# ✅ Sample 174/500 captured (Left hand, gesture: civilian)
# ✅ Sample 175/500 captured (Left hand, gesture: civilian)
# ✅ Sample 176/500 captured (Left hand, gesture: civilian)
# ✅ Sample 177/500 captured (Left hand, gesture: civilian)
# ✅ Sample 178/500 captured (Left hand, gesture: civilian)
# ✅ Sample 179/500 captured (Left hand, gesture: civilian)
# ✅ Sample 180/500 captured (Left hand, gesture: civilian)
# ✅ Sample 181/500 captured (Left hand, gesture: civilian)
# ✅ Sample 182/500 captured (Left hand, gesture: civilian)
# ✅ Sample 183/500 captured (Left hand, gesture: civilian)
# ✅ Sample 184/500 captured (Left hand, gesture: civilian)
# ✅ Sample 185/500 captured (Left hand, gesture: civilian)
# ✅ Sample 186/500 captured (Left hand, gesture: civilian)
# ✅ Sample 187/500 captured (Left hand, gesture: civilian)
# ✅ Sample 188/500 captured (Left hand, gesture: civilian)
# ✅ Sample 189/500 captured (Left hand, gesture: civilian)
# ✅ Sample 190/500 captured (Left hand, gesture: civilian)
# ✅ Sample 191/500 captured (Left hand, gesture: civilian)
# ✅ Sample 192/500 captured (Left hand, gesture: civilian)
# ✅ Sample 193/500 captured (Left hand, gesture: civilian)
# ✅ Sample 194/500 captured (Left hand, gesture: civilian)
# ✅ Sample 195/500 captured (Left hand, gesture: civilian)
# ✅ Sample 196/500 captured (Left hand, gesture: civilian)
# ✅ Sample 197/500 captured (Left hand, gesture: civilian)
# ✅ Sample 198/500 captured (Left hand, gesture: civilian)
# ✅ Sample 199/500 captured (Left hand, gesture: civilian)
# ✅ Sample 200/500 captured (Left hand, gesture: civilian)
# ✅ Sample 201/500 captured (Left hand, gesture: civilian)
# ✅ Sample 202/500 captured (Left hand, gesture: civilian)
# ✅ Sample 203/500 captured (Left hand, gesture: civilian)
# ✅ Sample 204/500 captured (Left hand, gesture: civilian)
# ✅ Sample 205/500 captured (Left hand, gesture: civilian)
# ✅ Sample 206/500 captured (Left hand, gesture: civilian)
# ✅ Sample 207/500 captured (Left hand, gesture: civilian)
# ✅ Sample 208/500 captured (Left hand, gesture: civilian)
# ✅ Sample 209/500 captured (Left hand, gesture: civilian)
# ✅ Sample 210/500 captured (Left hand, gesture: civilian)
# ✅ Sample 211/500 captured (Left hand, gesture: civilian)
# ✅ Sample 212/500 captured (Left hand, gesture: civilian)
# ✅ Sample 213/500 captured (Left hand, gesture: civilian)
# ✅ Sample 214/500 captured (Left hand, gesture: civilian)
# ✅ Sample 215/500 captured (Left hand, gesture: civilian)
# ✅ Sample 216/500 captured (Left hand, gesture: civilian)
# ✅ Sample 217/500 captured (Left hand, gesture: civilian)
# ✅ Sample 218/500 captured (Left hand, gesture: civilian)
# ✅ Sample 219/500 captured (Left hand, gesture: civilian)
# ✅ Sample 220/500 captured (Left hand, gesture: civilian)
# ✅ Sample 221/500 captured (Left hand, gesture: civilian)
# ✅ Sample 222/500 captured (Left hand, gesture: civilian)
# ✅ Sample 223/500 captured (Left hand, gesture: civilian)
# ✅ Sample 224/500 captured (Left hand, gesture: civilian)
# ✅ Sample 225/500 captured (Left hand, gesture: civilian)
# ✅ Sample 226/500 captured (Left hand, gesture: civilian)
# ✅ Sample 227/500 captured (Left hand, gesture: civilian)
# ✅ Sample 228/500 captured (Left hand, gesture: civilian)
# ✅ Sample 229/500 captured (Left hand, gesture: civilian)
# ✅ Sample 230/500 captured (Left hand, gesture: civilian)
# ✅ Sample 231/500 captured (Left hand, gesture: civilian)
# ✅ Sample 232/500 captured (Left hand, gesture: civilian)
# ✅ Sample 233/500 captured (Left hand, gesture: civilian)
# ✅ Sample 234/500 captured (Left hand, gesture: civilian)
# ✅ Sample 235/500 captured (Left hand, gesture: civilian)
# ✅ Sample 236/500 captured (Left hand, gesture: civilian)
# ✅ Sample 237/500 captured (Left hand, gesture: civilian)
# ✅ Sample 238/500 captured (Left hand, gesture: civilian)
# ✅ Sample 239/500 captured (Left hand, gesture: civilian)
# ✅ Sample 240/500 captured (Left hand, gesture: civilian)
# ✅ Sample 241/500 captured (Left hand, gesture: civilian)
# ✅ Sample 242/500 captured (Left hand, gesture: civilian)
# ✅ Sample 243/500 captured (Left hand, gesture: civilian)
# ✅ Sample 244/500 captured (Left hand, gesture: civilian)
# ✅ Sample 245/500 captured (Left hand, gesture: civilian)
# ✅ Sample 246/500 captured (Left hand, gesture: civilian)
# ✅ Sample 247/500 captured (Left hand, gesture: civilian)
# ✅ Sample 248/500 captured (Left hand, gesture: civilian)
# ✅ Sample 249/500 captured (Left hand, gesture: civilian)
# ✅ Sample 250/500 captured (Left hand, gesture: civilian)
# ✅ Sample 251/500 captured (Left hand, gesture: civilian)
# ✅ Sample 252/500 captured (Left hand, gesture: civilian)
# ✅ Sample 253/500 captured (Left hand, gesture: civilian)
# ✅ Sample 254/500 captured (Left hand, gesture: civilian)
# ✅ Sample 255/500 captured (Left hand, gesture: civilian)
# ✅ Sample 256/500 captured (Left hand, gesture: civilian)
# ✅ Sample 257/500 captured (Left hand, gesture: civilian)
# ✅ Sample 258/500 captured (Left hand, gesture: civilian)
# ✅ Sample 259/500 captured (Left hand, gesture: civilian)
# ✅ Sample 260/500 captured (Left hand, gesture: civilian)
# ✅ Sample 261/500 captured (Left hand, gesture: civilian)
# ✅ Sample 262/500 captured (Left hand, gesture: civilian)
# ✅ Sample 263/500 captured (Left hand, gesture: civilian)
# ✅ Sample 264/500 captured (Left hand, gesture: civilian)
# ✅ Sample 265/500 captured (Left hand, gesture: civilian)
# ✅ Sample 266/500 captured (Left hand, gesture: civilian)
# ✅ Sample 267/500 captured (Left hand, gesture: civilian)
# ✅ Sample 268/500 captured (Left hand, gesture: civilian)
# ✅ Sample 269/500 captured (Left hand, gesture: civilian)
# ✅ Sample 270/500 captured (Left hand, gesture: civilian)
# ✅ Sample 271/500 captured (Left hand, gesture: civilian)
# ✅ Sample 272/500 captured (Left hand, gesture: civilian)
# ✅ Sample 273/500 captured (Left hand, gesture: civilian)
# ✅ Sample 274/500 captured (Left hand, gesture: civilian)
# ✅ Sample 275/500 captured (Left hand, gesture: civilian)
# ✅ Sample 276/500 captured (Left hand, gesture: civilian)
# ✅ Sample 277/500 captured (Left hand, gesture: civilian)
# ✅ Sample 278/500 captured (Left hand, gesture: civilian)
# ✅ Sample 279/500 captured (Left hand, gesture: civilian)
# ✅ Sample 280/500 captured (Left hand, gesture: civilian)
# ✅ Sample 281/500 captured (Left hand, gesture: civilian)
# ✅ Sample 282/500 captured (Left hand, gesture: civilian)
# ✅ Sample 283/500 captured (Left hand, gesture: civilian)
# ✅ Sample 284/500 captured (Left hand, gesture: civilian)
# ✅ Sample 285/500 captured (Left hand, gesture: civilian)
# ✅ Sample 286/500 captured (Left hand, gesture: civilian)
# ✅ Sample 287/500 captured (Left hand, gesture: civilian)
# ✅ Sample 288/500 captured (Left hand, gesture: civilian)
# ✅ Sample 289/500 captured (Left hand, gesture: civilian)
# ✅ Sample 290/500 captured (Left hand, gesture: civilian)
# ✅ Sample 291/500 captured (Left hand, gesture: civilian)
# ✅ Sample 292/500 captured (Left hand, gesture: civilian)
# ✅ Sample 293/500 captured (Left hand, gesture: civilian)
# ✅ Sample 294/500 captured (Left hand, gesture: civilian)
# ✅ Sample 295/500 captured (Left hand, gesture: civilian)
# ✅ Sample 296/500 captured (Left hand, gesture: civilian)
# ✅ Sample 297/500 captured (Left hand, gesture: civilian)
# ✅ Sample 298/500 captured (Left hand, gesture: civilian)
# ✅ Sample 299/500 captured (Left hand, gesture: civilian)
# ✅ Sample 300/500 captured (Left hand, gesture: civilian)
# ✅ Sample 301/500 captured (Left hand, gesture: civilian)
# ✅ Sample 302/500 captured (Left hand, gesture: civilian)
# ✅ Sample 303/500 captured (Left hand, gesture: civilian)
# ✅ Sample 304/500 captured (Left hand, gesture: civilian)
# ✅ Sample 305/500 captured (Left hand, gesture: civilian)
# ✅ Sample 306/500 captured (Left hand, gesture: civilian)
# ✅ Sample 307/500 captured (Left hand, gesture: civilian)
# ✅ Sample 308/500 captured (Left hand, gesture: civilian)
# ✅ Sample 309/500 captured (Left hand, gesture: civilian)
# ✅ Sample 310/500 captured (Left hand, gesture: civilian)
# ✅ Sample 311/500 captured (Left hand, gesture: civilian)
# ✅ Sample 312/500 captured (Left hand, gesture: civilian)
# ✅ Sample 313/500 captured (Left hand, gesture: civilian)
# ✅ Sample 314/500 captured (Left hand, gesture: civilian)
# ✅ Sample 315/500 captured (Left hand, gesture: civilian)
# ✅ Sample 316/500 captured (Left hand, gesture: civilian)
# ✅ Sample 317/500 captured (Left hand, gesture: civilian)
# ✅ Sample 318/500 captured (Left hand, gesture: civilian)
# ✅ Sample 319/500 captured (Left hand, gesture: civilian)
# ✅ Sample 320/500 captured (Left hand, gesture: civilian)
# ✅ Sample 321/500 captured (Left hand, gesture: civilian)
# ✅ Sample 322/500 captured (Left hand, gesture: civilian)
# ✅ Sample 323/500 captured (Left hand, gesture: civilian)
# ✅ Sample 324/500 captured (Left hand, gesture: civilian)
# ✅ Sample 325/500 captured (Left hand, gesture: civilian)
# ✅ Sample 326/500 captured (Left hand, gesture: civilian)
# ✅ Sample 327/500 captured (Left hand, gesture: civilian)
# ✅ Sample 328/500 captured (Left hand, gesture: civilian)
# ✅ Sample 329/500 captured (Left hand, gesture: civilian)
# ✅ Sample 330/500 captured (Left hand, gesture: civilian)
# ✅ Sample 331/500 captured (Left hand, gesture: civilian)
# ✅ Sample 332/500 captured (Left hand, gesture: civilian)
# ✅ Sample 333/500 captured (Left hand, gesture: civilian)
# ✅ Sample 334/500 captured (Left hand, gesture: civilian)
# ✅ Sample 335/500 captured (Left hand, gesture: civilian)
# ✅ Sample 336/500 captured (Left hand, gesture: civilian)
# ✅ Sample 337/500 captured (Left hand, gesture: civilian)
# ✅ Sample 338/500 captured (Left hand, gesture: civilian)
# ✅ Sample 339/500 captured (Left hand, gesture: civilian)
# ✅ Sample 340/500 captured (Left hand, gesture: civilian)
# ✅ Sample 341/500 captured (Left hand, gesture: civilian)
# ✅ Sample 342/500 captured (Left hand, gesture: civilian)
# ✅ Sample 343/500 captured (Left hand, gesture: civilian)
# ✅ Sample 344/500 captured (Left hand, gesture: civilian)
# ✅ Sample 345/500 captured (Left hand, gesture: civilian)
# ✅ Sample 346/500 captured (Left hand, gesture: civilian)
# ✅ Sample 347/500 captured (Left hand, gesture: civilian)
# ✅ Sample 348/500 captured (Left hand, gesture: civilian)
# ✅ Sample 349/500 captured (Left hand, gesture: civilian)
# ✅ Sample 350/500 captured (Left hand, gesture: civilian)
# ✅ Sample 351/500 captured (Left hand, gesture: civilian)
# ✅ Sample 352/500 captured (Left hand, gesture: civilian)
# ✅ Sample 353/500 captured (Left hand, gesture: civilian)
# ✅ Sample 354/500 captured (Left hand, gesture: civilian)
# ✅ Sample 355/500 captured (Left hand, gesture: civilian)
# ✅ Sample 356/500 captured (Left hand, gesture: civilian)
# ✅ Sample 357/500 captured (Left hand, gesture: civilian)
# ✅ Sample 358/500 captured (Left hand, gesture: civilian)
# ✅ Sample 359/500 captured (Left hand, gesture: civilian)
# ✅ Sample 360/500 captured (Left hand, gesture: civilian)
# ✅ Sample 361/500 captured (Left hand, gesture: civilian)
# ✅ Sample 362/500 captured (Left hand, gesture: civilian)
# ✅ Sample 363/500 captured (Left hand, gesture: civilian)
# ✅ Sample 364/500 captured (Left hand, gesture: civilian)
# ✅ Sample 365/500 captured (Left hand, gesture: civilian)
# ✅ Sample 366/500 captured (Left hand, gesture: civilian)
# ✅ Sample 367/500 captured (Left hand, gesture: civilian)
# ✅ Sample 368/500 captured (Left hand, gesture: civilian)
# ✅ Sample 369/500 captured (Left hand, gesture: civilian)
# ✅ Sample 370/500 captured (Left hand, gesture: civilian)
# ✅ Sample 371/500 captured (Left hand, gesture: civilian)
# ✅ Sample 372/500 captured (Left hand, gesture: civilian)
# ✅ Sample 373/500 captured (Left hand, gesture: civilian)
# ✅ Sample 374/500 captured (Left hand, gesture: civilian)
# ✅ Sample 375/500 captured (Left hand, gesture: civilian)
# ✅ Sample 376/500 captured (Left hand, gesture: civilian)
# ✅ Sample 377/500 captured (Left hand, gesture: civilian)
# ✅ Sample 378/500 captured (Left hand, gesture: civilian)
# ✅ Sample 379/500 captured (Left hand, gesture: civilian)
# ✅ Sample 380/500 captured (Left hand, gesture: civilian)
# ✅ Sample 381/500 captured (Left hand, gesture: civilian)
# ✅ Sample 382/500 captured (Left hand, gesture: civilian)
# ✅ Sample 383/500 captured (Left hand, gesture: civilian)
# ✅ Sample 384/500 captured (Left hand, gesture: civilian)
# ✅ Sample 385/500 captured (Left hand, gesture: civilian)
# ✅ Sample 386/500 captured (Left hand, gesture: civilian)
# ✅ Sample 387/500 captured (Left hand, gesture: civilian)
# ✅ Sample 388/500 captured (Left hand, gesture: civilian)
# ✅ Sample 389/500 captured (Left hand, gesture: civilian)
# ✅ Sample 390/500 captured (Left hand, gesture: civilian)
# ✅ Sample 391/500 captured (Left hand, gesture: civilian)
# ✅ Sample 392/500 captured (Left hand, gesture: civilian)
# ✅ Sample 393/500 captured (Left hand, gesture: civilian)
# ✅ Sample 394/500 captured (Left hand, gesture: civilian)
# ✅ Sample 395/500 captured (Left hand, gesture: civilian)
# ✅ Sample 396/500 captured (Left hand, gesture: civilian)
# ✅ Sample 397/500 captured (Left hand, gesture: civilian)
# ✅ Sample 398/500 captured (Left hand, gesture: civilian)
# ✅ Sample 399/500 captured (Left hand, gesture: civilian)
# ✅ Sample 400/500 captured (Left hand, gesture: civilian)
# ✅ Sample 401/500 captured (Left hand, gesture: civilian)
# ✅ Sample 402/500 captured (Left hand, gesture: civilian)
# ✅ Sample 403/500 captured (Left hand, gesture: civilian)
# ✅ Sample 404/500 captured (Left hand, gesture: civilian)
# ✅ Sample 405/500 captured (Left hand, gesture: civilian)
# ✅ Sample 406/500 captured (Left hand, gesture: civilian)
# ✅ Sample 407/500 captured (Left hand, gesture: civilian)
# ✅ Sample 408/500 captured (Left hand, gesture: civilian)
# ✅ Sample 409/500 captured (Left hand, gesture: civilian)
# ✅ Sample 410/500 captured (Left hand, gesture: civilian)
# ✅ Sample 411/500 captured (Left hand, gesture: civilian)
# ✅ Sample 412/500 captured (Left hand, gesture: civilian)
# ✅ Sample 413/500 captured (Left hand, gesture: civilian)
# ✅ Sample 414/500 captured (Left hand, gesture: civilian)
# ✅ Sample 415/500 captured (Left hand, gesture: civilian)
# ✅ Sample 416/500 captured (Left hand, gesture: civilian)
# ✅ Sample 417/500 captured (Left hand, gesture: civilian)
# ✅ Sample 418/500 captured (Left hand, gesture: civilian)
# ✅ Sample 419/500 captured (Left hand, gesture: civilian)
# ✅ Sample 420/500 captured (Left hand, gesture: civilian)
# ✅ Sample 421/500 captured (Left hand, gesture: civilian)
# ✅ Sample 422/500 captured (Left hand, gesture: civilian)
# ✅ Sample 423/500 captured (Left hand, gesture: civilian)
# ✅ Sample 424/500 captured (Left hand, gesture: civilian)
# ✅ Sample 425/500 captured (Left hand, gesture: civilian)
# ✅ Sample 426/500 captured (Left hand, gesture: civilian)
# ✅ Sample 427/500 captured (Left hand, gesture: civilian)
# ✅ Sample 428/500 captured (Left hand, gesture: civilian)
# ✅ Sample 429/500 captured (Left hand, gesture: civilian)
# ✅ Sample 430/500 captured (Left hand, gesture: civilian)
# ✅ Sample 431/500 captured (Left hand, gesture: civilian)
# ✅ Sample 432/500 captured (Left hand, gesture: civilian)
# ✅ Sample 433/500 captured (Left hand, gesture: civilian)
# ✅ Sample 434/500 captured (Left hand, gesture: civilian)
# ✅ Sample 435/500 captured (Left hand, gesture: civilian)
# ✅ Sample 436/500 captured (Left hand, gesture: civilian)
# ✅ Sample 437/500 captured (Left hand, gesture: civilian)
# ✅ Sample 438/500 captured (Left hand, gesture: civilian)
# ✅ Sample 439/500 captured (Left hand, gesture: civilian)
# ✅ Sample 440/500 captured (Left hand, gesture: civilian)
# ✅ Sample 441/500 captured (Left hand, gesture: civilian)
# ✅ Sample 442/500 captured (Left hand, gesture: civilian)
# ✅ Sample 443/500 captured (Left hand, gesture: civilian)
# ✅ Sample 444/500 captured (Left hand, gesture: civilian)
# ✅ Sample 445/500 captured (Left hand, gesture: civilian)
# ✅ Sample 446/500 captured (Left hand, gesture: civilian)
# ✅ Sample 447/500 captured (Left hand, gesture: civilian)
# ✅ Sample 448/500 captured (Left hand, gesture: civilian)
# ✅ Sample 449/500 captured (Left hand, gesture: civilian)
# ✅ Sample 450/500 captured (Left hand, gesture: civilian)
# ✅ Sample 451/500 captured (Left hand, gesture: civilian)
# ✅ Sample 452/500 captured (Left hand, gesture: civilian)
# ✅ Sample 453/500 captured (Left hand, gesture: civilian)
# ✅ Sample 454/500 captured (Left hand, gesture: civilian)
# ✅ Sample 455/500 captured (Left hand, gesture: civilian)
# ✅ Sample 456/500 captured (Left hand, gesture: civilian)
# ✅ Sample 457/500 captured (Left hand, gesture: civilian)
# ✅ Sample 458/500 captured (Left hand, gesture: civilian)
# ✅ Sample 459/500 captured (Left hand, gesture: civilian)
# ✅ Sample 460/500 captured (Left hand, gesture: civilian)
# ✅ Sample 461/500 captured (Left hand, gesture: civilian)
# ✅ Sample 462/500 captured (Left hand, gesture: civilian)
# ✅ Sample 463/500 captured (Left hand, gesture: civilian)
# ✅ Sample 464/500 captured (Left hand, gesture: civilian)
# ✅ Sample 465/500 captured (Left hand, gesture: civilian)
# ✅ Sample 466/500 captured (Left hand, gesture: civilian)
# ✅ Sample 467/500 captured (Left hand, gesture: civilian)
# ✅ Sample 468/500 captured (Left hand, gesture: civilian)
# ✅ Sample 469/500 captured (Left hand, gesture: civilian)
# ✅ Sample 470/500 captured (Left hand, gesture: civilian)
# ✅ Sample 471/500 captured (Left hand, gesture: civilian)
# ✅ Sample 472/500 captured (Left hand, gesture: civilian)
# ✅ Sample 473/500 captured (Left hand, gesture: civilian)
# ✅ Sample 474/500 captured (Left hand, gesture: civilian)
# ✅ Sample 475/500 captured (Left hand, gesture: civilian)
# ✅ Sample 476/500 captured (Left hand, gesture: civilian)
# ✅ Sample 477/500 captured (Left hand, gesture: civilian)
# ✅ Sample 478/500 captured (Left hand, gesture: civilian)
# ✅ Sample 479/500 captured (Left hand, gesture: civilian)
# ✅ Sample 480/500 captured (Left hand, gesture: civilian)
# ✅ Sample 481/500 captured (Left hand, gesture: civilian)
# ✅ Sample 482/500 captured (Left hand, gesture: civilian)
# ✅ Sample 483/500 captured (Left hand, gesture: civilian)
# ✅ Sample 484/500 captured (Left hand, gesture: civilian)
# ✅ Sample 485/500 captured (Left hand, gesture: civilian)
# ✅ Sample 486/500 captured (Left hand, gesture: civilian)
# ✅ Sample 487/500 captured (Left hand, gesture: civilian)
# ✅ Sample 488/500 captured (Left hand, gesture: civilian)
# ✅ Sample 489/500 captured (Left hand, gesture: civilian)
# ✅ Sample 490/500 captured (Left hand, gesture: civilian)
# ✅ Sample 491/500 captured (Left hand, gesture: civilian)
# ✅ Sample 492/500 captured (Left hand, gesture: civilian)
# ✅ Sample 493/500 captured (Left hand, gesture: civilian)
# ✅ Sample 494/500 captured (Left hand, gesture: civilian)
# ✅ Sample 495/500 captured (Left hand, gesture: civilian)
# ✅ Sample 496/500 captured (Left hand, gesture: civilian)
# ✅ Sample 497/500 captured (Left hand, gesture: civilian)
# ✅ Sample 498/500 captured (Left hand, gesture: civilian)
# ✅ Sample 499/500 captured (Left hand, gesture: civilian)
# ✅ Sample 500/500 captured (Left hand, gesture: civilian)
#
# CSV saved: ../data/raw/upd_civilian.csv (2000 total rows)

# %%
gesture_label="cool" 
output_csv = '../data/raw/upd_cool.csv'

capture_hands_to_csv(
        output_csv=output_csv,
        gesture_label=gesture_label,
        max_samples=500,
        capture_interval=0.15
    )
# Out:
# I0000 00:00:1763285774.655583   64322 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763285774.660025   84846 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-34-generic)
# W0000 00:00:1763285774.681077   84828 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1763285774.698382   84840 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera ready. Capturing every 0.15s. Press 'q' to quit.
# ✅ Sample 1/500 captured (Right hand, gesture: cool)
# ✅ Sample 2/500 captured (Right hand, gesture: cool)
# ✅ Sample 3/500 captured (Right hand, gesture: cool)
# ✅ Sample 4/500 captured (Right hand, gesture: cool)
# ✅ Sample 5/500 captured (Right hand, gesture: cool)
# ✅ Sample 6/500 captured (Right hand, gesture: cool)
# ✅ Sample 7/500 captured (Right hand, gesture: cool)
# ✅ Sample 8/500 captured (Right hand, gesture: cool)
# ✅ Sample 9/500 captured (Right hand, gesture: cool)
# ✅ Sample 10/500 captured (Right hand, gesture: cool)
# ✅ Sample 11/500 captured (Right hand, gesture: cool)
# ✅ Sample 12/500 captured (Right hand, gesture: cool)
# ✅ Sample 13/500 captured (Right hand, gesture: cool)
# ✅ Sample 14/500 captured (Right hand, gesture: cool)
# ✅ Sample 15/500 captured (Right hand, gesture: cool)
# ✅ Sample 16/500 captured (Right hand, gesture: cool)
# ✅ Sample 17/500 captured (Right hand, gesture: cool)
# ✅ Sample 18/500 captured (Right hand, gesture: cool)
# ✅ Sample 19/500 captured (Right hand, gesture: cool)
# ✅ Sample 20/500 captured (Right hand, gesture: cool)
# ✅ Sample 21/500 captured (Right hand, gesture: cool)
# ✅ Sample 22/500 captured (Right hand, gesture: cool)
# ✅ Sample 23/500 captured (Right hand, gesture: cool)
# ✅ Sample 24/500 captured (Right hand, gesture: cool)
# ✅ Sample 25/500 captured (Right hand, gesture: cool)
# ✅ Sample 26/500 captured (Right hand, gesture: cool)
# ✅ Sample 27/500 captured (Right hand, gesture: cool)
# ✅ Sample 28/500 captured (Right hand, gesture: cool)
# ✅ Sample 29/500 captured (Right hand, gesture: cool)
# ✅ Sample 30/500 captured (Right hand, gesture: cool)
# ✅ Sample 31/500 captured (Right hand, gesture: cool)
# ✅ Sample 32/500 captured (Right hand, gesture: cool)
# ✅ Sample 33/500 captured (Right hand, gesture: cool)
# ✅ Sample 34/500 captured (Right hand, gesture: cool)
# ✅ Sample 35/500 captured (Right hand, gesture: cool)
# ✅ Sample 36/500 captured (Right hand, gesture: cool)
# ✅ Sample 37/500 captured (Right hand, gesture: cool)
# ✅ Sample 38/500 captured (Right hand, gesture: cool)
# ✅ Sample 39/500 captured (Right hand, gesture: cool)
# ✅ Sample 40/500 captured (Right hand, gesture: cool)
# ✅ Sample 41/500 captured (Right hand, gesture: cool)
# ✅ Sample 42/500 captured (Right hand, gesture: cool)
# ✅ Sample 43/500 captured (Right hand, gesture: cool)
# ✅ Sample 44/500 captured (Right hand, gesture: cool)
# ✅ Sample 45/500 captured (Right hand, gesture: cool)
# ✅ Sample 46/500 captured (Right hand, gesture: cool)
# ✅ Sample 47/500 captured (Right hand, gesture: cool)
# ✅ Sample 48/500 captured (Right hand, gesture: cool)
# ✅ Sample 49/500 captured (Right hand, gesture: cool)
# ✅ Sample 50/500 captured (Right hand, gesture: cool)
# ✅ Sample 51/500 captured (Right hand, gesture: cool)
# ✅ Sample 52/500 captured (Right hand, gesture: cool)
# ✅ Sample 53/500 captured (Right hand, gesture: cool)
# ✅ Sample 54/500 captured (Right hand, gesture: cool)
# ✅ Sample 55/500 captured (Right hand, gesture: cool)
# ✅ Sample 56/500 captured (Right hand, gesture: cool)
# ✅ Sample 57/500 captured (Right hand, gesture: cool)
# ✅ Sample 58/500 captured (Right hand, gesture: cool)
# ✅ Sample 59/500 captured (Right hand, gesture: cool)
# ✅ Sample 60/500 captured (Right hand, gesture: cool)
# ✅ Sample 61/500 captured (Right hand, gesture: cool)
# ✅ Sample 62/500 captured (Right hand, gesture: cool)
# ✅ Sample 63/500 captured (Right hand, gesture: cool)
# ✅ Sample 64/500 captured (Right hand, gesture: cool)
# ✅ Sample 65/500 captured (Right hand, gesture: cool)
# ✅ Sample 66/500 captured (Right hand, gesture: cool)
# ✅ Sample 67/500 captured (Right hand, gesture: cool)
# ✅ Sample 68/500 captured (Right hand, gesture: cool)
# ✅ Sample 69/500 captured (Right hand, gesture: cool)
# ✅ Sample 70/500 captured (Right hand, gesture: cool)
# ✅ Sample 71/500 captured (Right hand, gesture: cool)
# ✅ Sample 72/500 captured (Right hand, gesture: cool)
# ✅ Sample 73/500 captured (Right hand, gesture: cool)
# ✅ Sample 74/500 captured (Right hand, gesture: cool)
# ✅ Sample 75/500 captured (Right hand, gesture: cool)
# ✅ Sample 76/500 captured (Right hand, gesture: cool)
# ✅ Sample 77/500 captured (Right hand, gesture: cool)
# ✅ Sample 78/500 captured (Right hand, gesture: cool)
# ✅ Sample 79/500 captured (Right hand, gesture: cool)
# ✅ Sample 80/500 captured (Right hand, gesture: cool)
# ✅ Sample 81/500 captured (Right hand, gesture: cool)
# ✅ Sample 82/500 captured (Right hand, gesture: cool)
# ✅ Sample 83/500 captured (Right hand, gesture: cool)
# ✅ Sample 84/500 captured (Right hand, gesture: cool)
# ✅ Sample 85/500 captured (Right hand, gesture: cool)
# ✅ Sample 86/500 captured (Right hand, gesture: cool)
# ✅ Sample 87/500 captured (Right hand, gesture: cool)
# ✅ Sample 88/500 captured (Right hand, gesture: cool)
# ✅ Sample 89/500 captured (Right hand, gesture: cool)
# ✅ Sample 90/500 captured (Right hand, gesture: cool)
# ✅ Sample 91/500 captured (Right hand, gesture: cool)
# ✅ Sample 92/500 captured (Right hand, gesture: cool)
# ✅ Sample 93/500 captured (Right hand, gesture: cool)
# ✅ Sample 94/500 captured (Right hand, gesture: cool)
# ✅ Sample 95/500 captured (Right hand, gesture: cool)
# ✅ Sample 96/500 captured (Right hand, gesture: cool)
# ✅ Sample 97/500 captured (Right hand, gesture: cool)
# ✅ Sample 98/500 captured (Right hand, gesture: cool)
# ✅ Sample 99/500 captured (Right hand, gesture: cool)
# ✅ Sample 100/500 captured (Right hand, gesture: cool)
# ✅ Sample 101/500 captured (Right hand, gesture: cool)
# ✅ Sample 102/500 captured (Right hand, gesture: cool)
# ✅ Sample 103/500 captured (Right hand, gesture: cool)
# ✅ Sample 104/500 captured (Right hand, gesture: cool)
# ✅ Sample 105/500 captured (Right hand, gesture: cool)
# ✅ Sample 106/500 captured (Right hand, gesture: cool)
# ✅ Sample 107/500 captured (Right hand, gesture: cool)
# ✅ Sample 108/500 captured (Right hand, gesture: cool)
# ✅ Sample 109/500 captured (Right hand, gesture: cool)
# ✅ Sample 110/500 captured (Right hand, gesture: cool)
# ✅ Sample 111/500 captured (Right hand, gesture: cool)
# ✅ Sample 112/500 captured (Right hand, gesture: cool)
# ✅ Sample 113/500 captured (Right hand, gesture: cool)
# ✅ Sample 114/500 captured (Right hand, gesture: cool)
# ✅ Sample 115/500 captured (Right hand, gesture: cool)
# ✅ Sample 116/500 captured (Right hand, gesture: cool)
# ✅ Sample 117/500 captured (Right hand, gesture: cool)
# ✅ Sample 118/500 captured (Right hand, gesture: cool)
# ✅ Sample 119/500 captured (Right hand, gesture: cool)
# ✅ Sample 120/500 captured (Right hand, gesture: cool)
# ✅ Sample 121/500 captured (Right hand, gesture: cool)
# ✅ Sample 122/500 captured (Right hand, gesture: cool)
# ✅ Sample 123/500 captured (Right hand, gesture: cool)
# ✅ Sample 124/500 captured (Right hand, gesture: cool)
# ✅ Sample 125/500 captured (Right hand, gesture: cool)
# ✅ Sample 126/500 captured (Right hand, gesture: cool)
# ✅ Sample 127/500 captured (Right hand, gesture: cool)
# ✅ Sample 128/500 captured (Right hand, gesture: cool)
# ✅ Sample 129/500 captured (Right hand, gesture: cool)
# ✅ Sample 130/500 captured (Right hand, gesture: cool)
# ✅ Sample 131/500 captured (Right hand, gesture: cool)
# ✅ Sample 132/500 captured (Right hand, gesture: cool)
# ✅ Sample 133/500 captured (Right hand, gesture: cool)
# ✅ Sample 134/500 captured (Right hand, gesture: cool)
# ✅ Sample 135/500 captured (Right hand, gesture: cool)
# ✅ Sample 136/500 captured (Right hand, gesture: cool)
# ✅ Sample 137/500 captured (Right hand, gesture: cool)
# ✅ Sample 138/500 captured (Right hand, gesture: cool)
# ✅ Sample 139/500 captured (Right hand, gesture: cool)
# ✅ Sample 140/500 captured (Right hand, gesture: cool)
# ✅ Sample 141/500 captured (Right hand, gesture: cool)
# ✅ Sample 142/500 captured (Right hand, gesture: cool)
# ✅ Sample 143/500 captured (Right hand, gesture: cool)
# ✅ Sample 144/500 captured (Right hand, gesture: cool)
# ✅ Sample 145/500 captured (Right hand, gesture: cool)
# ✅ Sample 146/500 captured (Right hand, gesture: cool)
# ✅ Sample 147/500 captured (Right hand, gesture: cool)
# ✅ Sample 148/500 captured (Right hand, gesture: cool)
# ✅ Sample 149/500 captured (Right hand, gesture: cool)
# ✅ Sample 150/500 captured (Right hand, gesture: cool)
# ✅ Sample 151/500 captured (Right hand, gesture: cool)
# ✅ Sample 152/500 captured (Right hand, gesture: cool)
# ✅ Sample 153/500 captured (Right hand, gesture: cool)
# ✅ Sample 154/500 captured (Right hand, gesture: cool)
# ✅ Sample 155/500 captured (Right hand, gesture: cool)
# ✅ Sample 156/500 captured (Right hand, gesture: cool)
# ✅ Sample 157/500 captured (Right hand, gesture: cool)
# ✅ Sample 158/500 captured (Right hand, gesture: cool)
# ✅ Sample 159/500 captured (Right hand, gesture: cool)
# ✅ Sample 160/500 captured (Right hand, gesture: cool)
# ✅ Sample 161/500 captured (Right hand, gesture: cool)
# ✅ Sample 162/500 captured (Right hand, gesture: cool)
# ✅ Sample 163/500 captured (Right hand, gesture: cool)
# ✅ Sample 164/500 captured (Right hand, gesture: cool)
# ✅ Sample 165/500 captured (Right hand, gesture: cool)
# ✅ Sample 166/500 captured (Right hand, gesture: cool)
# ✅ Sample 167/500 captured (Right hand, gesture: cool)
# ✅ Sample 168/500 captured (Right hand, gesture: cool)
# ✅ Sample 169/500 captured (Right hand, gesture: cool)
# ✅ Sample 170/500 captured (Right hand, gesture: cool)
# ✅ Sample 171/500 captured (Right hand, gesture: cool)
# ✅ Sample 172/500 captured (Right hand, gesture: cool)
# ✅ Sample 173/500 captured (Right hand, gesture: cool)
# ✅ Sample 174/500 captured (Right hand, gesture: cool)
# ✅ Sample 175/500 captured (Right hand, gesture: cool)
# ✅ Sample 176/500 captured (Right hand, gesture: cool)
# ✅ Sample 177/500 captured (Right hand, gesture: cool)
# ✅ Sample 178/500 captured (Right hand, gesture: cool)
# ✅ Sample 179/500 captured (Right hand, gesture: cool)
# ✅ Sample 180/500 captured (Right hand, gesture: cool)
# ✅ Sample 181/500 captured (Right hand, gesture: cool)
# ✅ Sample 182/500 captured (Right hand, gesture: cool)
# ✅ Sample 183/500 captured (Right hand, gesture: cool)
# ✅ Sample 184/500 captured (Right hand, gesture: cool)
# ✅ Sample 185/500 captured (Right hand, gesture: cool)
# ✅ Sample 186/500 captured (Right hand, gesture: cool)
# ✅ Sample 187/500 captured (Right hand, gesture: cool)
# ✅ Sample 188/500 captured (Right hand, gesture: cool)
# ✅ Sample 189/500 captured (Right hand, gesture: cool)
# ✅ Sample 190/500 captured (Right hand, gesture: cool)
# ✅ Sample 191/500 captured (Right hand, gesture: cool)
# ✅ Sample 192/500 captured (Right hand, gesture: cool)
# ✅ Sample 193/500 captured (Right hand, gesture: cool)
# ✅ Sample 194/500 captured (Right hand, gesture: cool)
# ✅ Sample 195/500 captured (Right hand, gesture: cool)
# ✅ Sample 196/500 captured (Right hand, gesture: cool)
# ✅ Sample 197/500 captured (Right hand, gesture: cool)
# ✅ Sample 198/500 captured (Right hand, gesture: cool)
# ✅ Sample 199/500 captured (Right hand, gesture: cool)
# ✅ Sample 200/500 captured (Right hand, gesture: cool)
# ✅ Sample 201/500 captured (Right hand, gesture: cool)
# ✅ Sample 202/500 captured (Right hand, gesture: cool)
# ✅ Sample 203/500 captured (Right hand, gesture: cool)
# ✅ Sample 204/500 captured (Right hand, gesture: cool)
# ✅ Sample 205/500 captured (Right hand, gesture: cool)
# ✅ Sample 206/500 captured (Right hand, gesture: cool)
# ✅ Sample 207/500 captured (Right hand, gesture: cool)
# ✅ Sample 208/500 captured (Right hand, gesture: cool)
# ✅ Sample 209/500 captured (Right hand, gesture: cool)
# ✅ Sample 210/500 captured (Right hand, gesture: cool)
# ✅ Sample 211/500 captured (Right hand, gesture: cool)
# ✅ Sample 212/500 captured (Right hand, gesture: cool)
# ✅ Sample 213/500 captured (Right hand, gesture: cool)
# ✅ Sample 214/500 captured (Right hand, gesture: cool)
# ✅ Sample 215/500 captured (Right hand, gesture: cool)
# ✅ Sample 216/500 captured (Right hand, gesture: cool)
# ✅ Sample 217/500 captured (Right hand, gesture: cool)
# ✅ Sample 218/500 captured (Right hand, gesture: cool)
# ✅ Sample 219/500 captured (Right hand, gesture: cool)
# ✅ Sample 220/500 captured (Right hand, gesture: cool)
# ✅ Sample 221/500 captured (Right hand, gesture: cool)
# ✅ Sample 222/500 captured (Right hand, gesture: cool)
# ✅ Sample 223/500 captured (Right hand, gesture: cool)
# ✅ Sample 224/500 captured (Right hand, gesture: cool)
# ✅ Sample 225/500 captured (Right hand, gesture: cool)
# ✅ Sample 226/500 captured (Right hand, gesture: cool)
# ✅ Sample 227/500 captured (Right hand, gesture: cool)
# ✅ Sample 228/500 captured (Right hand, gesture: cool)
# ✅ Sample 229/500 captured (Right hand, gesture: cool)
# ✅ Sample 230/500 captured (Right hand, gesture: cool)
# ✅ Sample 231/500 captured (Right hand, gesture: cool)
# ✅ Sample 232/500 captured (Right hand, gesture: cool)
# ✅ Sample 233/500 captured (Right hand, gesture: cool)
# ✅ Sample 234/500 captured (Right hand, gesture: cool)
# ✅ Sample 235/500 captured (Right hand, gesture: cool)
# ✅ Sample 236/500 captured (Right hand, gesture: cool)
# ✅ Sample 237/500 captured (Right hand, gesture: cool)
# ✅ Sample 238/500 captured (Right hand, gesture: cool)
# ✅ Sample 239/500 captured (Right hand, gesture: cool)
# ✅ Sample 240/500 captured (Right hand, gesture: cool)
# ✅ Sample 241/500 captured (Right hand, gesture: cool)
# ✅ Sample 242/500 captured (Right hand, gesture: cool)
# ✅ Sample 243/500 captured (Right hand, gesture: cool)
# ✅ Sample 244/500 captured (Right hand, gesture: cool)
# ✅ Sample 245/500 captured (Right hand, gesture: cool)
# ✅ Sample 246/500 captured (Right hand, gesture: cool)
# ✅ Sample 247/500 captured (Right hand, gesture: cool)
# ✅ Sample 248/500 captured (Right hand, gesture: cool)
# ✅ Sample 249/500 captured (Right hand, gesture: cool)
# ✅ Sample 250/500 captured (Right hand, gesture: cool)
# ✅ Sample 251/500 captured (Right hand, gesture: cool)
# ✅ Sample 252/500 captured (Right hand, gesture: cool)
# ✅ Sample 253/500 captured (Right hand, gesture: cool)
# ✅ Sample 254/500 captured (Right hand, gesture: cool)
# ✅ Sample 255/500 captured (Right hand, gesture: cool)
# ✅ Sample 256/500 captured (Right hand, gesture: cool)
# ✅ Sample 257/500 captured (Right hand, gesture: cool)
# ✅ Sample 258/500 captured (Right hand, gesture: cool)
# ✅ Sample 259/500 captured (Right hand, gesture: cool)
# ✅ Sample 260/500 captured (Right hand, gesture: cool)
# ✅ Sample 261/500 captured (Right hand, gesture: cool)
# ✅ Sample 262/500 captured (Right hand, gesture: cool)
# ✅ Sample 263/500 captured (Right hand, gesture: cool)
# ✅ Sample 264/500 captured (Right hand, gesture: cool)
# ✅ Sample 265/500 captured (Right hand, gesture: cool)
# ✅ Sample 266/500 captured (Right hand, gesture: cool)
# ✅ Sample 267/500 captured (Right hand, gesture: cool)
# ✅ Sample 268/500 captured (Right hand, gesture: cool)
# ✅ Sample 269/500 captured (Right hand, gesture: cool)
# ✅ Sample 270/500 captured (Right hand, gesture: cool)
# ✅ Sample 271/500 captured (Right hand, gesture: cool)
# ✅ Sample 272/500 captured (Right hand, gesture: cool)
# ✅ Sample 273/500 captured (Right hand, gesture: cool)
# ✅ Sample 274/500 captured (Right hand, gesture: cool)
# ✅ Sample 275/500 captured (Right hand, gesture: cool)
# ✅ Sample 276/500 captured (Right hand, gesture: cool)
# ✅ Sample 277/500 captured (Right hand, gesture: cool)
# ✅ Sample 278/500 captured (Right hand, gesture: cool)
# ✅ Sample 279/500 captured (Right hand, gesture: cool)
# ✅ Sample 280/500 captured (Right hand, gesture: cool)
# ✅ Sample 281/500 captured (Right hand, gesture: cool)
# ✅ Sample 282/500 captured (Right hand, gesture: cool)
# ✅ Sample 283/500 captured (Right hand, gesture: cool)
# ✅ Sample 284/500 captured (Right hand, gesture: cool)
# ✅ Sample 285/500 captured (Right hand, gesture: cool)
# ✅ Sample 286/500 captured (Right hand, gesture: cool)
# ✅ Sample 287/500 captured (Right hand, gesture: cool)
# ✅ Sample 288/500 captured (Right hand, gesture: cool)
# ✅ Sample 289/500 captured (Right hand, gesture: cool)
# ✅ Sample 290/500 captured (Right hand, gesture: cool)
# ✅ Sample 291/500 captured (Right hand, gesture: cool)
# ✅ Sample 292/500 captured (Right hand, gesture: cool)
# ✅ Sample 293/500 captured (Right hand, gesture: cool)
# ✅ Sample 294/500 captured (Right hand, gesture: cool)
# ✅ Sample 295/500 captured (Right hand, gesture: cool)
# ✅ Sample 296/500 captured (Right hand, gesture: cool)
# ✅ Sample 297/500 captured (Right hand, gesture: cool)
# ✅ Sample 298/500 captured (Right hand, gesture: cool)
# ✅ Sample 299/500 captured (Right hand, gesture: cool)
# ✅ Sample 300/500 captured (Right hand, gesture: cool)
# ✅ Sample 301/500 captured (Right hand, gesture: cool)
# ✅ Sample 302/500 captured (Right hand, gesture: cool)
# ✅ Sample 303/500 captured (Right hand, gesture: cool)
# ✅ Sample 304/500 captured (Right hand, gesture: cool)
# ✅ Sample 305/500 captured (Right hand, gesture: cool)
# ✅ Sample 306/500 captured (Right hand, gesture: cool)
# ✅ Sample 307/500 captured (Right hand, gesture: cool)
# ✅ Sample 308/500 captured (Right hand, gesture: cool)
# ✅ Sample 309/500 captured (Right hand, gesture: cool)
# ✅ Sample 310/500 captured (Right hand, gesture: cool)
# ✅ Sample 311/500 captured (Right hand, gesture: cool)
# ✅ Sample 312/500 captured (Right hand, gesture: cool)
# ✅ Sample 313/500 captured (Right hand, gesture: cool)
# ✅ Sample 314/500 captured (Right hand, gesture: cool)
# ✅ Sample 315/500 captured (Right hand, gesture: cool)
# ✅ Sample 316/500 captured (Right hand, gesture: cool)
# ✅ Sample 317/500 captured (Right hand, gesture: cool)
# ✅ Sample 318/500 captured (Right hand, gesture: cool)
# ✅ Sample 319/500 captured (Right hand, gesture: cool)
# ✅ Sample 320/500 captured (Right hand, gesture: cool)
# ✅ Sample 321/500 captured (Right hand, gesture: cool)
# ✅ Sample 322/500 captured (Right hand, gesture: cool)
# ✅ Sample 323/500 captured (Right hand, gesture: cool)
# ✅ Sample 324/500 captured (Right hand, gesture: cool)
# ✅ Sample 325/500 captured (Right hand, gesture: cool)
# ✅ Sample 326/500 captured (Right hand, gesture: cool)
# ✅ Sample 327/500 captured (Right hand, gesture: cool)
# ✅ Sample 328/500 captured (Right hand, gesture: cool)
# ✅ Sample 329/500 captured (Right hand, gesture: cool)
# ✅ Sample 330/500 captured (Right hand, gesture: cool)
# ✅ Sample 331/500 captured (Right hand, gesture: cool)
# ✅ Sample 332/500 captured (Right hand, gesture: cool)
# ✅ Sample 333/500 captured (Right hand, gesture: cool)
# ✅ Sample 334/500 captured (Right hand, gesture: cool)
# ✅ Sample 335/500 captured (Right hand, gesture: cool)
# ✅ Sample 336/500 captured (Right hand, gesture: cool)
# ✅ Sample 337/500 captured (Right hand, gesture: cool)
# ✅ Sample 338/500 captured (Right hand, gesture: cool)
# ✅ Sample 339/500 captured (Right hand, gesture: cool)
# ✅ Sample 340/500 captured (Right hand, gesture: cool)
# ✅ Sample 341/500 captured (Right hand, gesture: cool)
# ✅ Sample 342/500 captured (Right hand, gesture: cool)
# ✅ Sample 343/500 captured (Right hand, gesture: cool)
# ✅ Sample 344/500 captured (Right hand, gesture: cool)
# ✅ Sample 345/500 captured (Right hand, gesture: cool)
# ✅ Sample 346/500 captured (Right hand, gesture: cool)
# ✅ Sample 347/500 captured (Right hand, gesture: cool)
# ✅ Sample 348/500 captured (Right hand, gesture: cool)
# ✅ Sample 349/500 captured (Right hand, gesture: cool)
# ✅ Sample 350/500 captured (Right hand, gesture: cool)
# ✅ Sample 351/500 captured (Right hand, gesture: cool)
# ✅ Sample 352/500 captured (Right hand, gesture: cool)
# ✅ Sample 353/500 captured (Right hand, gesture: cool)
# ✅ Sample 354/500 captured (Right hand, gesture: cool)
# ✅ Sample 355/500 captured (Right hand, gesture: cool)
# ✅ Sample 356/500 captured (Right hand, gesture: cool)
# ✅ Sample 357/500 captured (Right hand, gesture: cool)
# ✅ Sample 358/500 captured (Right hand, gesture: cool)
# ✅ Sample 359/500 captured (Right hand, gesture: cool)
# ✅ Sample 360/500 captured (Right hand, gesture: cool)
# ✅ Sample 361/500 captured (Right hand, gesture: cool)
# ✅ Sample 362/500 captured (Right hand, gesture: cool)
# ✅ Sample 363/500 captured (Right hand, gesture: cool)
# ✅ Sample 364/500 captured (Right hand, gesture: cool)
# ✅ Sample 365/500 captured (Right hand, gesture: cool)
# ✅ Sample 366/500 captured (Right hand, gesture: cool)
# ✅ Sample 367/500 captured (Right hand, gesture: cool)
# ✅ Sample 368/500 captured (Right hand, gesture: cool)
# ✅ Sample 369/500 captured (Right hand, gesture: cool)
# ✅ Sample 370/500 captured (Right hand, gesture: cool)
# ✅ Sample 371/500 captured (Right hand, gesture: cool)
# ✅ Sample 372/500 captured (Right hand, gesture: cool)
# ✅ Sample 373/500 captured (Right hand, gesture: cool)
# ✅ Sample 374/500 captured (Right hand, gesture: cool)
# ✅ Sample 375/500 captured (Right hand, gesture: cool)
# ✅ Sample 376/500 captured (Right hand, gesture: cool)
# ✅ Sample 377/500 captured (Right hand, gesture: cool)
# ✅ Sample 378/500 captured (Right hand, gesture: cool)
# ✅ Sample 379/500 captured (Right hand, gesture: cool)
# ✅ Sample 380/500 captured (Right hand, gesture: cool)
# ✅ Sample 381/500 captured (Right hand, gesture: cool)
# ✅ Sample 382/500 captured (Right hand, gesture: cool)
# ✅ Sample 383/500 captured (Right hand, gesture: cool)
# ✅ Sample 384/500 captured (Right hand, gesture: cool)
# ✅ Sample 385/500 captured (Right hand, gesture: cool)
# ✅ Sample 386/500 captured (Right hand, gesture: cool)
# ✅ Sample 387/500 captured (Right hand, gesture: cool)
# ✅ Sample 388/500 captured (Right hand, gesture: cool)
# ✅ Sample 389/500 captured (Right hand, gesture: cool)
# ✅ Sample 390/500 captured (Right hand, gesture: cool)
# ✅ Sample 391/500 captured (Right hand, gesture: cool)
# ✅ Sample 392/500 captured (Right hand, gesture: cool)
# ✅ Sample 393/500 captured (Right hand, gesture: cool)
# ✅ Sample 394/500 captured (Right hand, gesture: cool)
# ✅ Sample 395/500 captured (Right hand, gesture: cool)
# ✅ Sample 396/500 captured (Right hand, gesture: cool)
# ✅ Sample 397/500 captured (Right hand, gesture: cool)
# ✅ Sample 398/500 captured (Right hand, gesture: cool)
# ✅ Sample 399/500 captured (Right hand, gesture: cool)
# ✅ Sample 400/500 captured (Right hand, gesture: cool)
# ✅ Sample 401/500 captured (Right hand, gesture: cool)
# ✅ Sample 402/500 captured (Right hand, gesture: cool)
# ✅ Sample 403/500 captured (Right hand, gesture: cool)
# ✅ Sample 404/500 captured (Right hand, gesture: cool)
# ✅ Sample 405/500 captured (Right hand, gesture: cool)
# ✅ Sample 406/500 captured (Right hand, gesture: cool)
# ✅ Sample 407/500 captured (Right hand, gesture: cool)
# ✅ Sample 408/500 captured (Right hand, gesture: cool)
# ✅ Sample 409/500 captured (Right hand, gesture: cool)
# ✅ Sample 410/500 captured (Right hand, gesture: cool)
# ✅ Sample 411/500 captured (Right hand, gesture: cool)
# ✅ Sample 412/500 captured (Right hand, gesture: cool)
# ✅ Sample 413/500 captured (Right hand, gesture: cool)
# ✅ Sample 414/500 captured (Right hand, gesture: cool)
# ✅ Sample 415/500 captured (Right hand, gesture: cool)
# ✅ Sample 416/500 captured (Right hand, gesture: cool)
# ✅ Sample 417/500 captured (Right hand, gesture: cool)
# ✅ Sample 418/500 captured (Right hand, gesture: cool)
# ✅ Sample 419/500 captured (Right hand, gesture: cool)
# ✅ Sample 420/500 captured (Right hand, gesture: cool)
# ✅ Sample 421/500 captured (Right hand, gesture: cool)
# ✅ Sample 422/500 captured (Right hand, gesture: cool)
# ✅ Sample 423/500 captured (Right hand, gesture: cool)
# ✅ Sample 424/500 captured (Right hand, gesture: cool)
# ✅ Sample 425/500 captured (Right hand, gesture: cool)
# ✅ Sample 426/500 captured (Right hand, gesture: cool)
# ✅ Sample 427/500 captured (Right hand, gesture: cool)
# ✅ Sample 428/500 captured (Right hand, gesture: cool)
# ✅ Sample 429/500 captured (Right hand, gesture: cool)
# ✅ Sample 430/500 captured (Right hand, gesture: cool)
# ✅ Sample 431/500 captured (Right hand, gesture: cool)
# ✅ Sample 432/500 captured (Right hand, gesture: cool)
# ✅ Sample 433/500 captured (Right hand, gesture: cool)
# ✅ Sample 434/500 captured (Right hand, gesture: cool)
# ✅ Sample 435/500 captured (Right hand, gesture: cool)
# ✅ Sample 436/500 captured (Right hand, gesture: cool)
# ✅ Sample 437/500 captured (Right hand, gesture: cool)
# ✅ Sample 438/500 captured (Right hand, gesture: cool)
# ✅ Sample 439/500 captured (Right hand, gesture: cool)
# ✅ Sample 440/500 captured (Right hand, gesture: cool)
# ✅ Sample 441/500 captured (Right hand, gesture: cool)
# ✅ Sample 442/500 captured (Right hand, gesture: cool)
# ✅ Sample 443/500 captured (Right hand, gesture: cool)
# ✅ Sample 444/500 captured (Right hand, gesture: cool)
# ✅ Sample 445/500 captured (Right hand, gesture: cool)
# ✅ Sample 446/500 captured (Right hand, gesture: cool)
# ✅ Sample 447/500 captured (Right hand, gesture: cool)
# ✅ Sample 448/500 captured (Right hand, gesture: cool)
# ✅ Sample 449/500 captured (Right hand, gesture: cool)
# ✅ Sample 450/500 captured (Right hand, gesture: cool)
# ✅ Sample 451/500 captured (Right hand, gesture: cool)
# ✅ Sample 452/500 captured (Right hand, gesture: cool)
# ✅ Sample 453/500 captured (Right hand, gesture: cool)
# ✅ Sample 454/500 captured (Right hand, gesture: cool)
# ✅ Sample 455/500 captured (Right hand, gesture: cool)
# ✅ Sample 456/500 captured (Right hand, gesture: cool)
# ✅ Sample 457/500 captured (Right hand, gesture: cool)
# ✅ Sample 458/500 captured (Right hand, gesture: cool)
# ✅ Sample 459/500 captured (Right hand, gesture: cool)
# ✅ Sample 460/500 captured (Right hand, gesture: cool)
# ✅ Sample 461/500 captured (Right hand, gesture: cool)
# ✅ Sample 462/500 captured (Right hand, gesture: cool)
# ✅ Sample 463/500 captured (Right hand, gesture: cool)
# ✅ Sample 464/500 captured (Right hand, gesture: cool)
# ✅ Sample 465/500 captured (Right hand, gesture: cool)
# ✅ Sample 466/500 captured (Right hand, gesture: cool)
# ✅ Sample 467/500 captured (Right hand, gesture: cool)
# ✅ Sample 468/500 captured (Right hand, gesture: cool)
# ✅ Sample 469/500 captured (Right hand, gesture: cool)
# ✅ Sample 470/500 captured (Right hand, gesture: cool)
# ✅ Sample 471/500 captured (Right hand, gesture: cool)
# ✅ Sample 472/500 captured (Right hand, gesture: cool)
# ✅ Sample 473/500 captured (Right hand, gesture: cool)
# ✅ Sample 474/500 captured (Right hand, gesture: cool)
# ✅ Sample 475/500 captured (Right hand, gesture: cool)
# ✅ Sample 476/500 captured (Right hand, gesture: cool)
# ✅ Sample 477/500 captured (Right hand, gesture: cool)
# ✅ Sample 478/500 captured (Right hand, gesture: cool)
# ✅ Sample 479/500 captured (Right hand, gesture: cool)
# ✅ Sample 480/500 captured (Right hand, gesture: cool)
# ✅ Sample 481/500 captured (Right hand, gesture: cool)
# ✅ Sample 482/500 captured (Right hand, gesture: cool)
# ✅ Sample 483/500 captured (Right hand, gesture: cool)
# ✅ Sample 484/500 captured (Right hand, gesture: cool)
# ✅ Sample 485/500 captured (Right hand, gesture: cool)
# ✅ Sample 486/500 captured (Right hand, gesture: cool)
# ✅ Sample 487/500 captured (Right hand, gesture: cool)
# ✅ Sample 488/500 captured (Right hand, gesture: cool)
# ✅ Sample 489/500 captured (Right hand, gesture: cool)
# ✅ Sample 490/500 captured (Right hand, gesture: cool)
# ✅ Sample 491/500 captured (Right hand, gesture: cool)
# ✅ Sample 492/500 captured (Right hand, gesture: cool)
# ✅ Sample 493/500 captured (Right hand, gesture: cool)
# ✅ Sample 494/500 captured (Right hand, gesture: cool)
# ✅ Sample 495/500 captured (Right hand, gesture: cool)
# ✅ Sample 496/500 captured (Right hand, gesture: cool)
# ✅ Sample 497/500 captured (Right hand, gesture: cool)
# ✅ Sample 498/500 captured (Right hand, gesture: cool)
# ✅ Sample 499/500 captured (Right hand, gesture: cool)
# ✅ Sample 500/500 captured (Right hand, gesture: cool)
#
# CSV saved: ../data/raw/upd_cool.csv (2000 total rows)

# %%
gesture_label="don" 
output_csv = '../data/raw/upd_don.csv'

capture_hands_to_csv(
        output_csv=output_csv,
        gesture_label=gesture_label,
        max_samples=500,
        capture_interval=0.2
    )
# Out:
# I0000 00:00:1763286068.125859   64322 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763286068.130189   85054 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-34-generic)
# W0000 00:00:1763286068.152893   85039 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1763286068.167017   85045 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera ready. Capturing every 0.2s. Press 'q' to quit.
# ✅ Sample 1/500 captured (Right hand, gesture: don)
# ✅ Sample 2/500 captured (Right hand, gesture: don)
# ✅ Sample 3/500 captured (Right hand, gesture: don)
# ✅ Sample 4/500 captured (Right hand, gesture: don)
# ✅ Sample 5/500 captured (Right hand, gesture: don)
# ✅ Sample 6/500 captured (Right hand, gesture: don)
# ✅ Sample 7/500 captured (Right hand, gesture: don)
# ✅ Sample 8/500 captured (Right hand, gesture: don)
# ✅ Sample 9/500 captured (Right hand, gesture: don)
# ✅ Sample 10/500 captured (Right hand, gesture: don)
# ✅ Sample 11/500 captured (Right hand, gesture: don)
# ✅ Sample 12/500 captured (Right hand, gesture: don)
# ✅ Sample 13/500 captured (Right hand, gesture: don)
# ✅ Sample 14/500 captured (Right hand, gesture: don)
# ✅ Sample 15/500 captured (Right hand, gesture: don)
# ✅ Sample 16/500 captured (Right hand, gesture: don)
# ✅ Sample 17/500 captured (Right hand, gesture: don)
# ✅ Sample 18/500 captured (Right hand, gesture: don)
# ✅ Sample 19/500 captured (Right hand, gesture: don)
# ✅ Sample 20/500 captured (Right hand, gesture: don)
# ✅ Sample 21/500 captured (Right hand, gesture: don)
# ✅ Sample 22/500 captured (Right hand, gesture: don)
# ✅ Sample 23/500 captured (Right hand, gesture: don)
# ✅ Sample 24/500 captured (Right hand, gesture: don)
# ✅ Sample 25/500 captured (Right hand, gesture: don)
# ✅ Sample 26/500 captured (Right hand, gesture: don)
# ✅ Sample 27/500 captured (Right hand, gesture: don)
# ✅ Sample 28/500 captured (Right hand, gesture: don)
# ✅ Sample 29/500 captured (Right hand, gesture: don)
# ✅ Sample 30/500 captured (Right hand, gesture: don)
# ✅ Sample 31/500 captured (Right hand, gesture: don)
# ✅ Sample 32/500 captured (Right hand, gesture: don)
# ✅ Sample 33/500 captured (Right hand, gesture: don)
# ✅ Sample 34/500 captured (Right hand, gesture: don)
# ✅ Sample 35/500 captured (Right hand, gesture: don)
# ✅ Sample 36/500 captured (Right hand, gesture: don)
# ✅ Sample 37/500 captured (Right hand, gesture: don)
# ✅ Sample 38/500 captured (Right hand, gesture: don)
# ✅ Sample 39/500 captured (Right hand, gesture: don)
# ✅ Sample 40/500 captured (Right hand, gesture: don)
# ✅ Sample 41/500 captured (Right hand, gesture: don)
# ✅ Sample 42/500 captured (Right hand, gesture: don)
# ✅ Sample 43/500 captured (Right hand, gesture: don)
# ✅ Sample 44/500 captured (Right hand, gesture: don)
# ✅ Sample 45/500 captured (Right hand, gesture: don)
# ✅ Sample 46/500 captured (Right hand, gesture: don)
# ✅ Sample 47/500 captured (Right hand, gesture: don)
# ✅ Sample 48/500 captured (Right hand, gesture: don)
# ✅ Sample 49/500 captured (Right hand, gesture: don)
# ✅ Sample 50/500 captured (Right hand, gesture: don)
# ✅ Sample 51/500 captured (Right hand, gesture: don)
# ✅ Sample 52/500 captured (Right hand, gesture: don)
# ✅ Sample 53/500 captured (Right hand, gesture: don)
# ✅ Sample 54/500 captured (Right hand, gesture: don)
# ✅ Sample 55/500 captured (Right hand, gesture: don)
# ✅ Sample 56/500 captured (Right hand, gesture: don)
# ✅ Sample 57/500 captured (Right hand, gesture: don)
# ✅ Sample 58/500 captured (Right hand, gesture: don)
# ✅ Sample 59/500 captured (Right hand, gesture: don)
# ✅ Sample 60/500 captured (Right hand, gesture: don)
# ✅ Sample 61/500 captured (Right hand, gesture: don)
# ✅ Sample 62/500 captured (Right hand, gesture: don)
# ✅ Sample 63/500 captured (Right hand, gesture: don)
# ✅ Sample 64/500 captured (Right hand, gesture: don)
# ✅ Sample 65/500 captured (Right hand, gesture: don)
# ✅ Sample 66/500 captured (Right hand, gesture: don)
# ✅ Sample 67/500 captured (Right hand, gesture: don)
# ✅ Sample 68/500 captured (Right hand, gesture: don)
# ✅ Sample 69/500 captured (Right hand, gesture: don)
# ✅ Sample 70/500 captured (Right hand, gesture: don)
# ✅ Sample 71/500 captured (Right hand, gesture: don)
# ✅ Sample 72/500 captured (Right hand, gesture: don)
# ✅ Sample 73/500 captured (Right hand, gesture: don)
# ✅ Sample 74/500 captured (Right hand, gesture: don)
# ✅ Sample 75/500 captured (Right hand, gesture: don)
# ✅ Sample 76/500 captured (Right hand, gesture: don)
# ✅ Sample 77/500 captured (Right hand, gesture: don)
# ✅ Sample 78/500 captured (Right hand, gesture: don)
# ✅ Sample 79/500 captured (Right hand, gesture: don)
# ✅ Sample 80/500 captured (Right hand, gesture: don)
# ✅ Sample 81/500 captured (Right hand, gesture: don)
# ✅ Sample 82/500 captured (Right hand, gesture: don)
# ✅ Sample 83/500 captured (Right hand, gesture: don)
# ✅ Sample 84/500 captured (Right hand, gesture: don)
# ✅ Sample 85/500 captured (Right hand, gesture: don)
# ✅ Sample 86/500 captured (Right hand, gesture: don)
# ✅ Sample 87/500 captured (Right hand, gesture: don)
# ✅ Sample 88/500 captured (Right hand, gesture: don)
# ✅ Sample 89/500 captured (Right hand, gesture: don)
# ✅ Sample 90/500 captured (Right hand, gesture: don)
# ✅ Sample 91/500 captured (Right hand, gesture: don)
# ✅ Sample 92/500 captured (Right hand, gesture: don)
# ✅ Sample 93/500 captured (Right hand, gesture: don)
# ✅ Sample 94/500 captured (Right hand, gesture: don)
# ✅ Sample 95/500 captured (Right hand, gesture: don)
# ✅ Sample 96/500 captured (Right hand, gesture: don)
# ✅ Sample 97/500 captured (Right hand, gesture: don)
# ✅ Sample 98/500 captured (Right hand, gesture: don)
# ✅ Sample 99/500 captured (Right hand, gesture: don)
# ✅ Sample 100/500 captured (Right hand, gesture: don)
# ✅ Sample 101/500 captured (Right hand, gesture: don)
# ✅ Sample 102/500 captured (Right hand, gesture: don)
# ✅ Sample 103/500 captured (Right hand, gesture: don)
# ✅ Sample 104/500 captured (Right hand, gesture: don)
# ✅ Sample 105/500 captured (Right hand, gesture: don)
# ✅ Sample 106/500 captured (Right hand, gesture: don)
# ✅ Sample 107/500 captured (Right hand, gesture: don)
# ✅ Sample 108/500 captured (Right hand, gesture: don)
# ✅ Sample 109/500 captured (Right hand, gesture: don)
# ✅ Sample 110/500 captured (Right hand, gesture: don)
# ✅ Sample 111/500 captured (Right hand, gesture: don)
# ✅ Sample 112/500 captured (Right hand, gesture: don)
# ✅ Sample 113/500 captured (Right hand, gesture: don)
# ✅ Sample 114/500 captured (Right hand, gesture: don)
# ✅ Sample 115/500 captured (Right hand, gesture: don)
# ✅ Sample 116/500 captured (Right hand, gesture: don)
# ✅ Sample 117/500 captured (Right hand, gesture: don)
# ✅ Sample 118/500 captured (Right hand, gesture: don)
# ✅ Sample 119/500 captured (Right hand, gesture: don)
# ✅ Sample 120/500 captured (Right hand, gesture: don)
# ✅ Sample 121/500 captured (Right hand, gesture: don)
# ✅ Sample 122/500 captured (Right hand, gesture: don)
# ✅ Sample 123/500 captured (Right hand, gesture: don)
# ✅ Sample 124/500 captured (Right hand, gesture: don)
# ✅ Sample 125/500 captured (Right hand, gesture: don)
# ✅ Sample 126/500 captured (Right hand, gesture: don)
# ✅ Sample 127/500 captured (Right hand, gesture: don)
# ✅ Sample 128/500 captured (Right hand, gesture: don)
# ✅ Sample 129/500 captured (Right hand, gesture: don)
# ✅ Sample 130/500 captured (Right hand, gesture: don)
# ✅ Sample 131/500 captured (Right hand, gesture: don)
# ✅ Sample 132/500 captured (Right hand, gesture: don)
# ✅ Sample 133/500 captured (Right hand, gesture: don)
# ✅ Sample 134/500 captured (Right hand, gesture: don)
# ✅ Sample 135/500 captured (Right hand, gesture: don)
# ✅ Sample 136/500 captured (Right hand, gesture: don)
# ✅ Sample 137/500 captured (Right hand, gesture: don)
# ✅ Sample 138/500 captured (Right hand, gesture: don)
# ✅ Sample 139/500 captured (Right hand, gesture: don)
# ✅ Sample 140/500 captured (Right hand, gesture: don)
# ✅ Sample 141/500 captured (Right hand, gesture: don)
# ✅ Sample 142/500 captured (Right hand, gesture: don)
# ✅ Sample 143/500 captured (Right hand, gesture: don)
# ✅ Sample 144/500 captured (Right hand, gesture: don)
# ✅ Sample 145/500 captured (Right hand, gesture: don)
# ✅ Sample 146/500 captured (Right hand, gesture: don)
# ✅ Sample 147/500 captured (Right hand, gesture: don)
# ✅ Sample 148/500 captured (Right hand, gesture: don)
# ✅ Sample 149/500 captured (Right hand, gesture: don)
# ✅ Sample 150/500 captured (Right hand, gesture: don)
# ✅ Sample 151/500 captured (Right hand, gesture: don)
# ✅ Sample 152/500 captured (Right hand, gesture: don)
# ✅ Sample 153/500 captured (Right hand, gesture: don)
# ✅ Sample 154/500 captured (Right hand, gesture: don)
# ✅ Sample 155/500 captured (Right hand, gesture: don)
# ✅ Sample 156/500 captured (Right hand, gesture: don)
# ✅ Sample 157/500 captured (Right hand, gesture: don)
# ✅ Sample 158/500 captured (Right hand, gesture: don)
# ✅ Sample 159/500 captured (Right hand, gesture: don)
# ✅ Sample 160/500 captured (Right hand, gesture: don)
# ✅ Sample 161/500 captured (Right hand, gesture: don)
# ✅ Sample 162/500 captured (Right hand, gesture: don)
# ✅ Sample 163/500 captured (Right hand, gesture: don)
# ✅ Sample 164/500 captured (Right hand, gesture: don)
# ✅ Sample 165/500 captured (Right hand, gesture: don)
# ✅ Sample 166/500 captured (Right hand, gesture: don)
# ✅ Sample 167/500 captured (Right hand, gesture: don)
# ✅ Sample 168/500 captured (Right hand, gesture: don)
# ✅ Sample 169/500 captured (Right hand, gesture: don)
# ✅ Sample 170/500 captured (Right hand, gesture: don)
# ✅ Sample 171/500 captured (Right hand, gesture: don)
# ✅ Sample 172/500 captured (Right hand, gesture: don)
# ✅ Sample 173/500 captured (Right hand, gesture: don)
# ✅ Sample 174/500 captured (Right hand, gesture: don)
# ✅ Sample 175/500 captured (Right hand, gesture: don)
# ✅ Sample 176/500 captured (Right hand, gesture: don)
# ✅ Sample 177/500 captured (Right hand, gesture: don)
# ✅ Sample 178/500 captured (Right hand, gesture: don)
# ✅ Sample 179/500 captured (Right hand, gesture: don)
# ✅ Sample 180/500 captured (Right hand, gesture: don)
# ✅ Sample 181/500 captured (Right hand, gesture: don)
# ✅ Sample 182/500 captured (Right hand, gesture: don)
# ✅ Sample 183/500 captured (Right hand, gesture: don)
# ✅ Sample 184/500 captured (Right hand, gesture: don)
# ✅ Sample 185/500 captured (Right hand, gesture: don)
# ✅ Sample 186/500 captured (Right hand, gesture: don)
# ✅ Sample 187/500 captured (Right hand, gesture: don)
# ✅ Sample 188/500 captured (Right hand, gesture: don)
# ✅ Sample 189/500 captured (Right hand, gesture: don)
# ✅ Sample 190/500 captured (Right hand, gesture: don)
# ✅ Sample 191/500 captured (Right hand, gesture: don)
# ✅ Sample 192/500 captured (Right hand, gesture: don)
# ✅ Sample 193/500 captured (Right hand, gesture: don)
# ✅ Sample 194/500 captured (Right hand, gesture: don)
# ✅ Sample 195/500 captured (Right hand, gesture: don)
# ✅ Sample 196/500 captured (Right hand, gesture: don)
# ✅ Sample 197/500 captured (Right hand, gesture: don)
# ✅ Sample 198/500 captured (Right hand, gesture: don)
# ✅ Sample 199/500 captured (Right hand, gesture: don)
# ✅ Sample 200/500 captured (Right hand, gesture: don)
# ✅ Sample 201/500 captured (Right hand, gesture: don)
# ✅ Sample 202/500 captured (Right hand, gesture: don)
# ✅ Sample 203/500 captured (Right hand, gesture: don)
# ✅ Sample 204/500 captured (Right hand, gesture: don)
# ✅ Sample 205/500 captured (Right hand, gesture: don)
# ✅ Sample 206/500 captured (Right hand, gesture: don)
# ✅ Sample 207/500 captured (Right hand, gesture: don)
# ✅ Sample 208/500 captured (Right hand, gesture: don)
# ✅ Sample 209/500 captured (Right hand, gesture: don)
# ✅ Sample 210/500 captured (Right hand, gesture: don)
# ✅ Sample 211/500 captured (Right hand, gesture: don)
# ✅ Sample 212/500 captured (Right hand, gesture: don)
# ✅ Sample 213/500 captured (Right hand, gesture: don)
# ✅ Sample 214/500 captured (Right hand, gesture: don)
# ✅ Sample 215/500 captured (Right hand, gesture: don)
# ✅ Sample 216/500 captured (Right hand, gesture: don)
# ✅ Sample 217/500 captured (Right hand, gesture: don)
# ✅ Sample 218/500 captured (Right hand, gesture: don)
# ✅ Sample 219/500 captured (Right hand, gesture: don)
# ✅ Sample 220/500 captured (Right hand, gesture: don)
# ✅ Sample 221/500 captured (Right hand, gesture: don)
# ✅ Sample 222/500 captured (Right hand, gesture: don)
# ✅ Sample 223/500 captured (Right hand, gesture: don)
# ✅ Sample 224/500 captured (Right hand, gesture: don)
# ✅ Sample 225/500 captured (Right hand, gesture: don)
# ✅ Sample 226/500 captured (Right hand, gesture: don)
# ✅ Sample 227/500 captured (Right hand, gesture: don)
# ✅ Sample 228/500 captured (Right hand, gesture: don)
# ✅ Sample 229/500 captured (Right hand, gesture: don)
# ✅ Sample 230/500 captured (Right hand, gesture: don)
# ✅ Sample 231/500 captured (Right hand, gesture: don)
# ✅ Sample 232/500 captured (Right hand, gesture: don)
# ✅ Sample 233/500 captured (Right hand, gesture: don)
# ✅ Sample 234/500 captured (Right hand, gesture: don)
# ✅ Sample 235/500 captured (Right hand, gesture: don)
# ✅ Sample 236/500 captured (Right hand, gesture: don)
# ✅ Sample 237/500 captured (Right hand, gesture: don)
# ✅ Sample 238/500 captured (Right hand, gesture: don)
# ✅ Sample 239/500 captured (Right hand, gesture: don)
# ✅ Sample 240/500 captured (Right hand, gesture: don)
# ✅ Sample 241/500 captured (Right hand, gesture: don)
# ✅ Sample 242/500 captured (Right hand, gesture: don)
# ✅ Sample 243/500 captured (Right hand, gesture: don)
# ✅ Sample 244/500 captured (Right hand, gesture: don)
# ✅ Sample 245/500 captured (Right hand, gesture: don)
# ✅ Sample 246/500 captured (Right hand, gesture: don)
# ✅ Sample 247/500 captured (Right hand, gesture: don)
# ✅ Sample 248/500 captured (Right hand, gesture: don)
# ✅ Sample 249/500 captured (Right hand, gesture: don)
# ✅ Sample 250/500 captured (Right hand, gesture: don)
# ✅ Sample 251/500 captured (Right hand, gesture: don)
# ✅ Sample 252/500 captured (Right hand, gesture: don)
# ✅ Sample 253/500 captured (Right hand, gesture: don)
# ✅ Sample 254/500 captured (Right hand, gesture: don)
# ✅ Sample 255/500 captured (Right hand, gesture: don)
# ✅ Sample 256/500 captured (Right hand, gesture: don)
# ✅ Sample 257/500 captured (Right hand, gesture: don)
# ✅ Sample 258/500 captured (Right hand, gesture: don)
# ✅ Sample 259/500 captured (Right hand, gesture: don)
# ✅ Sample 260/500 captured (Right hand, gesture: don)
# ✅ Sample 261/500 captured (Right hand, gesture: don)
# ✅ Sample 262/500 captured (Right hand, gesture: don)
# ✅ Sample 263/500 captured (Right hand, gesture: don)
# ✅ Sample 264/500 captured (Right hand, gesture: don)
# ✅ Sample 265/500 captured (Right hand, gesture: don)
# ✅ Sample 266/500 captured (Right hand, gesture: don)
# ✅ Sample 267/500 captured (Right hand, gesture: don)
# ✅ Sample 268/500 captured (Right hand, gesture: don)
# ✅ Sample 269/500 captured (Right hand, gesture: don)
# ✅ Sample 270/500 captured (Right hand, gesture: don)
# ✅ Sample 271/500 captured (Right hand, gesture: don)
# ✅ Sample 272/500 captured (Right hand, gesture: don)
# ✅ Sample 273/500 captured (Right hand, gesture: don)
# ✅ Sample 274/500 captured (Right hand, gesture: don)
# ✅ Sample 275/500 captured (Right hand, gesture: don)
# ✅ Sample 276/500 captured (Right hand, gesture: don)
# ✅ Sample 277/500 captured (Right hand, gesture: don)
# ✅ Sample 278/500 captured (Right hand, gesture: don)
# ✅ Sample 279/500 captured (Right hand, gesture: don)
# ✅ Sample 280/500 captured (Right hand, gesture: don)
# ✅ Sample 281/500 captured (Right hand, gesture: don)
# ✅ Sample 282/500 captured (Right hand, gesture: don)
# ✅ Sample 283/500 captured (Right hand, gesture: don)
# ✅ Sample 284/500 captured (Right hand, gesture: don)
# ✅ Sample 285/500 captured (Right hand, gesture: don)
# ✅ Sample 286/500 captured (Right hand, gesture: don)
# ✅ Sample 287/500 captured (Right hand, gesture: don)
# ✅ Sample 288/500 captured (Right hand, gesture: don)
# ✅ Sample 289/500 captured (Right hand, gesture: don)
# ✅ Sample 290/500 captured (Right hand, gesture: don)
# ✅ Sample 291/500 captured (Right hand, gesture: don)
# ✅ Sample 292/500 captured (Right hand, gesture: don)
# ✅ Sample 293/500 captured (Right hand, gesture: don)
# ✅ Sample 294/500 captured (Right hand, gesture: don)
# ✅ Sample 295/500 captured (Right hand, gesture: don)
# ✅ Sample 296/500 captured (Right hand, gesture: don)
# ✅ Sample 297/500 captured (Right hand, gesture: don)
# ✅ Sample 298/500 captured (Right hand, gesture: don)
# ✅ Sample 299/500 captured (Right hand, gesture: don)
# ✅ Sample 300/500 captured (Right hand, gesture: don)
# ✅ Sample 301/500 captured (Right hand, gesture: don)
# ✅ Sample 302/500 captured (Right hand, gesture: don)
# ✅ Sample 303/500 captured (Right hand, gesture: don)
# ✅ Sample 304/500 captured (Right hand, gesture: don)
# ✅ Sample 305/500 captured (Right hand, gesture: don)
# ✅ Sample 306/500 captured (Right hand, gesture: don)
# ✅ Sample 307/500 captured (Right hand, gesture: don)
# ✅ Sample 308/500 captured (Right hand, gesture: don)
# ✅ Sample 309/500 captured (Right hand, gesture: don)
# ✅ Sample 310/500 captured (Right hand, gesture: don)
# ✅ Sample 311/500 captured (Right hand, gesture: don)
# ✅ Sample 312/500 captured (Right hand, gesture: don)
# ✅ Sample 313/500 captured (Right hand, gesture: don)
# ✅ Sample 314/500 captured (Right hand, gesture: don)
# ✅ Sample 315/500 captured (Right hand, gesture: don)
# ✅ Sample 316/500 captured (Right hand, gesture: don)
# ✅ Sample 317/500 captured (Right hand, gesture: don)
# ✅ Sample 318/500 captured (Right hand, gesture: don)
# ✅ Sample 319/500 captured (Right hand, gesture: don)
# ✅ Sample 320/500 captured (Right hand, gesture: don)
# ✅ Sample 321/500 captured (Right hand, gesture: don)
# ✅ Sample 322/500 captured (Right hand, gesture: don)
# ✅ Sample 323/500 captured (Right hand, gesture: don)
# ✅ Sample 324/500 captured (Right hand, gesture: don)
# ✅ Sample 325/500 captured (Right hand, gesture: don)
# ✅ Sample 326/500 captured (Right hand, gesture: don)
# ✅ Sample 327/500 captured (Right hand, gesture: don)
# ✅ Sample 328/500 captured (Right hand, gesture: don)
# ✅ Sample 329/500 captured (Right hand, gesture: don)
# ✅ Sample 330/500 captured (Right hand, gesture: don)
# ✅ Sample 331/500 captured (Right hand, gesture: don)
# ✅ Sample 332/500 captured (Right hand, gesture: don)
# ✅ Sample 333/500 captured (Right hand, gesture: don)
# ✅ Sample 334/500 captured (Right hand, gesture: don)
# ✅ Sample 335/500 captured (Right hand, gesture: don)
# ✅ Sample 336/500 captured (Right hand, gesture: don)
# ✅ Sample 337/500 captured (Right hand, gesture: don)
# ✅ Sample 338/500 captured (Right hand, gesture: don)
# ✅ Sample 339/500 captured (Right hand, gesture: don)
# ✅ Sample 340/500 captured (Right hand, gesture: don)
# ✅ Sample 341/500 captured (Right hand, gesture: don)
# ✅ Sample 342/500 captured (Right hand, gesture: don)
# ✅ Sample 343/500 captured (Right hand, gesture: don)
# ✅ Sample 344/500 captured (Right hand, gesture: don)
# ✅ Sample 345/500 captured (Right hand, gesture: don)
# ✅ Sample 346/500 captured (Right hand, gesture: don)
# ✅ Sample 347/500 captured (Right hand, gesture: don)
# ✅ Sample 348/500 captured (Right hand, gesture: don)
# ✅ Sample 349/500 captured (Right hand, gesture: don)
# ✅ Sample 350/500 captured (Right hand, gesture: don)
# ✅ Sample 351/500 captured (Right hand, gesture: don)
# ✅ Sample 352/500 captured (Right hand, gesture: don)
# ✅ Sample 353/500 captured (Right hand, gesture: don)
# ✅ Sample 354/500 captured (Right hand, gesture: don)
# ✅ Sample 355/500 captured (Right hand, gesture: don)
# ✅ Sample 356/500 captured (Right hand, gesture: don)
# ✅ Sample 357/500 captured (Right hand, gesture: don)
# ✅ Sample 358/500 captured (Right hand, gesture: don)
# ✅ Sample 359/500 captured (Right hand, gesture: don)
# ✅ Sample 360/500 captured (Right hand, gesture: don)
# ✅ Sample 361/500 captured (Right hand, gesture: don)
# ✅ Sample 362/500 captured (Right hand, gesture: don)
# ✅ Sample 363/500 captured (Right hand, gesture: don)
# ✅ Sample 364/500 captured (Right hand, gesture: don)
# ✅ Sample 365/500 captured (Right hand, gesture: don)
# ✅ Sample 366/500 captured (Right hand, gesture: don)
# ✅ Sample 367/500 captured (Right hand, gesture: don)
# ✅ Sample 368/500 captured (Right hand, gesture: don)
# ✅ Sample 369/500 captured (Right hand, gesture: don)
# ✅ Sample 370/500 captured (Right hand, gesture: don)
# ✅ Sample 371/500 captured (Right hand, gesture: don)
# ✅ Sample 372/500 captured (Right hand, gesture: don)
# ✅ Sample 373/500 captured (Right hand, gesture: don)
# ✅ Sample 374/500 captured (Right hand, gesture: don)
# ✅ Sample 375/500 captured (Right hand, gesture: don)
# ✅ Sample 376/500 captured (Right hand, gesture: don)
# ✅ Sample 377/500 captured (Right hand, gesture: don)
# ✅ Sample 378/500 captured (Right hand, gesture: don)
# ✅ Sample 379/500 captured (Right hand, gesture: don)
# ✅ Sample 380/500 captured (Right hand, gesture: don)
# ✅ Sample 381/500 captured (Right hand, gesture: don)
# ✅ Sample 382/500 captured (Right hand, gesture: don)
# ✅ Sample 383/500 captured (Right hand, gesture: don)
# ✅ Sample 384/500 captured (Right hand, gesture: don)
# ✅ Sample 385/500 captured (Right hand, gesture: don)
# ✅ Sample 386/500 captured (Right hand, gesture: don)
# ✅ Sample 387/500 captured (Right hand, gesture: don)
# ✅ Sample 388/500 captured (Right hand, gesture: don)
# ✅ Sample 389/500 captured (Right hand, gesture: don)
# ✅ Sample 390/500 captured (Right hand, gesture: don)
# ✅ Sample 391/500 captured (Right hand, gesture: don)
# ✅ Sample 392/500 captured (Right hand, gesture: don)
# ✅ Sample 393/500 captured (Right hand, gesture: don)
# ✅ Sample 394/500 captured (Right hand, gesture: don)
# ✅ Sample 395/500 captured (Right hand, gesture: don)
# ✅ Sample 396/500 captured (Right hand, gesture: don)
# ✅ Sample 397/500 captured (Right hand, gesture: don)
# ✅ Sample 398/500 captured (Right hand, gesture: don)
# ✅ Sample 399/500 captured (Right hand, gesture: don)
# ✅ Sample 400/500 captured (Right hand, gesture: don)
# ✅ Sample 401/500 captured (Right hand, gesture: don)
# ✅ Sample 402/500 captured (Right hand, gesture: don)
# ✅ Sample 403/500 captured (Right hand, gesture: don)
# ✅ Sample 404/500 captured (Right hand, gesture: don)
# ✅ Sample 405/500 captured (Right hand, gesture: don)
# ✅ Sample 406/500 captured (Right hand, gesture: don)
# ✅ Sample 407/500 captured (Right hand, gesture: don)
# ✅ Sample 408/500 captured (Right hand, gesture: don)
# ✅ Sample 409/500 captured (Right hand, gesture: don)
# ✅ Sample 410/500 captured (Right hand, gesture: don)
# ✅ Sample 411/500 captured (Right hand, gesture: don)
# ✅ Sample 412/500 captured (Right hand, gesture: don)
# ✅ Sample 413/500 captured (Right hand, gesture: don)
# ✅ Sample 414/500 captured (Right hand, gesture: don)
# ✅ Sample 415/500 captured (Right hand, gesture: don)
# ✅ Sample 416/500 captured (Right hand, gesture: don)
# ✅ Sample 417/500 captured (Right hand, gesture: don)
# ✅ Sample 418/500 captured (Right hand, gesture: don)
# ✅ Sample 419/500 captured (Right hand, gesture: don)
# ✅ Sample 420/500 captured (Right hand, gesture: don)
# ✅ Sample 421/500 captured (Right hand, gesture: don)
# ✅ Sample 422/500 captured (Right hand, gesture: don)
# ✅ Sample 423/500 captured (Right hand, gesture: don)
# ✅ Sample 424/500 captured (Right hand, gesture: don)
# ✅ Sample 425/500 captured (Right hand, gesture: don)
# ✅ Sample 426/500 captured (Right hand, gesture: don)
# ✅ Sample 427/500 captured (Right hand, gesture: don)
# ✅ Sample 428/500 captured (Right hand, gesture: don)
# ✅ Sample 429/500 captured (Right hand, gesture: don)
# ✅ Sample 430/500 captured (Right hand, gesture: don)
# ✅ Sample 431/500 captured (Right hand, gesture: don)
# ✅ Sample 432/500 captured (Right hand, gesture: don)
# ✅ Sample 433/500 captured (Right hand, gesture: don)
# ✅ Sample 434/500 captured (Right hand, gesture: don)
# ✅ Sample 435/500 captured (Right hand, gesture: don)
# ✅ Sample 436/500 captured (Right hand, gesture: don)
# ✅ Sample 437/500 captured (Right hand, gesture: don)
# ✅ Sample 438/500 captured (Right hand, gesture: don)
# ✅ Sample 439/500 captured (Right hand, gesture: don)
# ✅ Sample 440/500 captured (Right hand, gesture: don)
# ✅ Sample 441/500 captured (Right hand, gesture: don)
# ✅ Sample 442/500 captured (Right hand, gesture: don)
# ✅ Sample 443/500 captured (Right hand, gesture: don)
# ✅ Sample 444/500 captured (Right hand, gesture: don)
# ✅ Sample 445/500 captured (Right hand, gesture: don)
# ✅ Sample 446/500 captured (Right hand, gesture: don)
# ✅ Sample 447/500 captured (Right hand, gesture: don)
# ✅ Sample 448/500 captured (Right hand, gesture: don)
# ✅ Sample 449/500 captured (Right hand, gesture: don)
# ✅ Sample 450/500 captured (Right hand, gesture: don)
# ✅ Sample 451/500 captured (Right hand, gesture: don)
# ✅ Sample 452/500 captured (Right hand, gesture: don)
# ✅ Sample 453/500 captured (Right hand, gesture: don)
# ✅ Sample 454/500 captured (Right hand, gesture: don)
# ✅ Sample 455/500 captured (Right hand, gesture: don)
# ✅ Sample 456/500 captured (Right hand, gesture: don)
# ✅ Sample 457/500 captured (Right hand, gesture: don)
# ✅ Sample 458/500 captured (Right hand, gesture: don)
# ✅ Sample 459/500 captured (Right hand, gesture: don)
# ✅ Sample 460/500 captured (Right hand, gesture: don)
# ✅ Sample 461/500 captured (Right hand, gesture: don)
# ✅ Sample 462/500 captured (Right hand, gesture: don)
# ✅ Sample 463/500 captured (Right hand, gesture: don)
# ✅ Sample 464/500 captured (Right hand, gesture: don)
# ✅ Sample 465/500 captured (Right hand, gesture: don)
# ✅ Sample 466/500 captured (Right hand, gesture: don)
# ✅ Sample 467/500 captured (Right hand, gesture: don)
# ✅ Sample 468/500 captured (Right hand, gesture: don)
# ✅ Sample 469/500 captured (Right hand, gesture: don)
# ✅ Sample 470/500 captured (Right hand, gesture: don)
# ✅ Sample 471/500 captured (Right hand, gesture: don)
# ✅ Sample 472/500 captured (Right hand, gesture: don)
# ✅ Sample 473/500 captured (Right hand, gesture: don)
# ✅ Sample 474/500 captured (Right hand, gesture: don)
# ✅ Sample 475/500 captured (Right hand, gesture: don)
# ✅ Sample 476/500 captured (Right hand, gesture: don)
# ✅ Sample 477/500 captured (Right hand, gesture: don)
# ✅ Sample 478/500 captured (Right hand, gesture: don)
# ✅ Sample 479/500 captured (Right hand, gesture: don)
# ✅ Sample 480/500 captured (Right hand, gesture: don)
# ✅ Sample 481/500 captured (Right hand, gesture: don)
# ✅ Sample 482/500 captured (Right hand, gesture: don)
# ✅ Sample 483/500 captured (Right hand, gesture: don)
# ✅ Sample 484/500 captured (Right hand, gesture: don)
# ✅ Sample 485/500 captured (Right hand, gesture: don)
# ✅ Sample 486/500 captured (Right hand, gesture: don)
# ✅ Sample 487/500 captured (Right hand, gesture: don)
# ✅ Sample 488/500 captured (Right hand, gesture: don)
# ✅ Sample 489/500 captured (Right hand, gesture: don)
# ✅ Sample 490/500 captured (Right hand, gesture: don)
# ✅ Sample 491/500 captured (Right hand, gesture: don)
# ✅ Sample 492/500 captured (Right hand, gesture: don)
# ✅ Sample 493/500 captured (Right hand, gesture: don)
# ✅ Sample 494/500 captured (Right hand, gesture: don)
# ✅ Sample 495/500 captured (Right hand, gesture: don)
# ✅ Sample 496/500 captured (Right hand, gesture: don)
# ✅ Sample 497/500 captured (Right hand, gesture: don)
# ✅ Sample 498/500 captured (Right hand, gesture: don)
# ✅ Sample 499/500 captured (Right hand, gesture: don)
# ✅ Sample 500/500 captured (Right hand, gesture: don)
#
# CSV saved: ../data/raw/upd_don.csv (2000 total rows)

# %%
gesture_label="mafia" 
output_csv = '../data/raw/upd_mafia.csv'

capture_hands_to_csv(
        output_csv=output_csv,
        gesture_label=gesture_label,
        max_samples=500,
        capture_interval=0.1
    )
# Out:
# I0000 00:00:1763286362.078567   64322 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763286362.082587   85222 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-34-generic)
# W0000 00:00:1763286362.104045   85204 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1763286362.121640   85203 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera ready. Capturing every 0.1s. Press 'q' to quit.
# ✅ Sample 1/500 captured (Right hand, gesture: mafia)
# ✅ Sample 2/500 captured (Right hand, gesture: mafia)
# ✅ Sample 3/500 captured (Right hand, gesture: mafia)
# ✅ Sample 4/500 captured (Right hand, gesture: mafia)
# ✅ Sample 5/500 captured (Right hand, gesture: mafia)
# ✅ Sample 6/500 captured (Right hand, gesture: mafia)
# ✅ Sample 7/500 captured (Right hand, gesture: mafia)
# ✅ Sample 8/500 captured (Right hand, gesture: mafia)
# ✅ Sample 9/500 captured (Right hand, gesture: mafia)
# ✅ Sample 10/500 captured (Right hand, gesture: mafia)
# ✅ Sample 11/500 captured (Right hand, gesture: mafia)
# ✅ Sample 12/500 captured (Right hand, gesture: mafia)
# ✅ Sample 13/500 captured (Right hand, gesture: mafia)
# ✅ Sample 14/500 captured (Right hand, gesture: mafia)
# ✅ Sample 15/500 captured (Right hand, gesture: mafia)
# ✅ Sample 16/500 captured (Right hand, gesture: mafia)
# ✅ Sample 17/500 captured (Right hand, gesture: mafia)
# ✅ Sample 18/500 captured (Right hand, gesture: mafia)
# ✅ Sample 19/500 captured (Right hand, gesture: mafia)
# ✅ Sample 20/500 captured (Right hand, gesture: mafia)
# ✅ Sample 21/500 captured (Right hand, gesture: mafia)
# ✅ Sample 22/500 captured (Right hand, gesture: mafia)
# ✅ Sample 23/500 captured (Right hand, gesture: mafia)
# ✅ Sample 24/500 captured (Right hand, gesture: mafia)
# ✅ Sample 25/500 captured (Right hand, gesture: mafia)
# ✅ Sample 26/500 captured (Right hand, gesture: mafia)
# ✅ Sample 27/500 captured (Right hand, gesture: mafia)
# ✅ Sample 28/500 captured (Right hand, gesture: mafia)
# ✅ Sample 29/500 captured (Right hand, gesture: mafia)
# ✅ Sample 30/500 captured (Right hand, gesture: mafia)
# ✅ Sample 31/500 captured (Right hand, gesture: mafia)
# ✅ Sample 32/500 captured (Right hand, gesture: mafia)
# ✅ Sample 33/500 captured (Right hand, gesture: mafia)
# ✅ Sample 34/500 captured (Right hand, gesture: mafia)
# ✅ Sample 35/500 captured (Right hand, gesture: mafia)
# ✅ Sample 36/500 captured (Right hand, gesture: mafia)
# ✅ Sample 37/500 captured (Right hand, gesture: mafia)
# ✅ Sample 38/500 captured (Right hand, gesture: mafia)
# ✅ Sample 39/500 captured (Right hand, gesture: mafia)
# ✅ Sample 40/500 captured (Right hand, gesture: mafia)
# ✅ Sample 41/500 captured (Right hand, gesture: mafia)
# ✅ Sample 42/500 captured (Right hand, gesture: mafia)
# ✅ Sample 43/500 captured (Right hand, gesture: mafia)
# ✅ Sample 44/500 captured (Right hand, gesture: mafia)
# ✅ Sample 45/500 captured (Right hand, gesture: mafia)
# ✅ Sample 46/500 captured (Right hand, gesture: mafia)
# ✅ Sample 47/500 captured (Right hand, gesture: mafia)
# ✅ Sample 48/500 captured (Right hand, gesture: mafia)
# ✅ Sample 49/500 captured (Right hand, gesture: mafia)
# ✅ Sample 50/500 captured (Right hand, gesture: mafia)
# ✅ Sample 51/500 captured (Right hand, gesture: mafia)
# ✅ Sample 52/500 captured (Right hand, gesture: mafia)
# ✅ Sample 53/500 captured (Right hand, gesture: mafia)
# ✅ Sample 54/500 captured (Right hand, gesture: mafia)
# ✅ Sample 55/500 captured (Right hand, gesture: mafia)
# ✅ Sample 56/500 captured (Right hand, gesture: mafia)
# ✅ Sample 57/500 captured (Right hand, gesture: mafia)
# ✅ Sample 58/500 captured (Right hand, gesture: mafia)
# ✅ Sample 59/500 captured (Right hand, gesture: mafia)
# ✅ Sample 60/500 captured (Right hand, gesture: mafia)
# ✅ Sample 61/500 captured (Right hand, gesture: mafia)
# ✅ Sample 62/500 captured (Right hand, gesture: mafia)
# ✅ Sample 63/500 captured (Right hand, gesture: mafia)
# ✅ Sample 64/500 captured (Right hand, gesture: mafia)
# ✅ Sample 65/500 captured (Right hand, gesture: mafia)
# ✅ Sample 66/500 captured (Right hand, gesture: mafia)
# ✅ Sample 67/500 captured (Right hand, gesture: mafia)
# ✅ Sample 68/500 captured (Right hand, gesture: mafia)
# ✅ Sample 69/500 captured (Right hand, gesture: mafia)
# ✅ Sample 70/500 captured (Right hand, gesture: mafia)
# ✅ Sample 71/500 captured (Right hand, gesture: mafia)
# ✅ Sample 72/500 captured (Right hand, gesture: mafia)
# ✅ Sample 73/500 captured (Right hand, gesture: mafia)
# ✅ Sample 74/500 captured (Right hand, gesture: mafia)
# ✅ Sample 75/500 captured (Right hand, gesture: mafia)
# ✅ Sample 76/500 captured (Right hand, gesture: mafia)
# ✅ Sample 77/500 captured (Right hand, gesture: mafia)
# ✅ Sample 78/500 captured (Right hand, gesture: mafia)
# ✅ Sample 79/500 captured (Right hand, gesture: mafia)
# ✅ Sample 80/500 captured (Right hand, gesture: mafia)
# ✅ Sample 81/500 captured (Right hand, gesture: mafia)
# ✅ Sample 82/500 captured (Right hand, gesture: mafia)
# ✅ Sample 83/500 captured (Right hand, gesture: mafia)
# ✅ Sample 84/500 captured (Right hand, gesture: mafia)
# ✅ Sample 85/500 captured (Right hand, gesture: mafia)
# ✅ Sample 86/500 captured (Right hand, gesture: mafia)
# ✅ Sample 87/500 captured (Right hand, gesture: mafia)
# ✅ Sample 88/500 captured (Right hand, gesture: mafia)
# ✅ Sample 89/500 captured (Right hand, gesture: mafia)
# ✅ Sample 90/500 captured (Right hand, gesture: mafia)
# ✅ Sample 91/500 captured (Right hand, gesture: mafia)
# ✅ Sample 92/500 captured (Right hand, gesture: mafia)
# ✅ Sample 93/500 captured (Right hand, gesture: mafia)
# ✅ Sample 94/500 captured (Right hand, gesture: mafia)
# ✅ Sample 95/500 captured (Right hand, gesture: mafia)
# ✅ Sample 96/500 captured (Right hand, gesture: mafia)
# ✅ Sample 97/500 captured (Right hand, gesture: mafia)
# ✅ Sample 98/500 captured (Right hand, gesture: mafia)
# ✅ Sample 99/500 captured (Right hand, gesture: mafia)
# ✅ Sample 100/500 captured (Right hand, gesture: mafia)
# ✅ Sample 101/500 captured (Right hand, gesture: mafia)
# ✅ Sample 102/500 captured (Right hand, gesture: mafia)
# ✅ Sample 103/500 captured (Right hand, gesture: mafia)
# ✅ Sample 104/500 captured (Right hand, gesture: mafia)
# ✅ Sample 105/500 captured (Right hand, gesture: mafia)
# ✅ Sample 106/500 captured (Right hand, gesture: mafia)
# ✅ Sample 107/500 captured (Right hand, gesture: mafia)
# ✅ Sample 108/500 captured (Right hand, gesture: mafia)
# ✅ Sample 109/500 captured (Right hand, gesture: mafia)
# ✅ Sample 110/500 captured (Right hand, gesture: mafia)
# ✅ Sample 111/500 captured (Right hand, gesture: mafia)
# ✅ Sample 112/500 captured (Right hand, gesture: mafia)
# ✅ Sample 113/500 captured (Right hand, gesture: mafia)
# ✅ Sample 114/500 captured (Right hand, gesture: mafia)
# ✅ Sample 115/500 captured (Right hand, gesture: mafia)
# ✅ Sample 116/500 captured (Right hand, gesture: mafia)
# ✅ Sample 117/500 captured (Right hand, gesture: mafia)
# ✅ Sample 118/500 captured (Right hand, gesture: mafia)
# ✅ Sample 119/500 captured (Right hand, gesture: mafia)
# ✅ Sample 120/500 captured (Right hand, gesture: mafia)
# ✅ Sample 121/500 captured (Right hand, gesture: mafia)
# ✅ Sample 122/500 captured (Right hand, gesture: mafia)
# ✅ Sample 123/500 captured (Right hand, gesture: mafia)
# ✅ Sample 124/500 captured (Right hand, gesture: mafia)
# ✅ Sample 125/500 captured (Right hand, gesture: mafia)
# ✅ Sample 126/500 captured (Right hand, gesture: mafia)
# ✅ Sample 127/500 captured (Right hand, gesture: mafia)
# ✅ Sample 128/500 captured (Right hand, gesture: mafia)
# ✅ Sample 129/500 captured (Right hand, gesture: mafia)
# ✅ Sample 130/500 captured (Right hand, gesture: mafia)
# ✅ Sample 131/500 captured (Right hand, gesture: mafia)
# ✅ Sample 132/500 captured (Right hand, gesture: mafia)
# ✅ Sample 133/500 captured (Right hand, gesture: mafia)
# ✅ Sample 134/500 captured (Right hand, gesture: mafia)
# ✅ Sample 135/500 captured (Right hand, gesture: mafia)
# ✅ Sample 136/500 captured (Right hand, gesture: mafia)
# ✅ Sample 137/500 captured (Right hand, gesture: mafia)
# ✅ Sample 138/500 captured (Right hand, gesture: mafia)
# ✅ Sample 139/500 captured (Right hand, gesture: mafia)
# ✅ Sample 140/500 captured (Right hand, gesture: mafia)
# ✅ Sample 141/500 captured (Right hand, gesture: mafia)
# ✅ Sample 142/500 captured (Right hand, gesture: mafia)
# ✅ Sample 143/500 captured (Right hand, gesture: mafia)
# ✅ Sample 144/500 captured (Right hand, gesture: mafia)
# ✅ Sample 145/500 captured (Right hand, gesture: mafia)
# ✅ Sample 146/500 captured (Right hand, gesture: mafia)
# ✅ Sample 147/500 captured (Right hand, gesture: mafia)
# ✅ Sample 148/500 captured (Right hand, gesture: mafia)
# ✅ Sample 149/500 captured (Right hand, gesture: mafia)
# ✅ Sample 150/500 captured (Right hand, gesture: mafia)
# ✅ Sample 151/500 captured (Right hand, gesture: mafia)
# ✅ Sample 152/500 captured (Right hand, gesture: mafia)
# ✅ Sample 153/500 captured (Right hand, gesture: mafia)
# ✅ Sample 154/500 captured (Right hand, gesture: mafia)
# ✅ Sample 155/500 captured (Right hand, gesture: mafia)
# ✅ Sample 156/500 captured (Right hand, gesture: mafia)
# ✅ Sample 157/500 captured (Right hand, gesture: mafia)
# ✅ Sample 158/500 captured (Right hand, gesture: mafia)
# ✅ Sample 159/500 captured (Right hand, gesture: mafia)
# ✅ Sample 160/500 captured (Right hand, gesture: mafia)
# ✅ Sample 161/500 captured (Right hand, gesture: mafia)
# ✅ Sample 162/500 captured (Right hand, gesture: mafia)
# ✅ Sample 163/500 captured (Right hand, gesture: mafia)
# ✅ Sample 164/500 captured (Right hand, gesture: mafia)
# ✅ Sample 165/500 captured (Right hand, gesture: mafia)
# ✅ Sample 166/500 captured (Right hand, gesture: mafia)
# ✅ Sample 167/500 captured (Right hand, gesture: mafia)
# ✅ Sample 168/500 captured (Right hand, gesture: mafia)
# ✅ Sample 169/500 captured (Right hand, gesture: mafia)
# ✅ Sample 170/500 captured (Right hand, gesture: mafia)
# ✅ Sample 171/500 captured (Right hand, gesture: mafia)
# ✅ Sample 172/500 captured (Right hand, gesture: mafia)
# ✅ Sample 173/500 captured (Right hand, gesture: mafia)
# ✅ Sample 174/500 captured (Right hand, gesture: mafia)
# ✅ Sample 175/500 captured (Right hand, gesture: mafia)
# ✅ Sample 176/500 captured (Right hand, gesture: mafia)
# ✅ Sample 177/500 captured (Right hand, gesture: mafia)
# ✅ Sample 178/500 captured (Right hand, gesture: mafia)
# ✅ Sample 179/500 captured (Right hand, gesture: mafia)
# ✅ Sample 180/500 captured (Right hand, gesture: mafia)
# ✅ Sample 181/500 captured (Right hand, gesture: mafia)
# ✅ Sample 182/500 captured (Right hand, gesture: mafia)
# ✅ Sample 183/500 captured (Right hand, gesture: mafia)
# ✅ Sample 184/500 captured (Right hand, gesture: mafia)
# ✅ Sample 185/500 captured (Right hand, gesture: mafia)
# ✅ Sample 186/500 captured (Right hand, gesture: mafia)
# ✅ Sample 187/500 captured (Right hand, gesture: mafia)
# ✅ Sample 188/500 captured (Right hand, gesture: mafia)
# ✅ Sample 189/500 captured (Right hand, gesture: mafia)
# ✅ Sample 190/500 captured (Right hand, gesture: mafia)
# ✅ Sample 191/500 captured (Right hand, gesture: mafia)
# ✅ Sample 192/500 captured (Right hand, gesture: mafia)
# ✅ Sample 193/500 captured (Right hand, gesture: mafia)
# ✅ Sample 194/500 captured (Right hand, gesture: mafia)
# ✅ Sample 195/500 captured (Right hand, gesture: mafia)
# ✅ Sample 196/500 captured (Right hand, gesture: mafia)
# ✅ Sample 197/500 captured (Right hand, gesture: mafia)
# ✅ Sample 198/500 captured (Right hand, gesture: mafia)
# ✅ Sample 199/500 captured (Right hand, gesture: mafia)
# ✅ Sample 200/500 captured (Right hand, gesture: mafia)
# ✅ Sample 201/500 captured (Right hand, gesture: mafia)
# ✅ Sample 202/500 captured (Right hand, gesture: mafia)
# ✅ Sample 203/500 captured (Right hand, gesture: mafia)
# ✅ Sample 204/500 captured (Right hand, gesture: mafia)
# ✅ Sample 205/500 captured (Right hand, gesture: mafia)
# ✅ Sample 206/500 captured (Right hand, gesture: mafia)
# ✅ Sample 207/500 captured (Right hand, gesture: mafia)
# ✅ Sample 208/500 captured (Right hand, gesture: mafia)
# ✅ Sample 209/500 captured (Right hand, gesture: mafia)
# ✅ Sample 210/500 captured (Right hand, gesture: mafia)
# ✅ Sample 211/500 captured (Right hand, gesture: mafia)
# ✅ Sample 212/500 captured (Right hand, gesture: mafia)
# ✅ Sample 213/500 captured (Right hand, gesture: mafia)
# ✅ Sample 214/500 captured (Right hand, gesture: mafia)
# ✅ Sample 215/500 captured (Right hand, gesture: mafia)
# ✅ Sample 216/500 captured (Right hand, gesture: mafia)
# ✅ Sample 217/500 captured (Right hand, gesture: mafia)
# ✅ Sample 218/500 captured (Right hand, gesture: mafia)
# ✅ Sample 219/500 captured (Right hand, gesture: mafia)
# ✅ Sample 220/500 captured (Right hand, gesture: mafia)
# ✅ Sample 221/500 captured (Right hand, gesture: mafia)
# ✅ Sample 222/500 captured (Right hand, gesture: mafia)
# ✅ Sample 223/500 captured (Right hand, gesture: mafia)
# ✅ Sample 224/500 captured (Right hand, gesture: mafia)
# ✅ Sample 225/500 captured (Right hand, gesture: mafia)
# ✅ Sample 226/500 captured (Right hand, gesture: mafia)
# ✅ Sample 227/500 captured (Right hand, gesture: mafia)
# ✅ Sample 228/500 captured (Right hand, gesture: mafia)
# ✅ Sample 229/500 captured (Right hand, gesture: mafia)
# ✅ Sample 230/500 captured (Right hand, gesture: mafia)
# ✅ Sample 231/500 captured (Right hand, gesture: mafia)
# ✅ Sample 232/500 captured (Right hand, gesture: mafia)
# ✅ Sample 233/500 captured (Right hand, gesture: mafia)
# ✅ Sample 234/500 captured (Right hand, gesture: mafia)
# ✅ Sample 235/500 captured (Right hand, gesture: mafia)
# ✅ Sample 236/500 captured (Right hand, gesture: mafia)
# ✅ Sample 237/500 captured (Right hand, gesture: mafia)
# ✅ Sample 238/500 captured (Right hand, gesture: mafia)
# ✅ Sample 239/500 captured (Right hand, gesture: mafia)
# ✅ Sample 240/500 captured (Right hand, gesture: mafia)
# ✅ Sample 241/500 captured (Right hand, gesture: mafia)
# ✅ Sample 242/500 captured (Right hand, gesture: mafia)
# ✅ Sample 243/500 captured (Right hand, gesture: mafia)
# ✅ Sample 244/500 captured (Right hand, gesture: mafia)
# ✅ Sample 245/500 captured (Right hand, gesture: mafia)
# ✅ Sample 246/500 captured (Right hand, gesture: mafia)
# ✅ Sample 247/500 captured (Right hand, gesture: mafia)
# ✅ Sample 248/500 captured (Right hand, gesture: mafia)
# ✅ Sample 249/500 captured (Right hand, gesture: mafia)
# ✅ Sample 250/500 captured (Right hand, gesture: mafia)
# ✅ Sample 251/500 captured (Right hand, gesture: mafia)
# ✅ Sample 252/500 captured (Right hand, gesture: mafia)
# ✅ Sample 253/500 captured (Right hand, gesture: mafia)
# ✅ Sample 254/500 captured (Right hand, gesture: mafia)
# ✅ Sample 255/500 captured (Right hand, gesture: mafia)
# ✅ Sample 256/500 captured (Right hand, gesture: mafia)
# ✅ Sample 257/500 captured (Right hand, gesture: mafia)
# ✅ Sample 258/500 captured (Right hand, gesture: mafia)
# ✅ Sample 259/500 captured (Right hand, gesture: mafia)
# ✅ Sample 260/500 captured (Right hand, gesture: mafia)
# ✅ Sample 261/500 captured (Right hand, gesture: mafia)
# ✅ Sample 262/500 captured (Right hand, gesture: mafia)
# ✅ Sample 263/500 captured (Right hand, gesture: mafia)
# ✅ Sample 264/500 captured (Right hand, gesture: mafia)
# ✅ Sample 265/500 captured (Right hand, gesture: mafia)
# ✅ Sample 266/500 captured (Right hand, gesture: mafia)
# ✅ Sample 267/500 captured (Right hand, gesture: mafia)
# ✅ Sample 268/500 captured (Right hand, gesture: mafia)
# ✅ Sample 269/500 captured (Right hand, gesture: mafia)
# ✅ Sample 270/500 captured (Right hand, gesture: mafia)
# ✅ Sample 271/500 captured (Right hand, gesture: mafia)
# ✅ Sample 272/500 captured (Right hand, gesture: mafia)
# ✅ Sample 273/500 captured (Right hand, gesture: mafia)
# ✅ Sample 274/500 captured (Right hand, gesture: mafia)
# ✅ Sample 275/500 captured (Right hand, gesture: mafia)
# ✅ Sample 276/500 captured (Right hand, gesture: mafia)
# ✅ Sample 277/500 captured (Right hand, gesture: mafia)
# ✅ Sample 278/500 captured (Right hand, gesture: mafia)
# ✅ Sample 279/500 captured (Right hand, gesture: mafia)
# ✅ Sample 280/500 captured (Right hand, gesture: mafia)
# ✅ Sample 281/500 captured (Right hand, gesture: mafia)
# ✅ Sample 282/500 captured (Right hand, gesture: mafia)
# ✅ Sample 283/500 captured (Right hand, gesture: mafia)
# ✅ Sample 284/500 captured (Right hand, gesture: mafia)
# ✅ Sample 285/500 captured (Right hand, gesture: mafia)
# ✅ Sample 286/500 captured (Right hand, gesture: mafia)
# ✅ Sample 287/500 captured (Right hand, gesture: mafia)
# ✅ Sample 288/500 captured (Right hand, gesture: mafia)
# ✅ Sample 289/500 captured (Right hand, gesture: mafia)
# ✅ Sample 290/500 captured (Right hand, gesture: mafia)
# ✅ Sample 291/500 captured (Right hand, gesture: mafia)
# ✅ Sample 292/500 captured (Right hand, gesture: mafia)
# ✅ Sample 293/500 captured (Right hand, gesture: mafia)
# ✅ Sample 294/500 captured (Right hand, gesture: mafia)
# ✅ Sample 295/500 captured (Right hand, gesture: mafia)
# ✅ Sample 296/500 captured (Right hand, gesture: mafia)
# ✅ Sample 297/500 captured (Right hand, gesture: mafia)
# ✅ Sample 298/500 captured (Right hand, gesture: mafia)
# ✅ Sample 299/500 captured (Right hand, gesture: mafia)
# ✅ Sample 300/500 captured (Right hand, gesture: mafia)
# ✅ Sample 301/500 captured (Right hand, gesture: mafia)
# ✅ Sample 302/500 captured (Right hand, gesture: mafia)
# ✅ Sample 303/500 captured (Right hand, gesture: mafia)
# ✅ Sample 304/500 captured (Right hand, gesture: mafia)
# ✅ Sample 305/500 captured (Right hand, gesture: mafia)
# ✅ Sample 306/500 captured (Right hand, gesture: mafia)
# ✅ Sample 307/500 captured (Right hand, gesture: mafia)
# ✅ Sample 308/500 captured (Right hand, gesture: mafia)
# ✅ Sample 309/500 captured (Right hand, gesture: mafia)
# ✅ Sample 310/500 captured (Right hand, gesture: mafia)
# ✅ Sample 311/500 captured (Right hand, gesture: mafia)
# ✅ Sample 312/500 captured (Right hand, gesture: mafia)
# ✅ Sample 313/500 captured (Right hand, gesture: mafia)
# ✅ Sample 314/500 captured (Right hand, gesture: mafia)
# ✅ Sample 315/500 captured (Right hand, gesture: mafia)
# ✅ Sample 316/500 captured (Right hand, gesture: mafia)
# ✅ Sample 317/500 captured (Right hand, gesture: mafia)
# ✅ Sample 318/500 captured (Right hand, gesture: mafia)
# ✅ Sample 319/500 captured (Right hand, gesture: mafia)
# ✅ Sample 320/500 captured (Right hand, gesture: mafia)
# ✅ Sample 321/500 captured (Right hand, gesture: mafia)
# ✅ Sample 322/500 captured (Right hand, gesture: mafia)
# ✅ Sample 323/500 captured (Right hand, gesture: mafia)
# ✅ Sample 324/500 captured (Right hand, gesture: mafia)
# ✅ Sample 325/500 captured (Right hand, gesture: mafia)
# ✅ Sample 326/500 captured (Right hand, gesture: mafia)
# ✅ Sample 327/500 captured (Right hand, gesture: mafia)
# ✅ Sample 328/500 captured (Right hand, gesture: mafia)
# ✅ Sample 329/500 captured (Right hand, gesture: mafia)
# ✅ Sample 330/500 captured (Right hand, gesture: mafia)
# ✅ Sample 331/500 captured (Right hand, gesture: mafia)
# ✅ Sample 332/500 captured (Right hand, gesture: mafia)
# ✅ Sample 333/500 captured (Right hand, gesture: mafia)
# ✅ Sample 334/500 captured (Right hand, gesture: mafia)
# ✅ Sample 335/500 captured (Right hand, gesture: mafia)
# ✅ Sample 336/500 captured (Right hand, gesture: mafia)
# ✅ Sample 337/500 captured (Right hand, gesture: mafia)
# ✅ Sample 338/500 captured (Right hand, gesture: mafia)
# ✅ Sample 339/500 captured (Right hand, gesture: mafia)
# ✅ Sample 340/500 captured (Right hand, gesture: mafia)
# ✅ Sample 341/500 captured (Right hand, gesture: mafia)
# ✅ Sample 342/500 captured (Right hand, gesture: mafia)
# ✅ Sample 343/500 captured (Right hand, gesture: mafia)
# ✅ Sample 344/500 captured (Right hand, gesture: mafia)
# ✅ Sample 345/500 captured (Right hand, gesture: mafia)
# ✅ Sample 346/500 captured (Right hand, gesture: mafia)
# ✅ Sample 347/500 captured (Right hand, gesture: mafia)
# ✅ Sample 348/500 captured (Right hand, gesture: mafia)
# ✅ Sample 349/500 captured (Right hand, gesture: mafia)
# ✅ Sample 350/500 captured (Right hand, gesture: mafia)
# ✅ Sample 351/500 captured (Right hand, gesture: mafia)
# ✅ Sample 352/500 captured (Right hand, gesture: mafia)
# ✅ Sample 353/500 captured (Right hand, gesture: mafia)
# ✅ Sample 354/500 captured (Right hand, gesture: mafia)
# ✅ Sample 355/500 captured (Right hand, gesture: mafia)
# ✅ Sample 356/500 captured (Right hand, gesture: mafia)
# ✅ Sample 357/500 captured (Right hand, gesture: mafia)
# ✅ Sample 358/500 captured (Right hand, gesture: mafia)
# ✅ Sample 359/500 captured (Right hand, gesture: mafia)
# ✅ Sample 360/500 captured (Right hand, gesture: mafia)
# ✅ Sample 361/500 captured (Right hand, gesture: mafia)
# ✅ Sample 362/500 captured (Right hand, gesture: mafia)
# ✅ Sample 363/500 captured (Right hand, gesture: mafia)
# ✅ Sample 364/500 captured (Right hand, gesture: mafia)
# ✅ Sample 365/500 captured (Right hand, gesture: mafia)
# ✅ Sample 366/500 captured (Right hand, gesture: mafia)
# ✅ Sample 367/500 captured (Right hand, gesture: mafia)
# ✅ Sample 368/500 captured (Right hand, gesture: mafia)
# ✅ Sample 369/500 captured (Right hand, gesture: mafia)
# ✅ Sample 370/500 captured (Right hand, gesture: mafia)
# ✅ Sample 371/500 captured (Right hand, gesture: mafia)
# ✅ Sample 372/500 captured (Right hand, gesture: mafia)
# ✅ Sample 373/500 captured (Right hand, gesture: mafia)
# ✅ Sample 374/500 captured (Right hand, gesture: mafia)
# ✅ Sample 375/500 captured (Right hand, gesture: mafia)
# ✅ Sample 376/500 captured (Right hand, gesture: mafia)
# ✅ Sample 377/500 captured (Right hand, gesture: mafia)
# ✅ Sample 378/500 captured (Right hand, gesture: mafia)
# ✅ Sample 379/500 captured (Right hand, gesture: mafia)
# ✅ Sample 380/500 captured (Right hand, gesture: mafia)
# ✅ Sample 381/500 captured (Right hand, gesture: mafia)
# ✅ Sample 382/500 captured (Right hand, gesture: mafia)
# ✅ Sample 383/500 captured (Right hand, gesture: mafia)
# ✅ Sample 384/500 captured (Right hand, gesture: mafia)
# ✅ Sample 385/500 captured (Right hand, gesture: mafia)
# ✅ Sample 386/500 captured (Right hand, gesture: mafia)
# ✅ Sample 387/500 captured (Right hand, gesture: mafia)
# ✅ Sample 388/500 captured (Right hand, gesture: mafia)
# ✅ Sample 389/500 captured (Right hand, gesture: mafia)
# ✅ Sample 390/500 captured (Right hand, gesture: mafia)
# ✅ Sample 391/500 captured (Right hand, gesture: mafia)
# ✅ Sample 392/500 captured (Right hand, gesture: mafia)
# ✅ Sample 393/500 captured (Right hand, gesture: mafia)
# ✅ Sample 394/500 captured (Right hand, gesture: mafia)
# ✅ Sample 395/500 captured (Right hand, gesture: mafia)
# ✅ Sample 396/500 captured (Right hand, gesture: mafia)
# ✅ Sample 397/500 captured (Right hand, gesture: mafia)
# ✅ Sample 398/500 captured (Right hand, gesture: mafia)
# ✅ Sample 399/500 captured (Right hand, gesture: mafia)
# ✅ Sample 400/500 captured (Right hand, gesture: mafia)
# ✅ Sample 401/500 captured (Right hand, gesture: mafia)
# ✅ Sample 402/500 captured (Right hand, gesture: mafia)
# ✅ Sample 403/500 captured (Right hand, gesture: mafia)
# ✅ Sample 404/500 captured (Right hand, gesture: mafia)
# ✅ Sample 405/500 captured (Right hand, gesture: mafia)
# ✅ Sample 406/500 captured (Right hand, gesture: mafia)
# ✅ Sample 407/500 captured (Right hand, gesture: mafia)
# ✅ Sample 408/500 captured (Right hand, gesture: mafia)
# ✅ Sample 409/500 captured (Right hand, gesture: mafia)
# ✅ Sample 410/500 captured (Right hand, gesture: mafia)
# ✅ Sample 411/500 captured (Right hand, gesture: mafia)
# ✅ Sample 412/500 captured (Right hand, gesture: mafia)
# ✅ Sample 413/500 captured (Right hand, gesture: mafia)
# ✅ Sample 414/500 captured (Right hand, gesture: mafia)
# ✅ Sample 415/500 captured (Right hand, gesture: mafia)
# ✅ Sample 416/500 captured (Right hand, gesture: mafia)
# ✅ Sample 417/500 captured (Right hand, gesture: mafia)
# ✅ Sample 418/500 captured (Right hand, gesture: mafia)
# ✅ Sample 419/500 captured (Right hand, gesture: mafia)
# ✅ Sample 420/500 captured (Right hand, gesture: mafia)
# ✅ Sample 421/500 captured (Right hand, gesture: mafia)
# ✅ Sample 422/500 captured (Right hand, gesture: mafia)
# ✅ Sample 423/500 captured (Right hand, gesture: mafia)
# ✅ Sample 424/500 captured (Right hand, gesture: mafia)
# ✅ Sample 425/500 captured (Right hand, gesture: mafia)
# ✅ Sample 426/500 captured (Right hand, gesture: mafia)
# ✅ Sample 427/500 captured (Right hand, gesture: mafia)
# ✅ Sample 428/500 captured (Right hand, gesture: mafia)
# ✅ Sample 429/500 captured (Right hand, gesture: mafia)
# ✅ Sample 430/500 captured (Right hand, gesture: mafia)
# ✅ Sample 431/500 captured (Right hand, gesture: mafia)
# ✅ Sample 432/500 captured (Right hand, gesture: mafia)
# ✅ Sample 433/500 captured (Right hand, gesture: mafia)
# ✅ Sample 434/500 captured (Right hand, gesture: mafia)
# ✅ Sample 435/500 captured (Right hand, gesture: mafia)
# ✅ Sample 436/500 captured (Right hand, gesture: mafia)
# ✅ Sample 437/500 captured (Right hand, gesture: mafia)
# ✅ Sample 438/500 captured (Right hand, gesture: mafia)
# ✅ Sample 439/500 captured (Right hand, gesture: mafia)
# ✅ Sample 440/500 captured (Right hand, gesture: mafia)
# ✅ Sample 441/500 captured (Right hand, gesture: mafia)
# ✅ Sample 442/500 captured (Right hand, gesture: mafia)
# ✅ Sample 443/500 captured (Right hand, gesture: mafia)
# ✅ Sample 444/500 captured (Right hand, gesture: mafia)
# ✅ Sample 445/500 captured (Right hand, gesture: mafia)
# ✅ Sample 446/500 captured (Right hand, gesture: mafia)
# ✅ Sample 447/500 captured (Right hand, gesture: mafia)
# ✅ Sample 448/500 captured (Right hand, gesture: mafia)
# ✅ Sample 449/500 captured (Right hand, gesture: mafia)
# ✅ Sample 450/500 captured (Right hand, gesture: mafia)
# ✅ Sample 451/500 captured (Right hand, gesture: mafia)
# ✅ Sample 452/500 captured (Right hand, gesture: mafia)
# ✅ Sample 453/500 captured (Right hand, gesture: mafia)
# ✅ Sample 454/500 captured (Right hand, gesture: mafia)
# ✅ Sample 455/500 captured (Right hand, gesture: mafia)
# ✅ Sample 456/500 captured (Right hand, gesture: mafia)
# ✅ Sample 457/500 captured (Right hand, gesture: mafia)
# ✅ Sample 458/500 captured (Right hand, gesture: mafia)
# ✅ Sample 459/500 captured (Right hand, gesture: mafia)
# ✅ Sample 460/500 captured (Right hand, gesture: mafia)
# ✅ Sample 461/500 captured (Right hand, gesture: mafia)
# ✅ Sample 462/500 captured (Right hand, gesture: mafia)
# ✅ Sample 463/500 captured (Right hand, gesture: mafia)
# ✅ Sample 464/500 captured (Right hand, gesture: mafia)
# ✅ Sample 465/500 captured (Right hand, gesture: mafia)
# ✅ Sample 466/500 captured (Right hand, gesture: mafia)
# ✅ Sample 467/500 captured (Right hand, gesture: mafia)
# ✅ Sample 468/500 captured (Right hand, gesture: mafia)
# ✅ Sample 469/500 captured (Right hand, gesture: mafia)
# ✅ Sample 470/500 captured (Right hand, gesture: mafia)
# ✅ Sample 471/500 captured (Right hand, gesture: mafia)
# ✅ Sample 472/500 captured (Right hand, gesture: mafia)
# ✅ Sample 473/500 captured (Right hand, gesture: mafia)
# ✅ Sample 474/500 captured (Right hand, gesture: mafia)
# ✅ Sample 475/500 captured (Right hand, gesture: mafia)
# ✅ Sample 476/500 captured (Right hand, gesture: mafia)
# ✅ Sample 477/500 captured (Right hand, gesture: mafia)
# ✅ Sample 478/500 captured (Right hand, gesture: mafia)
# ✅ Sample 479/500 captured (Right hand, gesture: mafia)
# ✅ Sample 480/500 captured (Right hand, gesture: mafia)
# ✅ Sample 481/500 captured (Right hand, gesture: mafia)
# ✅ Sample 482/500 captured (Right hand, gesture: mafia)
# ✅ Sample 483/500 captured (Right hand, gesture: mafia)
# ✅ Sample 484/500 captured (Right hand, gesture: mafia)
# ✅ Sample 485/500 captured (Right hand, gesture: mafia)
# ✅ Sample 486/500 captured (Right hand, gesture: mafia)
# ✅ Sample 487/500 captured (Right hand, gesture: mafia)
# ✅ Sample 488/500 captured (Right hand, gesture: mafia)
# ✅ Sample 489/500 captured (Right hand, gesture: mafia)
# ✅ Sample 490/500 captured (Right hand, gesture: mafia)
# ✅ Sample 491/500 captured (Right hand, gesture: mafia)
# ✅ Sample 492/500 captured (Right hand, gesture: mafia)
# ✅ Sample 493/500 captured (Right hand, gesture: mafia)
# ✅ Sample 494/500 captured (Right hand, gesture: mafia)
# ✅ Sample 495/500 captured (Right hand, gesture: mafia)
# ✅ Sample 496/500 captured (Right hand, gesture: mafia)
# ✅ Sample 497/500 captured (Right hand, gesture: mafia)
# ✅ Sample 498/500 captured (Right hand, gesture: mafia)
# ✅ Sample 499/500 captured (Right hand, gesture: mafia)
# ✅ Sample 500/500 captured (Right hand, gesture: mafia)
#
# CSV saved: ../data/raw/upd_mafia.csv (2000 total rows)

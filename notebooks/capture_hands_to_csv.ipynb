# %%
import cv2
import mediapipe as mp
import pandas as pd
import os
from datetime import datetime
import time 

def capture_hands_to_csv(output_csv, gesture_label, max_samples=100):
    """
    Открывает камеру, делает снимки по нажатию 'c' 
    и сохраняет координаты 21 точки руки в CSV.
    Столбцы: x0,y0,...,x20,y20,gesture,is_right_hand (1=Right, 0=Left)

    Аргументы:
    - output_csv: путь к CSV-файлу (например 'data/gestures.csv')
    - gesture_label: метка жеста (например 'thumbs_up')
    - max_samples: максимальное кол-во записей
    """

    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands(
        static_image_mode=True,
        max_num_hands=1,
        min_detection_confidence=0.9,
        min_tracking_confidence=0.7
    )

    capture_interval = 0.5
    last_capture_time = 0

    rows = []
    count = 0

    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print(" !!! Unable to access camera")
        return

    print("Camera is ready. Press 'c' to capture, 'q' to quit.")

    while cap.isOpened() and count < max_samples:
        success, frame = cap.read()
        if not success:
            print(" !!! Can't read frame from camera")
            break

        # Отражаем кадр для отображения и для анализа
        frame_flipped = cv2.flip(frame, 1)
        image_rgb = cv2.cvtColor(frame_flipped, cv2.COLOR_BGR2RGB)
        result = hands.process(image_rgb)

        # Отображаем руку на экране
        if result.multi_hand_landmarks:
            for hand_landmarks in result.multi_hand_landmarks:
                mp.solutions.drawing_utils.draw_landmarks(
                    frame_flipped, hand_landmarks, mp_hands.HAND_CONNECTIONS
                )

        cv2.imshow("Hand Capture", frame_flipped)
        key = cv2.waitKey(1) & 0xFF

    
        if key == ord('c'):
            if result.multi_hand_landmarks and result.multi_handedness:
                hand_landmarks = result.multi_hand_landmarks[0]
                handedness_info = result.multi_handedness[0]
                label = handedness_info.classification[0].label
                is_right = 1 if label == "Right" else 0

                coords = []
                for lm in hand_landmarks.landmark:
                    coords.extend([lm.x, lm.y])

                rows.append(coords + [gesture_label, is_right])
                count += 1
                print(f"✅ Sample {count}/{max_samples} captured ({label} hand)")
            else:
                print("⚠️ No hand detected. Try again.")

        elif key == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    hands.close()

    if not rows:
        print("      No samples recorded.")
        return

    columns = [f"{axis}{i}" for i in range(21) for axis in ("x", "y")] + ["gesture", "is_right_hand"]
    df = pd.DataFrame(rows, columns=columns)

    os.makedirs(os.path.dirname(output_csv), exist_ok=True)

    if os.path.exists(output_csv):
        df_existing = pd.read_csv(output_csv)
        df = pd.concat([df_existing, df], ignore_index=True)

    df.to_csv(output_csv, index=False)
    print(f"\n CSV saved: {output_csv} ({len(df)} total rows)")

# %%
# question 
output_csv = '../data/raw/question3.csv'
capture_hands_to_csv(output_csv, "question", max_samples=300)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762269880.770370  110065 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762269880.779946  110141 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-33-generic)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1762269880.854138  110116 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762269880.908614  110126 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera is ready. Press 'c' to capture, 'q' to quit.
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/fateee/Desktop/ulyana/Hand-Gesture-Recognition/.venv/lib/python3.12/site-packages/cv2/qt/plugins"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # question
#       2 output_csv = '../data/raw/question3.csv'
# ----> 3 capture_hands_to_csv(output_csv, "question", max_samples=300)
#
# Cell In[2], line 60, in capture_hands_to_csv(output_csv, gesture_label, max_samples)
#      55         mp.solutions.drawing_utils.draw_landmarks(
#      56             frame_flipped, hand_landmarks, mp_hands.HAND_CONNECTIONS
#      57         )
#      59 cv2.imshow("Hand Capture", frame_flipped)
# ---> 60 key = cv2.waitKey(1) & 0xFF
#      63 if key == ord('c'):
#      64     if result.multi_hand_landmarks and result.multi_handedness:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# question 
output_csv = '../data/raw/question4.csv'
capture_hands_to_csv(output_csv, "question", max_samples=500)
# Out:
# I0000 00:00:1762268240.237493  107140 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762268240.241641  107681 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-33-generic)
# W0000 00:00:1762268240.294899  107662 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762268240.331685  107668 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera is ready. Press 'c' to capture, 'q' to quit.
# ✅ Sample 1/500 captured (Right hand)
# ✅ Sample 2/500 captured (Right hand)
# ✅ Sample 3/500 captured (Right hand)
# ✅ Sample 4/500 captured (Right hand)
# ✅ Sample 5/500 captured (Right hand)
# ✅ Sample 6/500 captured (Right hand)
# ✅ Sample 7/500 captured (Right hand)
# ✅ Sample 8/500 captured (Right hand)
# ✅ Sample 9/500 captured (Right hand)
# ✅ Sample 10/500 captured (Right hand)
# ✅ Sample 11/500 captured (Right hand)
# ✅ Sample 12/500 captured (Right hand)
# ✅ Sample 13/500 captured (Right hand)
# ✅ Sample 14/500 captured (Right hand)
# ✅ Sample 15/500 captured (Right hand)
# ✅ Sample 16/500 captured (Right hand)
# ✅ Sample 17/500 captured (Right hand)
# ✅ Sample 18/500 captured (Right hand)
# ✅ Sample 19/500 captured (Right hand)
# ✅ Sample 20/500 captured (Right hand)
# ✅ Sample 21/500 captured (Right hand)
# ✅ Sample 22/500 captured (Right hand)
# ✅ Sample 23/500 captured (Right hand)
# ✅ Sample 24/500 captured (Right hand)
# ✅ Sample 25/500 captured (Right hand)
# ✅ Sample 26/500 captured (Right hand)
# ✅ Sample 27/500 captured (Right hand)
# ✅ Sample 28/500 captured (Right hand)
# ✅ Sample 29/500 captured (Right hand)
# ✅ Sample 30/500 captured (Right hand)
# ✅ Sample 31/500 captured (Right hand)
# ✅ Sample 32/500 captured (Right hand)
# ✅ Sample 33/500 captured (Right hand)
# ✅ Sample 34/500 captured (Right hand)
# ✅ Sample 35/500 captured (Right hand)
# ✅ Sample 36/500 captured (Right hand)
# ✅ Sample 37/500 captured (Right hand)
# ✅ Sample 38/500 captured (Right hand)
# ✅ Sample 39/500 captured (Right hand)
# ✅ Sample 40/500 captured (Right hand)
# ✅ Sample 41/500 captured (Right hand)
# ✅ Sample 42/500 captured (Right hand)
# ✅ Sample 43/500 captured (Right hand)
# ✅ Sample 44/500 captured (Right hand)
# ✅ Sample 45/500 captured (Right hand)
# ✅ Sample 46/500 captured (Right hand)
# ✅ Sample 47/500 captured (Right hand)
# ✅ Sample 48/500 captured (Right hand)
# ✅ Sample 49/500 captured (Right hand)
# ✅ Sample 50/500 captured (Right hand)
# ✅ Sample 51/500 captured (Right hand)
# ✅ Sample 52/500 captured (Right hand)
# ✅ Sample 53/500 captured (Right hand)
# ✅ Sample 54/500 captured (Right hand)
# ✅ Sample 55/500 captured (Right hand)
# ✅ Sample 56/500 captured (Right hand)
# ✅ Sample 57/500 captured (Right hand)
# ✅ Sample 58/500 captured (Right hand)
# ✅ Sample 59/500 captured (Right hand)
# ✅ Sample 60/500 captured (Right hand)
# ✅ Sample 61/500 captured (Right hand)
# ✅ Sample 62/500 captured (Right hand)
# ✅ Sample 63/500 captured (Right hand)
# ✅ Sample 64/500 captured (Right hand)
# ✅ Sample 65/500 captured (Right hand)
# ✅ Sample 66/500 captured (Right hand)
# ✅ Sample 67/500 captured (Right hand)
# ✅ Sample 68/500 captured (Right hand)
# ✅ Sample 69/500 captured (Right hand)
# ✅ Sample 70/500 captured (Right hand)
# ✅ Sample 71/500 captured (Right hand)
# ✅ Sample 72/500 captured (Right hand)
# ✅ Sample 73/500 captured (Right hand)
# ✅ Sample 74/500 captured (Right hand)
# ✅ Sample 75/500 captured (Right hand)
# ✅ Sample 76/500 captured (Right hand)
# ✅ Sample 77/500 captured (Right hand)
# ✅ Sample 78/500 captured (Right hand)
# ✅ Sample 79/500 captured (Right hand)
# ✅ Sample 80/500 captured (Right hand)
# ✅ Sample 81/500 captured (Right hand)
# ✅ Sample 82/500 captured (Right hand)
# ✅ Sample 83/500 captured (Right hand)
# ✅ Sample 84/500 captured (Right hand)
# ✅ Sample 85/500 captured (Right hand)
# ✅ Sample 86/500 captured (Right hand)
# ✅ Sample 87/500 captured (Right hand)
# ✅ Sample 88/500 captured (Right hand)
# ✅ Sample 89/500 captured (Right hand)
# ✅ Sample 90/500 captured (Right hand)
# ✅ Sample 91/500 captured (Right hand)
# ✅ Sample 92/500 captured (Right hand)
# ✅ Sample 93/500 captured (Right hand)
# ✅ Sample 94/500 captured (Right hand)
# ✅ Sample 95/500 captured (Right hand)
# ✅ Sample 96/500 captured (Right hand)
# ✅ Sample 97/500 captured (Right hand)
# ✅ Sample 98/500 captured (Right hand)
# ✅ Sample 99/500 captured (Right hand)
# ✅ Sample 100/500 captured (Right hand)
# ✅ Sample 101/500 captured (Right hand)
# ✅ Sample 102/500 captured (Right hand)
# ✅ Sample 103/500 captured (Right hand)
# ✅ Sample 104/500 captured (Right hand)
# ✅ Sample 105/500 captured (Right hand)
# ✅ Sample 106/500 captured (Right hand)
# ✅ Sample 107/500 captured (Right hand)
# ✅ Sample 108/500 captured (Right hand)
# ✅ Sample 109/500 captured (Right hand)
# ✅ Sample 110/500 captured (Right hand)
# ✅ Sample 111/500 captured (Right hand)
# ✅ Sample 112/500 captured (Right hand)
# ✅ Sample 113/500 captured (Right hand)
# ✅ Sample 114/500 captured (Right hand)
# ✅ Sample 115/500 captured (Right hand)
# ✅ Sample 116/500 captured (Right hand)
# ✅ Sample 117/500 captured (Right hand)
# ✅ Sample 118/500 captured (Right hand)
# ✅ Sample 119/500 captured (Right hand)
# ✅ Sample 120/500 captured (Right hand)
# ✅ Sample 121/500 captured (Right hand)
# ✅ Sample 122/500 captured (Right hand)
# ✅ Sample 123/500 captured (Right hand)
# ✅ Sample 124/500 captured (Right hand)
# ✅ Sample 125/500 captured (Right hand)
# ✅ Sample 126/500 captured (Right hand)
# ✅ Sample 127/500 captured (Right hand)
# ✅ Sample 128/500 captured (Right hand)
# ✅ Sample 129/500 captured (Right hand)
# ✅ Sample 130/500 captured (Right hand)
# ✅ Sample 131/500 captured (Right hand)
# ✅ Sample 132/500 captured (Right hand)
# ✅ Sample 133/500 captured (Right hand)
# ✅ Sample 134/500 captured (Right hand)
# ✅ Sample 135/500 captured (Right hand)
# ✅ Sample 136/500 captured (Right hand)
# ✅ Sample 137/500 captured (Right hand)
# ✅ Sample 138/500 captured (Right hand)
# ✅ Sample 139/500 captured (Right hand)
# ✅ Sample 140/500 captured (Right hand)
# ✅ Sample 141/500 captured (Right hand)
# ✅ Sample 142/500 captured (Right hand)
# ✅ Sample 143/500 captured (Right hand)
# ✅ Sample 144/500 captured (Right hand)
# ✅ Sample 145/500 captured (Right hand)
# ✅ Sample 146/500 captured (Right hand)
# ✅ Sample 147/500 captured (Right hand)
# ✅ Sample 148/500 captured (Right hand)
# ✅ Sample 149/500 captured (Right hand)
# ✅ Sample 150/500 captured (Right hand)
# ✅ Sample 151/500 captured (Right hand)
# ✅ Sample 152/500 captured (Right hand)
# ✅ Sample 153/500 captured (Right hand)
# ✅ Sample 154/500 captured (Right hand)
# ✅ Sample 155/500 captured (Right hand)
# ✅ Sample 156/500 captured (Right hand)
# ✅ Sample 157/500 captured (Right hand)
# ✅ Sample 158/500 captured (Right hand)
# ✅ Sample 159/500 captured (Right hand)
# ✅ Sample 160/500 captured (Right hand)
# ✅ Sample 161/500 captured (Right hand)
# ✅ Sample 162/500 captured (Right hand)
# ✅ Sample 163/500 captured (Right hand)
# ✅ Sample 164/500 captured (Right hand)
# ✅ Sample 165/500 captured (Right hand)
# ✅ Sample 166/500 captured (Right hand)
# ✅ Sample 167/500 captured (Right hand)
# ✅ Sample 168/500 captured (Right hand)
# ✅ Sample 169/500 captured (Right hand)
# ✅ Sample 170/500 captured (Right hand)
# ✅ Sample 171/500 captured (Right hand)
# ✅ Sample 172/500 captured (Right hand)
# ✅ Sample 173/500 captured (Right hand)
# ✅ Sample 174/500 captured (Right hand)
# ✅ Sample 175/500 captured (Right hand)
# ✅ Sample 176/500 captured (Right hand)
# ✅ Sample 177/500 captured (Right hand)
# ✅ Sample 178/500 captured (Right hand)
# ✅ Sample 179/500 captured (Right hand)
# ✅ Sample 180/500 captured (Right hand)
# ✅ Sample 181/500 captured (Right hand)
# ✅ Sample 182/500 captured (Right hand)
# ✅ Sample 183/500 captured (Right hand)
# ✅ Sample 184/500 captured (Right hand)
# ✅ Sample 185/500 captured (Right hand)
# ✅ Sample 186/500 captured (Right hand)
# ✅ Sample 187/500 captured (Right hand)
# ✅ Sample 188/500 captured (Right hand)
# ✅ Sample 189/500 captured (Right hand)
# ✅ Sample 190/500 captured (Right hand)
# ✅ Sample 191/500 captured (Right hand)
# ✅ Sample 192/500 captured (Right hand)
# ✅ Sample 193/500 captured (Right hand)
# ✅ Sample 194/500 captured (Right hand)
# ✅ Sample 195/500 captured (Right hand)
# ✅ Sample 196/500 captured (Right hand)
# ✅ Sample 197/500 captured (Right hand)
# ✅ Sample 198/500 captured (Right hand)
# ✅ Sample 199/500 captured (Right hand)
# ✅ Sample 200/500 captured (Right hand)
# ✅ Sample 201/500 captured (Right hand)
# ✅ Sample 202/500 captured (Right hand)
# ✅ Sample 203/500 captured (Right hand)
# ✅ Sample 204/500 captured (Right hand)
# ✅ Sample 205/500 captured (Right hand)
# ✅ Sample 206/500 captured (Right hand)
# ✅ Sample 207/500 captured (Right hand)
# ✅ Sample 208/500 captured (Right hand)
# ✅ Sample 209/500 captured (Right hand)
# ✅ Sample 210/500 captured (Right hand)
# ✅ Sample 211/500 captured (Right hand)
# ✅ Sample 212/500 captured (Right hand)
# ✅ Sample 213/500 captured (Right hand)
# ✅ Sample 214/500 captured (Right hand)
# ✅ Sample 215/500 captured (Right hand)
# ✅ Sample 216/500 captured (Right hand)
# ✅ Sample 217/500 captured (Right hand)
# ✅ Sample 218/500 captured (Right hand)
# ✅ Sample 219/500 captured (Right hand)
# ✅ Sample 220/500 captured (Right hand)
# ✅ Sample 221/500 captured (Right hand)
# ✅ Sample 222/500 captured (Right hand)
# ✅ Sample 223/500 captured (Right hand)
# ✅ Sample 224/500 captured (Right hand)
# ✅ Sample 225/500 captured (Right hand)
# ✅ Sample 226/500 captured (Right hand)
# ✅ Sample 227/500 captured (Right hand)
# ✅ Sample 228/500 captured (Right hand)
# ✅ Sample 229/500 captured (Right hand)
# ✅ Sample 230/500 captured (Right hand)
# ✅ Sample 231/500 captured (Right hand)
# ✅ Sample 232/500 captured (Right hand)
# ✅ Sample 233/500 captured (Right hand)
# ✅ Sample 234/500 captured (Right hand)
# ✅ Sample 235/500 captured (Right hand)
# ✅ Sample 236/500 captured (Right hand)
# ✅ Sample 237/500 captured (Right hand)
# ✅ Sample 238/500 captured (Right hand)
# ✅ Sample 239/500 captured (Right hand)
# ✅ Sample 240/500 captured (Right hand)
# ✅ Sample 241/500 captured (Right hand)
# ✅ Sample 242/500 captured (Right hand)
# ✅ Sample 243/500 captured (Right hand)
# ✅ Sample 244/500 captured (Right hand)
# ✅ Sample 245/500 captured (Right hand)
# ✅ Sample 246/500 captured (Right hand)
# ✅ Sample 247/500 captured (Right hand)
# ✅ Sample 248/500 captured (Right hand)
# ✅ Sample 249/500 captured (Right hand)
# ✅ Sample 250/500 captured (Right hand)
# ✅ Sample 251/500 captured (Right hand)
# ✅ Sample 252/500 captured (Right hand)
# ✅ Sample 253/500 captured (Right hand)
# ✅ Sample 254/500 captured (Right hand)
# ✅ Sample 255/500 captured (Right hand)
# ✅ Sample 256/500 captured (Right hand)
# ✅ Sample 257/500 captured (Right hand)
# ✅ Sample 258/500 captured (Right hand)
# ✅ Sample 259/500 captured (Right hand)
# ✅ Sample 260/500 captured (Right hand)
# ✅ Sample 261/500 captured (Right hand)
# ✅ Sample 262/500 captured (Right hand)
# ✅ Sample 263/500 captured (Right hand)
# ✅ Sample 264/500 captured (Right hand)
# ✅ Sample 265/500 captured (Right hand)
# ✅ Sample 266/500 captured (Right hand)
# ✅ Sample 267/500 captured (Right hand)
# ✅ Sample 268/500 captured (Right hand)
# ✅ Sample 269/500 captured (Right hand)
# ✅ Sample 270/500 captured (Right hand)
# ✅ Sample 271/500 captured (Right hand)
# ✅ Sample 272/500 captured (Right hand)
# ✅ Sample 273/500 captured (Right hand)
# ✅ Sample 274/500 captured (Right hand)
# ✅ Sample 275/500 captured (Right hand)
# ✅ Sample 276/500 captured (Right hand)
# ✅ Sample 277/500 captured (Right hand)
# ✅ Sample 278/500 captured (Right hand)
# ✅ Sample 279/500 captured (Right hand)
# ✅ Sample 280/500 captured (Right hand)
# ✅ Sample 281/500 captured (Right hand)
# ✅ Sample 282/500 captured (Right hand)
# ✅ Sample 283/500 captured (Right hand)
# ✅ Sample 284/500 captured (Right hand)
# ✅ Sample 285/500 captured (Right hand)
# ✅ Sample 286/500 captured (Right hand)
# ✅ Sample 287/500 captured (Right hand)
# ✅ Sample 288/500 captured (Right hand)
# ✅ Sample 289/500 captured (Right hand)
# ✅ Sample 290/500 captured (Left hand)
# ✅ Sample 291/500 captured (Left hand)
# ✅ Sample 292/500 captured (Left hand)
# ✅ Sample 293/500 captured (Left hand)
# ✅ Sample 294/500 captured (Left hand)
# ✅ Sample 295/500 captured (Left hand)
# ✅ Sample 296/500 captured (Left hand)
# ✅ Sample 297/500 captured (Left hand)
# ✅ Sample 298/500 captured (Left hand)
# ✅ Sample 299/500 captured (Left hand)
# ✅ Sample 300/500 captured (Left hand)
# ✅ Sample 301/500 captured (Left hand)
# ✅ Sample 302/500 captured (Left hand)
# ✅ Sample 303/500 captured (Left hand)
# ✅ Sample 304/500 captured (Left hand)
# ✅ Sample 305/500 captured (Left hand)
# ✅ Sample 306/500 captured (Left hand)
# ✅ Sample 307/500 captured (Left hand)
# ✅ Sample 308/500 captured (Left hand)
# ✅ Sample 309/500 captured (Left hand)
# ✅ Sample 310/500 captured (Left hand)
# ✅ Sample 311/500 captured (Left hand)
# ✅ Sample 312/500 captured (Left hand)
# ✅ Sample 313/500 captured (Left hand)
# ✅ Sample 314/500 captured (Left hand)
# ✅ Sample 315/500 captured (Left hand)
# ✅ Sample 316/500 captured (Left hand)
# ✅ Sample 317/500 captured (Left hand)
# ✅ Sample 318/500 captured (Left hand)
# ✅ Sample 319/500 captured (Left hand)
# ✅ Sample 320/500 captured (Left hand)
# ✅ Sample 321/500 captured (Left hand)
# ✅ Sample 322/500 captured (Left hand)
# ✅ Sample 323/500 captured (Left hand)
# ✅ Sample 324/500 captured (Left hand)
# ✅ Sample 325/500 captured (Left hand)
# ✅ Sample 326/500 captured (Left hand)
# ✅ Sample 327/500 captured (Left hand)
# ✅ Sample 328/500 captured (Left hand)
# ✅ Sample 329/500 captured (Left hand)
# ✅ Sample 330/500 captured (Left hand)
# ✅ Sample 331/500 captured (Left hand)
# ✅ Sample 332/500 captured (Left hand)
# ✅ Sample 333/500 captured (Left hand)
# ✅ Sample 334/500 captured (Left hand)
# ✅ Sample 335/500 captured (Left hand)
# ✅ Sample 336/500 captured (Left hand)
# ✅ Sample 337/500 captured (Left hand)
# ✅ Sample 338/500 captured (Left hand)
# ✅ Sample 339/500 captured (Left hand)
# ✅ Sample 340/500 captured (Left hand)
# ✅ Sample 341/500 captured (Left hand)
# ✅ Sample 342/500 captured (Left hand)
# ✅ Sample 343/500 captured (Left hand)
# ✅ Sample 344/500 captured (Left hand)
# ✅ Sample 345/500 captured (Left hand)
# ✅ Sample 346/500 captured (Left hand)
# ✅ Sample 347/500 captured (Left hand)
# ✅ Sample 348/500 captured (Left hand)
# ✅ Sample 349/500 captured (Left hand)
# ✅ Sample 350/500 captured (Left hand)
# ✅ Sample 351/500 captured (Left hand)
# ✅ Sample 352/500 captured (Left hand)
# ✅ Sample 353/500 captured (Left hand)
# ✅ Sample 354/500 captured (Left hand)
# ✅ Sample 355/500 captured (Left hand)
# ✅ Sample 356/500 captured (Left hand)
# ✅ Sample 357/500 captured (Left hand)
# ✅ Sample 358/500 captured (Left hand)
# ✅ Sample 359/500 captured (Left hand)
# ✅ Sample 360/500 captured (Left hand)
# ✅ Sample 361/500 captured (Left hand)
# ✅ Sample 362/500 captured (Left hand)
# ✅ Sample 363/500 captured (Left hand)
# ✅ Sample 364/500 captured (Left hand)
# ✅ Sample 365/500 captured (Left hand)
# ✅ Sample 366/500 captured (Left hand)
# ✅ Sample 367/500 captured (Left hand)
# ✅ Sample 368/500 captured (Left hand)
# ✅ Sample 369/500 captured (Left hand)
# ✅ Sample 370/500 captured (Left hand)
# ✅ Sample 371/500 captured (Left hand)
# ✅ Sample 372/500 captured (Left hand)
# ✅ Sample 373/500 captured (Left hand)
# ✅ Sample 374/500 captured (Left hand)
# ✅ Sample 375/500 captured (Left hand)
# ✅ Sample 376/500 captured (Left hand)
# ✅ Sample 377/500 captured (Left hand)
# ✅ Sample 378/500 captured (Left hand)
# ✅ Sample 379/500 captured (Left hand)
# ✅ Sample 380/500 captured (Left hand)
# ✅ Sample 381/500 captured (Left hand)
# ✅ Sample 382/500 captured (Left hand)
# ✅ Sample 383/500 captured (Left hand)
# ✅ Sample 384/500 captured (Left hand)
# ✅ Sample 385/500 captured (Left hand)
# ✅ Sample 386/500 captured (Left hand)
# ✅ Sample 387/500 captured (Left hand)
# ✅ Sample 388/500 captured (Left hand)
# ✅ Sample 389/500 captured (Left hand)
# ✅ Sample 390/500 captured (Left hand)
# ✅ Sample 391/500 captured (Left hand)
# ✅ Sample 392/500 captured (Left hand)
# ✅ Sample 393/500 captured (Left hand)
# ✅ Sample 394/500 captured (Left hand)
# ✅ Sample 395/500 captured (Left hand)
# ✅ Sample 396/500 captured (Left hand)
# ✅ Sample 397/500 captured (Left hand)
# ✅ Sample 398/500 captured (Left hand)
# ✅ Sample 399/500 captured (Left hand)
# ✅ Sample 400/500 captured (Left hand)
# ✅ Sample 401/500 captured (Left hand)
# ✅ Sample 402/500 captured (Left hand)
# ✅ Sample 403/500 captured (Left hand)
# ✅ Sample 404/500 captured (Left hand)
# ✅ Sample 405/500 captured (Left hand)
# ✅ Sample 406/500 captured (Left hand)
# ✅ Sample 407/500 captured (Left hand)
# ✅ Sample 408/500 captured (Left hand)
# ✅ Sample 409/500 captured (Left hand)
# ✅ Sample 410/500 captured (Left hand)
# ✅ Sample 411/500 captured (Left hand)
# ✅ Sample 412/500 captured (Left hand)
# ✅ Sample 413/500 captured (Left hand)
# ✅ Sample 414/500 captured (Left hand)
# ✅ Sample 415/500 captured (Left hand)
# ✅ Sample 416/500 captured (Left hand)
# ✅ Sample 417/500 captured (Left hand)
# ✅ Sample 418/500 captured (Left hand)
# ✅ Sample 419/500 captured (Left hand)
# ✅ Sample 420/500 captured (Left hand)
# ✅ Sample 421/500 captured (Left hand)
# ✅ Sample 422/500 captured (Left hand)
# ✅ Sample 423/500 captured (Left hand)
# ✅ Sample 424/500 captured (Left hand)
# ✅ Sample 425/500 captured (Left hand)
# ✅ Sample 426/500 captured (Left hand)
# ✅ Sample 427/500 captured (Left hand)
# ✅ Sample 428/500 captured (Left hand)
# ✅ Sample 429/500 captured (Left hand)
# ✅ Sample 430/500 captured (Left hand)
# ✅ Sample 431/500 captured (Left hand)
# ✅ Sample 432/500 captured (Left hand)
# ✅ Sample 433/500 captured (Left hand)
# ✅ Sample 434/500 captured (Left hand)
# ✅ Sample 435/500 captured (Left hand)
# ✅ Sample 436/500 captured (Left hand)
# ✅ Sample 437/500 captured (Left hand)
# ✅ Sample 438/500 captured (Left hand)
# ✅ Sample 439/500 captured (Left hand)
# ✅ Sample 440/500 captured (Left hand)
# ✅ Sample 441/500 captured (Left hand)
# ✅ Sample 442/500 captured (Left hand)
# ✅ Sample 443/500 captured (Left hand)
# ✅ Sample 444/500 captured (Left hand)
# ✅ Sample 445/500 captured (Left hand)
# ✅ Sample 446/500 captured (Left hand)
# ✅ Sample 447/500 captured (Left hand)
# ✅ Sample 448/500 captured (Left hand)
# ✅ Sample 449/500 captured (Left hand)
# ✅ Sample 450/500 captured (Left hand)
# ✅ Sample 451/500 captured (Left hand)
# ✅ Sample 452/500 captured (Left hand)
# ✅ Sample 453/500 captured (Left hand)
# ✅ Sample 454/500 captured (Left hand)
# ✅ Sample 455/500 captured (Left hand)
# ✅ Sample 456/500 captured (Left hand)
# ✅ Sample 457/500 captured (Left hand)
# ✅ Sample 458/500 captured (Left hand)
# ✅ Sample 459/500 captured (Left hand)
# ✅ Sample 460/500 captured (Left hand)
# ✅ Sample 461/500 captured (Left hand)
# ✅ Sample 462/500 captured (Left hand)
# ✅ Sample 463/500 captured (Left hand)
# ✅ Sample 464/500 captured (Left hand)
# ✅ Sample 465/500 captured (Left hand)
# ✅ Sample 466/500 captured (Left hand)
# ✅ Sample 467/500 captured (Left hand)
# ✅ Sample 468/500 captured (Left hand)
# ✅ Sample 469/500 captured (Left hand)
# ✅ Sample 470/500 captured (Left hand)
# ✅ Sample 471/500 captured (Left hand)
# ✅ Sample 472/500 captured (Left hand)
# ✅ Sample 473/500 captured (Left hand)
# ✅ Sample 474/500 captured (Left hand)
# ✅ Sample 475/500 captured (Left hand)
# ✅ Sample 476/500 captured (Left hand)
# ✅ Sample 477/500 captured (Left hand)
# ✅ Sample 478/500 captured (Left hand)
# ✅ Sample 479/500 captured (Left hand)
# ✅ Sample 480/500 captured (Left hand)
# ✅ Sample 481/500 captured (Left hand)
# ✅ Sample 482/500 captured (Left hand)
# ✅ Sample 483/500 captured (Left hand)
# ✅ Sample 484/500 captured (Left hand)
# ✅ Sample 485/500 captured (Left hand)
# ✅ Sample 486/500 captured (Left hand)
# ✅ Sample 487/500 captured (Left hand)
# ✅ Sample 488/500 captured (Left hand)
# ✅ Sample 489/500 captured (Left hand)
# ✅ Sample 490/500 captured (Left hand)
# ✅ Sample 491/500 captured (Left hand)
# ✅ Sample 492/500 captured (Left hand)
# ✅ Sample 493/500 captured (Left hand)
# ✅ Sample 494/500 captured (Left hand)
# ✅ Sample 495/500 captured (Left hand)
# ✅ Sample 496/500 captured (Left hand)
# ✅ Sample 497/500 captured (Left hand)
# ✅ Sample 498/500 captured (Left hand)
# ✅ Sample 499/500 captured (Left hand)
# ✅ Sample 500/500 captured (Left hand)
#
#  CSV saved: ../data/raw/question4.csv (1000 total rows)

# %%
def capture_hands_to_csv_auto(output_csv, gesture_label, max_samples=100, capture_interval=0.1):
    """
    Открывает камеру и автоматически делает снимки руки каждые capture_interval секунд.
    Сохраняет координаты 21 точки руки в CSV.
    Столбцы: x0,y0,...,x20,y20,gesture,is_right_hand (1=Right, 0=Left)

    Аргументы:
    - output_csv: путь к CSV-файлу (например 'data/gestures.csv')
    - gesture_label: метка жеста (например 'thumbs_up')
    - max_samples: максимальное кол-во записей
    - capture_interval: интервал между снимками в секундах
    """

    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands(
        static_image_mode=True,
        max_num_hands=1,
        min_detection_confidence=0.9,
        min_tracking_confidence=0.7
    )

    rows = []
    count = 0
    last_capture_time = 0

    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print(" !!! Unable to access camera")
        return

    print(f"Camera is ready. Capturing every {capture_interval} seconds. Press 'q' to quit.")

    while cap.isOpened() and count < max_samples:
        success, frame = cap.read()
        if not success:
            print(" !!! Can't read frame from camera")
            break

        # Отражаем кадр для отображения и анализа
        frame_flipped = cv2.flip(frame, 1)
        image_rgb = cv2.cvtColor(frame_flipped, cv2.COLOR_BGR2RGB)
        result = hands.process(image_rgb)

        # Отображаем руку на экране
        if result.multi_hand_landmarks:
            for hand_landmarks in result.multi_hand_landmarks:
                mp.solutions.drawing_utils.draw_landmarks(
                    frame_flipped, hand_landmarks, mp_hands.HAND_CONNECTIONS
                )

        cv2.imshow("Hand Capture", frame_flipped)
        key = cv2.waitKey(1) & 0xFF

        # Автоматическая съемка через capture_interval секунд
        current_time = time.time()
        if current_time - last_capture_time >= capture_interval:
            if result.multi_hand_landmarks and result.multi_handedness:
                hand_landmarks = result.multi_hand_landmarks[0]
                handedness_info = result.multi_handedness[0]
                label = handedness_info.classification[0].label
                is_right = 1 if label == "Right" else 0

                coords = []
                for lm in hand_landmarks.landmark:
                    coords.extend([lm.x, lm.y])

                rows.append(coords + [gesture_label, is_right])
                count += 1
                last_capture_time = current_time
                print(f"✅ Sample {count}/{max_samples} captured ({label} hand)")

        if key == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    hands.close()

    if not rows:
        print("No samples recorded.")
        return

    columns = [f"{axis}{i}" for i in range(21) for axis in ("x", "y")] + ["gesture", "is_right_hand"]
    df = pd.DataFrame(rows, columns=columns)

    os.makedirs(os.path.dirname(output_csv), exist_ok=True)

    if os.path.exists(output_csv):
        df_existing = pd.read_csv(output_csv)
        df = pd.concat([df_existing, df], ignore_index=True)

    df.to_csv(output_csv, index=False)
    print(f"\nCSV saved: {output_csv} ({len(df)} total rows)")

# %%
# question 
output_csv = '../data/raw/question_g.csv'
capture_hands_to_csv_auto(output_csv, "question", max_samples=500)
# Out:
# I0000 00:00:1762269392.591039  108205 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762269392.596238  109320 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-33-generic)
# W0000 00:00:1762269392.648725  109304 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762269392.669027  109316 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera is ready. Capturing every 0.2 seconds. Press 'q' to quit.
# ✅ Sample 1/500 captured (Right hand)
# ✅ Sample 2/500 captured (Right hand)
# ✅ Sample 3/500 captured (Right hand)
# ✅ Sample 4/500 captured (Right hand)
# ✅ Sample 5/500 captured (Right hand)
# ✅ Sample 6/500 captured (Right hand)
# ✅ Sample 7/500 captured (Right hand)
# ✅ Sample 8/500 captured (Right hand)
# ✅ Sample 9/500 captured (Right hand)
# ✅ Sample 10/500 captured (Right hand)
# ✅ Sample 11/500 captured (Right hand)
# ✅ Sample 12/500 captured (Right hand)
# ✅ Sample 13/500 captured (Right hand)
# ✅ Sample 14/500 captured (Right hand)
# ✅ Sample 15/500 captured (Right hand)
# ✅ Sample 16/500 captured (Right hand)
# ✅ Sample 17/500 captured (Right hand)
# ✅ Sample 18/500 captured (Right hand)
# ✅ Sample 19/500 captured (Right hand)
# ✅ Sample 20/500 captured (Right hand)
# ✅ Sample 21/500 captured (Right hand)
# ✅ Sample 22/500 captured (Right hand)
# ✅ Sample 23/500 captured (Right hand)
# ✅ Sample 24/500 captured (Right hand)
# ✅ Sample 25/500 captured (Right hand)
# ✅ Sample 26/500 captured (Right hand)
# ✅ Sample 27/500 captured (Right hand)
# ✅ Sample 28/500 captured (Right hand)
# ✅ Sample 29/500 captured (Right hand)
# ✅ Sample 30/500 captured (Right hand)
# ✅ Sample 31/500 captured (Right hand)
# ✅ Sample 32/500 captured (Right hand)
# ✅ Sample 33/500 captured (Right hand)
# ✅ Sample 34/500 captured (Right hand)
# ✅ Sample 35/500 captured (Right hand)
# ✅ Sample 36/500 captured (Right hand)
# ✅ Sample 37/500 captured (Right hand)
# ✅ Sample 38/500 captured (Right hand)
# ✅ Sample 39/500 captured (Right hand)
# ✅ Sample 40/500 captured (Right hand)
# ✅ Sample 41/500 captured (Right hand)
# ✅ Sample 42/500 captured (Right hand)
# ✅ Sample 43/500 captured (Right hand)
# ✅ Sample 44/500 captured (Right hand)
# ✅ Sample 45/500 captured (Right hand)
# ✅ Sample 46/500 captured (Right hand)
# ✅ Sample 47/500 captured (Right hand)
# ✅ Sample 48/500 captured (Right hand)
# ✅ Sample 49/500 captured (Right hand)
# ✅ Sample 50/500 captured (Right hand)
# ✅ Sample 51/500 captured (Right hand)
# ✅ Sample 52/500 captured (Right hand)
# ✅ Sample 53/500 captured (Right hand)
# ✅ Sample 54/500 captured (Right hand)
# ✅ Sample 55/500 captured (Right hand)
# ✅ Sample 56/500 captured (Right hand)
# ✅ Sample 57/500 captured (Right hand)
# ✅ Sample 58/500 captured (Right hand)
# ✅ Sample 59/500 captured (Right hand)
# ✅ Sample 60/500 captured (Right hand)
# ✅ Sample 61/500 captured (Right hand)
# ✅ Sample 62/500 captured (Right hand)
# ✅ Sample 63/500 captured (Right hand)
# ✅ Sample 64/500 captured (Right hand)
# ✅ Sample 65/500 captured (Right hand)
# ✅ Sample 66/500 captured (Right hand)
# ✅ Sample 67/500 captured (Right hand)
# ✅ Sample 68/500 captured (Right hand)
# ✅ Sample 69/500 captured (Right hand)
# ✅ Sample 70/500 captured (Right hand)
# ✅ Sample 71/500 captured (Right hand)
# ✅ Sample 72/500 captured (Right hand)
# ✅ Sample 73/500 captured (Right hand)
# ✅ Sample 74/500 captured (Right hand)
# ✅ Sample 75/500 captured (Right hand)
# ✅ Sample 76/500 captured (Right hand)
# ✅ Sample 77/500 captured (Right hand)
# ✅ Sample 78/500 captured (Right hand)
# ✅ Sample 79/500 captured (Right hand)
# ✅ Sample 80/500 captured (Right hand)
# ✅ Sample 81/500 captured (Right hand)
# ✅ Sample 82/500 captured (Right hand)
# ✅ Sample 83/500 captured (Right hand)
# ✅ Sample 84/500 captured (Right hand)
# ✅ Sample 85/500 captured (Right hand)
# ✅ Sample 86/500 captured (Right hand)
# ✅ Sample 87/500 captured (Right hand)
# ✅ Sample 88/500 captured (Right hand)
# ✅ Sample 89/500 captured (Right hand)
# ✅ Sample 90/500 captured (Right hand)
# ✅ Sample 91/500 captured (Right hand)
# ✅ Sample 92/500 captured (Right hand)
# ✅ Sample 93/500 captured (Right hand)
# ✅ Sample 94/500 captured (Right hand)
# ✅ Sample 95/500 captured (Right hand)
# ✅ Sample 96/500 captured (Right hand)
# ✅ Sample 97/500 captured (Right hand)
# ✅ Sample 98/500 captured (Right hand)
# ✅ Sample 99/500 captured (Right hand)
# ✅ Sample 100/500 captured (Right hand)
# ✅ Sample 101/500 captured (Right hand)
# ✅ Sample 102/500 captured (Right hand)
# ✅ Sample 103/500 captured (Right hand)
# ✅ Sample 104/500 captured (Right hand)
# ✅ Sample 105/500 captured (Right hand)
# ✅ Sample 106/500 captured (Right hand)
# ✅ Sample 107/500 captured (Right hand)
# ✅ Sample 108/500 captured (Right hand)
# ✅ Sample 109/500 captured (Right hand)
# ✅ Sample 110/500 captured (Right hand)
# ✅ Sample 111/500 captured (Right hand)
# ✅ Sample 112/500 captured (Right hand)
# ✅ Sample 113/500 captured (Right hand)
# ✅ Sample 114/500 captured (Right hand)
# ✅ Sample 115/500 captured (Right hand)
# ✅ Sample 116/500 captured (Right hand)
# ✅ Sample 117/500 captured (Right hand)
# ✅ Sample 118/500 captured (Right hand)
# ✅ Sample 119/500 captured (Right hand)
# ✅ Sample 120/500 captured (Right hand)
# ✅ Sample 121/500 captured (Right hand)
# ✅ Sample 122/500 captured (Right hand)
# ✅ Sample 123/500 captured (Right hand)
# ✅ Sample 124/500 captured (Right hand)
# ✅ Sample 125/500 captured (Right hand)
# ✅ Sample 126/500 captured (Right hand)
# ✅ Sample 127/500 captured (Right hand)
# ✅ Sample 128/500 captured (Right hand)
# ✅ Sample 129/500 captured (Right hand)
# ✅ Sample 130/500 captured (Right hand)
# ✅ Sample 131/500 captured (Right hand)
# ✅ Sample 132/500 captured (Right hand)
# ✅ Sample 133/500 captured (Right hand)
# ✅ Sample 134/500 captured (Right hand)
# ✅ Sample 135/500 captured (Right hand)
# ✅ Sample 136/500 captured (Right hand)
# ✅ Sample 137/500 captured (Right hand)
# ✅ Sample 138/500 captured (Right hand)
# ✅ Sample 139/500 captured (Right hand)
# ✅ Sample 140/500 captured (Right hand)
# ✅ Sample 141/500 captured (Right hand)
# ✅ Sample 142/500 captured (Right hand)
# ✅ Sample 143/500 captured (Right hand)
# ✅ Sample 144/500 captured (Right hand)
# ✅ Sample 145/500 captured (Right hand)
# ✅ Sample 146/500 captured (Right hand)
# ✅ Sample 147/500 captured (Right hand)
# ✅ Sample 148/500 captured (Right hand)
# ✅ Sample 149/500 captured (Right hand)
# ✅ Sample 150/500 captured (Right hand)
# ✅ Sample 151/500 captured (Right hand)
# ✅ Sample 152/500 captured (Right hand)
# ✅ Sample 153/500 captured (Right hand)
# ✅ Sample 154/500 captured (Right hand)
# ✅ Sample 155/500 captured (Right hand)
# ✅ Sample 156/500 captured (Right hand)
# ✅ Sample 157/500 captured (Right hand)
# ✅ Sample 158/500 captured (Right hand)
# ✅ Sample 159/500 captured (Right hand)
# ✅ Sample 160/500 captured (Right hand)
# ✅ Sample 161/500 captured (Right hand)
# ✅ Sample 162/500 captured (Right hand)
# ✅ Sample 163/500 captured (Right hand)
# ✅ Sample 164/500 captured (Right hand)
# ✅ Sample 165/500 captured (Right hand)
# ✅ Sample 166/500 captured (Right hand)
# ✅ Sample 167/500 captured (Right hand)
# ✅ Sample 168/500 captured (Right hand)
# ✅ Sample 169/500 captured (Right hand)
# ✅ Sample 170/500 captured (Right hand)
# ✅ Sample 171/500 captured (Right hand)
# ✅ Sample 172/500 captured (Right hand)
# ✅ Sample 173/500 captured (Right hand)
# ✅ Sample 174/500 captured (Right hand)
# ✅ Sample 175/500 captured (Right hand)
# ✅ Sample 176/500 captured (Right hand)
# ✅ Sample 177/500 captured (Right hand)
# ✅ Sample 178/500 captured (Right hand)
# ✅ Sample 179/500 captured (Right hand)
# ✅ Sample 180/500 captured (Right hand)
# ✅ Sample 181/500 captured (Right hand)
# ✅ Sample 182/500 captured (Right hand)
# ✅ Sample 183/500 captured (Right hand)
# ✅ Sample 184/500 captured (Right hand)
# ✅ Sample 185/500 captured (Right hand)
# ✅ Sample 186/500 captured (Right hand)
# ✅ Sample 187/500 captured (Right hand)
# ✅ Sample 188/500 captured (Right hand)
# ✅ Sample 189/500 captured (Right hand)
# ✅ Sample 190/500 captured (Right hand)
# ✅ Sample 191/500 captured (Right hand)
# ✅ Sample 192/500 captured (Right hand)
# ✅ Sample 193/500 captured (Right hand)
# ✅ Sample 194/500 captured (Right hand)
# ✅ Sample 195/500 captured (Right hand)
# ✅ Sample 196/500 captured (Right hand)
# ✅ Sample 197/500 captured (Right hand)
# ✅ Sample 198/500 captured (Right hand)
# ✅ Sample 199/500 captured (Right hand)
# ✅ Sample 200/500 captured (Right hand)
# ✅ Sample 201/500 captured (Right hand)
# ✅ Sample 202/500 captured (Right hand)
# ✅ Sample 203/500 captured (Right hand)
# ✅ Sample 204/500 captured (Right hand)
# ✅ Sample 205/500 captured (Right hand)
# ✅ Sample 206/500 captured (Right hand)
# ✅ Sample 207/500 captured (Right hand)
# ✅ Sample 208/500 captured (Right hand)
# ✅ Sample 209/500 captured (Right hand)
# ✅ Sample 210/500 captured (Right hand)
# ✅ Sample 211/500 captured (Right hand)
# ✅ Sample 212/500 captured (Right hand)
# ✅ Sample 213/500 captured (Right hand)
# ✅ Sample 214/500 captured (Left hand)
# ✅ Sample 215/500 captured (Left hand)
# ✅ Sample 216/500 captured (Left hand)
# ✅ Sample 217/500 captured (Left hand)
# ✅ Sample 218/500 captured (Left hand)
# ✅ Sample 219/500 captured (Left hand)
# ✅ Sample 220/500 captured (Left hand)
# ✅ Sample 221/500 captured (Left hand)
# ✅ Sample 222/500 captured (Left hand)
# ✅ Sample 223/500 captured (Left hand)
# ✅ Sample 224/500 captured (Left hand)
# ✅ Sample 225/500 captured (Left hand)
# ✅ Sample 226/500 captured (Left hand)
# ✅ Sample 227/500 captured (Left hand)
# ✅ Sample 228/500 captured (Left hand)
# ✅ Sample 229/500 captured (Left hand)
# ✅ Sample 230/500 captured (Left hand)
# ✅ Sample 231/500 captured (Left hand)
# ✅ Sample 232/500 captured (Left hand)
# ✅ Sample 233/500 captured (Left hand)
# ✅ Sample 234/500 captured (Left hand)
# ✅ Sample 235/500 captured (Left hand)
# ✅ Sample 236/500 captured (Left hand)
# ✅ Sample 237/500 captured (Left hand)
# ✅ Sample 238/500 captured (Left hand)
# ✅ Sample 239/500 captured (Left hand)
# ✅ Sample 240/500 captured (Left hand)
# ✅ Sample 241/500 captured (Left hand)
# ✅ Sample 242/500 captured (Left hand)
# ✅ Sample 243/500 captured (Left hand)
# ✅ Sample 244/500 captured (Left hand)
# ✅ Sample 245/500 captured (Left hand)
# ✅ Sample 246/500 captured (Left hand)
# ✅ Sample 247/500 captured (Left hand)
# ✅ Sample 248/500 captured (Left hand)
# ✅ Sample 249/500 captured (Left hand)
# ✅ Sample 250/500 captured (Left hand)
# ✅ Sample 251/500 captured (Left hand)
# ✅ Sample 252/500 captured (Left hand)
# ✅ Sample 253/500 captured (Left hand)
# ✅ Sample 254/500 captured (Left hand)
# ✅ Sample 255/500 captured (Left hand)
# ✅ Sample 256/500 captured (Left hand)
# ✅ Sample 257/500 captured (Left hand)
# ✅ Sample 258/500 captured (Left hand)
# ✅ Sample 259/500 captured (Left hand)
# ✅ Sample 260/500 captured (Left hand)
# ✅ Sample 261/500 captured (Left hand)
# ✅ Sample 262/500 captured (Left hand)
# ✅ Sample 263/500 captured (Left hand)
# ✅ Sample 264/500 captured (Left hand)
# ✅ Sample 265/500 captured (Left hand)
# ✅ Sample 266/500 captured (Left hand)
# ✅ Sample 267/500 captured (Left hand)
# ✅ Sample 268/500 captured (Left hand)
# ✅ Sample 269/500 captured (Left hand)
# ✅ Sample 270/500 captured (Left hand)
# ✅ Sample 271/500 captured (Left hand)
# ✅ Sample 272/500 captured (Left hand)
# ✅ Sample 273/500 captured (Left hand)
# ✅ Sample 274/500 captured (Left hand)
# ✅ Sample 275/500 captured (Left hand)
# ✅ Sample 276/500 captured (Left hand)
# ✅ Sample 277/500 captured (Left hand)
# ✅ Sample 278/500 captured (Left hand)
# ✅ Sample 279/500 captured (Left hand)
# ✅ Sample 280/500 captured (Left hand)
# ✅ Sample 281/500 captured (Left hand)
# ✅ Sample 282/500 captured (Left hand)
# ✅ Sample 283/500 captured (Left hand)
# ✅ Sample 284/500 captured (Left hand)
# ✅ Sample 285/500 captured (Left hand)
# ✅ Sample 286/500 captured (Left hand)
# ✅ Sample 287/500 captured (Left hand)
# ✅ Sample 288/500 captured (Left hand)
# ✅ Sample 289/500 captured (Left hand)
# ✅ Sample 290/500 captured (Left hand)
# ✅ Sample 291/500 captured (Left hand)
# ✅ Sample 292/500 captured (Left hand)
# ✅ Sample 293/500 captured (Left hand)
# ✅ Sample 294/500 captured (Left hand)
# ✅ Sample 295/500 captured (Left hand)
# ✅ Sample 296/500 captured (Left hand)
# ✅ Sample 297/500 captured (Left hand)
# ✅ Sample 298/500 captured (Left hand)
# ✅ Sample 299/500 captured (Left hand)
# ✅ Sample 300/500 captured (Left hand)
# ✅ Sample 301/500 captured (Left hand)
# ✅ Sample 302/500 captured (Left hand)
# ✅ Sample 303/500 captured (Left hand)
# ✅ Sample 304/500 captured (Left hand)
# ✅ Sample 305/500 captured (Left hand)
# ✅ Sample 306/500 captured (Left hand)
# ✅ Sample 307/500 captured (Left hand)
# ✅ Sample 308/500 captured (Left hand)
# ✅ Sample 309/500 captured (Left hand)
# ✅ Sample 310/500 captured (Left hand)
# ✅ Sample 311/500 captured (Left hand)
# ✅ Sample 312/500 captured (Left hand)
# ✅ Sample 313/500 captured (Left hand)
# ✅ Sample 314/500 captured (Left hand)
# ✅ Sample 315/500 captured (Left hand)
# ✅ Sample 316/500 captured (Left hand)
# ✅ Sample 317/500 captured (Left hand)
# ✅ Sample 318/500 captured (Left hand)
# ✅ Sample 319/500 captured (Left hand)
# ✅ Sample 320/500 captured (Left hand)
# ✅ Sample 321/500 captured (Left hand)
# ✅ Sample 322/500 captured (Left hand)
# ✅ Sample 323/500 captured (Left hand)
# ✅ Sample 324/500 captured (Left hand)
# ✅ Sample 325/500 captured (Left hand)
# ✅ Sample 326/500 captured (Left hand)
# ✅ Sample 327/500 captured (Left hand)
# ✅ Sample 328/500 captured (Left hand)
# ✅ Sample 329/500 captured (Left hand)
# ✅ Sample 330/500 captured (Left hand)
# ✅ Sample 331/500 captured (Left hand)
# ✅ Sample 332/500 captured (Left hand)
# ✅ Sample 333/500 captured (Left hand)
# ✅ Sample 334/500 captured (Left hand)
# ✅ Sample 335/500 captured (Left hand)
# ✅ Sample 336/500 captured (Left hand)
# ✅ Sample 337/500 captured (Left hand)
# ✅ Sample 338/500 captured (Left hand)
# ✅ Sample 339/500 captured (Left hand)
# ✅ Sample 340/500 captured (Left hand)
# ✅ Sample 341/500 captured (Left hand)
# ✅ Sample 342/500 captured (Left hand)
# ✅ Sample 343/500 captured (Left hand)
# ✅ Sample 344/500 captured (Left hand)
# ✅ Sample 345/500 captured (Left hand)
# ✅ Sample 346/500 captured (Left hand)
# ✅ Sample 347/500 captured (Left hand)
# ✅ Sample 348/500 captured (Left hand)
# ✅ Sample 349/500 captured (Left hand)
# ✅ Sample 350/500 captured (Left hand)
# ✅ Sample 351/500 captured (Left hand)
# ✅ Sample 352/500 captured (Left hand)
# ✅ Sample 353/500 captured (Left hand)
# ✅ Sample 354/500 captured (Left hand)
# ✅ Sample 355/500 captured (Left hand)
# ✅ Sample 356/500 captured (Left hand)
# ✅ Sample 357/500 captured (Left hand)
# ✅ Sample 358/500 captured (Left hand)
# ✅ Sample 359/500 captured (Left hand)
# ✅ Sample 360/500 captured (Left hand)
# ✅ Sample 361/500 captured (Left hand)
# ✅ Sample 362/500 captured (Left hand)
# ✅ Sample 363/500 captured (Left hand)
# ✅ Sample 364/500 captured (Left hand)
# ✅ Sample 365/500 captured (Left hand)
# ✅ Sample 366/500 captured (Left hand)
# ✅ Sample 367/500 captured (Left hand)
# ✅ Sample 368/500 captured (Left hand)
# ✅ Sample 369/500 captured (Left hand)
# ✅ Sample 370/500 captured (Left hand)
# ✅ Sample 371/500 captured (Left hand)
# ✅ Sample 372/500 captured (Left hand)
# ✅ Sample 373/500 captured (Left hand)
# ✅ Sample 374/500 captured (Left hand)
# ✅ Sample 375/500 captured (Left hand)
# ✅ Sample 376/500 captured (Left hand)
# ✅ Sample 377/500 captured (Left hand)
# ✅ Sample 378/500 captured (Left hand)
# ✅ Sample 379/500 captured (Left hand)
# ✅ Sample 380/500 captured (Left hand)
# ✅ Sample 381/500 captured (Left hand)
# ✅ Sample 382/500 captured (Left hand)
# ✅ Sample 383/500 captured (Left hand)
# ✅ Sample 384/500 captured (Left hand)
# ✅ Sample 385/500 captured (Left hand)
# ✅ Sample 386/500 captured (Left hand)
# ✅ Sample 387/500 captured (Left hand)
# ✅ Sample 388/500 captured (Left hand)
# ✅ Sample 389/500 captured (Left hand)
# ✅ Sample 390/500 captured (Left hand)
# ✅ Sample 391/500 captured (Left hand)
# ✅ Sample 392/500 captured (Left hand)
# ✅ Sample 393/500 captured (Left hand)
# ✅ Sample 394/500 captured (Left hand)
# ✅ Sample 395/500 captured (Left hand)
# ✅ Sample 396/500 captured (Left hand)
# ✅ Sample 397/500 captured (Left hand)
# ✅ Sample 398/500 captured (Left hand)
# ✅ Sample 399/500 captured (Left hand)
# ✅ Sample 400/500 captured (Left hand)
# ✅ Sample 401/500 captured (Left hand)
# ✅ Sample 402/500 captured (Left hand)
# ✅ Sample 403/500 captured (Left hand)
# ✅ Sample 404/500 captured (Left hand)
# ✅ Sample 405/500 captured (Left hand)
# ✅ Sample 406/500 captured (Left hand)
# ✅ Sample 407/500 captured (Left hand)
# ✅ Sample 408/500 captured (Left hand)
# ✅ Sample 409/500 captured (Left hand)
# ✅ Sample 410/500 captured (Left hand)
# ✅ Sample 411/500 captured (Left hand)
# ✅ Sample 412/500 captured (Left hand)
# ✅ Sample 413/500 captured (Left hand)
# ✅ Sample 414/500 captured (Left hand)
# ✅ Sample 415/500 captured (Left hand)
# ✅ Sample 416/500 captured (Left hand)
# ✅ Sample 417/500 captured (Left hand)
# ✅ Sample 418/500 captured (Left hand)
# ✅ Sample 419/500 captured (Left hand)
# ✅ Sample 420/500 captured (Left hand)
# ✅ Sample 421/500 captured (Left hand)
# ✅ Sample 422/500 captured (Left hand)
# ✅ Sample 423/500 captured (Left hand)
# ✅ Sample 424/500 captured (Left hand)
# ✅ Sample 425/500 captured (Left hand)
# ✅ Sample 426/500 captured (Left hand)
# ✅ Sample 427/500 captured (Left hand)
# ✅ Sample 428/500 captured (Left hand)
# ✅ Sample 429/500 captured (Left hand)
# ✅ Sample 430/500 captured (Left hand)
# ✅ Sample 431/500 captured (Left hand)
# ✅ Sample 432/500 captured (Left hand)
# ✅ Sample 433/500 captured (Left hand)
# ✅ Sample 434/500 captured (Left hand)
# ✅ Sample 435/500 captured (Left hand)
# ✅ Sample 436/500 captured (Left hand)
# ✅ Sample 437/500 captured (Left hand)
# ✅ Sample 438/500 captured (Left hand)
# ✅ Sample 439/500 captured (Left hand)
# ✅ Sample 440/500 captured (Left hand)
# ✅ Sample 441/500 captured (Left hand)
# ✅ Sample 442/500 captured (Left hand)
# ✅ Sample 443/500 captured (Left hand)
# ✅ Sample 444/500 captured (Left hand)
# ✅ Sample 445/500 captured (Left hand)
# ✅ Sample 446/500 captured (Left hand)
# ✅ Sample 447/500 captured (Left hand)
# ✅ Sample 448/500 captured (Left hand)
# ✅ Sample 449/500 captured (Left hand)
# ✅ Sample 450/500 captured (Left hand)
# ✅ Sample 451/500 captured (Left hand)
# ✅ Sample 452/500 captured (Left hand)
# ✅ Sample 453/500 captured (Left hand)
# ✅ Sample 454/500 captured (Left hand)
# ✅ Sample 455/500 captured (Left hand)
# ✅ Sample 456/500 captured (Left hand)
# ✅ Sample 457/500 captured (Left hand)
# ✅ Sample 458/500 captured (Left hand)
# ✅ Sample 459/500 captured (Left hand)
# ✅ Sample 460/500 captured (Left hand)
# ✅ Sample 461/500 captured (Left hand)
# ✅ Sample 462/500 captured (Left hand)
# ✅ Sample 463/500 captured (Left hand)
# ✅ Sample 464/500 captured (Left hand)
# ✅ Sample 465/500 captured (Left hand)
# ✅ Sample 466/500 captured (Left hand)
# ✅ Sample 467/500 captured (Left hand)
# ✅ Sample 468/500 captured (Left hand)
# ✅ Sample 469/500 captured (Left hand)
# ✅ Sample 470/500 captured (Left hand)
# ✅ Sample 471/500 captured (Left hand)
# ✅ Sample 472/500 captured (Left hand)
# ✅ Sample 473/500 captured (Left hand)
# ✅ Sample 474/500 captured (Left hand)
# ✅ Sample 475/500 captured (Left hand)
# ✅ Sample 476/500 captured (Left hand)
# ✅ Sample 477/500 captured (Left hand)
# ✅ Sample 478/500 captured (Left hand)
# ✅ Sample 479/500 captured (Left hand)
# ✅ Sample 480/500 captured (Left hand)
# ✅ Sample 481/500 captured (Left hand)
# ✅ Sample 482/500 captured (Left hand)
# ✅ Sample 483/500 captured (Left hand)
# ✅ Sample 484/500 captured (Left hand)
# ✅ Sample 485/500 captured (Left hand)
# ✅ Sample 486/500 captured (Left hand)
# ✅ Sample 487/500 captured (Left hand)
# ✅ Sample 488/500 captured (Left hand)
# ✅ Sample 489/500 captured (Left hand)
# ✅ Sample 490/500 captured (Left hand)
# ✅ Sample 491/500 captured (Left hand)
# ✅ Sample 492/500 captured (Left hand)
# ✅ Sample 493/500 captured (Left hand)
# ✅ Sample 494/500 captured (Left hand)
# ✅ Sample 495/500 captured (Left hand)
# ✅ Sample 496/500 captured (Left hand)
# ✅ Sample 497/500 captured (Left hand)
# ✅ Sample 498/500 captured (Left hand)
# ✅ Sample 499/500 captured (Left hand)
# ✅ Sample 500/500 captured (Left hand)
#
# CSV saved: ../data/raw/question_g.csv (1000 total rows)

# %%
# question 
output_csv = '../data/raw/question_k.csv'
capture_hands_to_csv_auto(output_csv, "question", max_samples=500)
# Out:
# I0000 00:00:1762269216.325409  108205 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762269216.329784  109124 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-33-generic)
# W0000 00:00:1762269216.356373  109108 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762269216.407356  109115 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera is ready. Capturing every 0.2 seconds. Press 'q' to quit.
# ✅ Sample 1/500 captured (Left hand)
# ✅ Sample 2/500 captured (Left hand)
# ✅ Sample 3/500 captured (Left hand)
# ✅ Sample 4/500 captured (Left hand)
# ✅ Sample 5/500 captured (Left hand)
# ✅ Sample 6/500 captured (Left hand)
# ✅ Sample 7/500 captured (Left hand)
# ✅ Sample 8/500 captured (Left hand)
# ✅ Sample 9/500 captured (Left hand)
# ✅ Sample 10/500 captured (Left hand)
# ✅ Sample 11/500 captured (Left hand)
# ✅ Sample 12/500 captured (Left hand)
# ✅ Sample 13/500 captured (Left hand)
# ✅ Sample 14/500 captured (Left hand)
# ✅ Sample 15/500 captured (Left hand)
# ✅ Sample 16/500 captured (Left hand)
# ✅ Sample 17/500 captured (Left hand)
# ✅ Sample 18/500 captured (Left hand)
# ✅ Sample 19/500 captured (Left hand)
# ✅ Sample 20/500 captured (Left hand)
# ✅ Sample 21/500 captured (Left hand)
# ✅ Sample 22/500 captured (Left hand)
# ✅ Sample 23/500 captured (Left hand)
# ✅ Sample 24/500 captured (Left hand)
# ✅ Sample 25/500 captured (Left hand)
# ✅ Sample 26/500 captured (Left hand)
# ✅ Sample 27/500 captured (Left hand)
# ✅ Sample 28/500 captured (Left hand)
# ✅ Sample 29/500 captured (Left hand)
# ✅ Sample 30/500 captured (Left hand)
# ✅ Sample 31/500 captured (Left hand)
# ✅ Sample 32/500 captured (Left hand)
# ✅ Sample 33/500 captured (Left hand)
# ✅ Sample 34/500 captured (Left hand)
# ✅ Sample 35/500 captured (Left hand)
# ✅ Sample 36/500 captured (Left hand)
# ✅ Sample 37/500 captured (Left hand)
# ✅ Sample 38/500 captured (Left hand)
# ✅ Sample 39/500 captured (Left hand)
# ✅ Sample 40/500 captured (Left hand)
# ✅ Sample 41/500 captured (Left hand)
# ✅ Sample 42/500 captured (Left hand)
# ✅ Sample 43/500 captured (Left hand)
# ✅ Sample 44/500 captured (Left hand)
# ✅ Sample 45/500 captured (Left hand)
# ✅ Sample 46/500 captured (Left hand)
# ✅ Sample 47/500 captured (Left hand)
# ✅ Sample 48/500 captured (Left hand)
# ✅ Sample 49/500 captured (Left hand)
# ✅ Sample 50/500 captured (Left hand)
# ✅ Sample 51/500 captured (Left hand)
# ✅ Sample 52/500 captured (Left hand)
# ✅ Sample 53/500 captured (Left hand)
# ✅ Sample 54/500 captured (Left hand)
# ✅ Sample 55/500 captured (Left hand)
# ✅ Sample 56/500 captured (Left hand)
# ✅ Sample 57/500 captured (Left hand)
# ✅ Sample 58/500 captured (Left hand)
# ✅ Sample 59/500 captured (Left hand)
# ✅ Sample 60/500 captured (Left hand)
# ✅ Sample 61/500 captured (Left hand)
# ✅ Sample 62/500 captured (Left hand)
# ✅ Sample 63/500 captured (Left hand)
# ✅ Sample 64/500 captured (Left hand)
# ✅ Sample 65/500 captured (Left hand)
# ✅ Sample 66/500 captured (Left hand)
# ✅ Sample 67/500 captured (Left hand)
# ✅ Sample 68/500 captured (Left hand)
# ✅ Sample 69/500 captured (Left hand)
# ✅ Sample 70/500 captured (Left hand)
# ✅ Sample 71/500 captured (Left hand)
# ✅ Sample 72/500 captured (Left hand)
# ✅ Sample 73/500 captured (Left hand)
# ✅ Sample 74/500 captured (Left hand)
# ✅ Sample 75/500 captured (Left hand)
# ✅ Sample 76/500 captured (Left hand)
# ✅ Sample 77/500 captured (Left hand)
# ✅ Sample 78/500 captured (Left hand)
# ✅ Sample 79/500 captured (Left hand)
# ✅ Sample 80/500 captured (Left hand)
# ✅ Sample 81/500 captured (Left hand)
# ✅ Sample 82/500 captured (Left hand)
# ✅ Sample 83/500 captured (Left hand)
# ✅ Sample 84/500 captured (Left hand)
# ✅ Sample 85/500 captured (Left hand)
# ✅ Sample 86/500 captured (Left hand)
# ✅ Sample 87/500 captured (Left hand)
# ✅ Sample 88/500 captured (Left hand)
# ✅ Sample 89/500 captured (Left hand)
# ✅ Sample 90/500 captured (Left hand)
# ✅ Sample 91/500 captured (Left hand)
# ✅ Sample 92/500 captured (Left hand)
# ✅ Sample 93/500 captured (Left hand)
# ✅ Sample 94/500 captured (Left hand)
# ✅ Sample 95/500 captured (Left hand)
# ✅ Sample 96/500 captured (Left hand)
# ✅ Sample 97/500 captured (Left hand)
# ✅ Sample 98/500 captured (Left hand)
# ✅ Sample 99/500 captured (Left hand)
# ✅ Sample 100/500 captured (Left hand)
# ✅ Sample 101/500 captured (Left hand)
# ✅ Sample 102/500 captured (Left hand)
# ✅ Sample 103/500 captured (Left hand)
# ✅ Sample 104/500 captured (Left hand)
# ✅ Sample 105/500 captured (Left hand)
# ✅ Sample 106/500 captured (Left hand)
# ✅ Sample 107/500 captured (Left hand)
# ✅ Sample 108/500 captured (Left hand)
# ✅ Sample 109/500 captured (Left hand)
# ✅ Sample 110/500 captured (Left hand)
# ✅ Sample 111/500 captured (Left hand)
# ✅ Sample 112/500 captured (Left hand)
# ✅ Sample 113/500 captured (Left hand)
# ✅ Sample 114/500 captured (Left hand)
# ✅ Sample 115/500 captured (Left hand)
# ✅ Sample 116/500 captured (Left hand)
# ✅ Sample 117/500 captured (Left hand)
# ✅ Sample 118/500 captured (Left hand)
# ✅ Sample 119/500 captured (Left hand)
# ✅ Sample 120/500 captured (Left hand)
# ✅ Sample 121/500 captured (Left hand)
# ✅ Sample 122/500 captured (Left hand)
# ✅ Sample 123/500 captured (Left hand)
# ✅ Sample 124/500 captured (Left hand)
# ✅ Sample 125/500 captured (Left hand)
# ✅ Sample 126/500 captured (Left hand)
# ✅ Sample 127/500 captured (Left hand)
# ✅ Sample 128/500 captured (Left hand)
# ✅ Sample 129/500 captured (Left hand)
# ✅ Sample 130/500 captured (Left hand)
# ✅ Sample 131/500 captured (Left hand)
# ✅ Sample 132/500 captured (Left hand)
# ✅ Sample 133/500 captured (Left hand)
# ✅ Sample 134/500 captured (Left hand)
# ✅ Sample 135/500 captured (Left hand)
# ✅ Sample 136/500 captured (Left hand)
# ✅ Sample 137/500 captured (Left hand)
# ✅ Sample 138/500 captured (Left hand)
# ✅ Sample 139/500 captured (Left hand)
# ✅ Sample 140/500 captured (Left hand)
# ✅ Sample 141/500 captured (Left hand)
# ✅ Sample 142/500 captured (Left hand)
# ✅ Sample 143/500 captured (Left hand)
# ✅ Sample 144/500 captured (Left hand)
# ✅ Sample 145/500 captured (Left hand)
# ✅ Sample 146/500 captured (Left hand)
# ✅ Sample 147/500 captured (Left hand)
# ✅ Sample 148/500 captured (Left hand)
# ✅ Sample 149/500 captured (Left hand)
# ✅ Sample 150/500 captured (Left hand)
# ✅ Sample 151/500 captured (Left hand)
# ✅ Sample 152/500 captured (Left hand)
# ✅ Sample 153/500 captured (Left hand)
# ✅ Sample 154/500 captured (Left hand)
# ✅ Sample 155/500 captured (Left hand)
# ✅ Sample 156/500 captured (Left hand)
# ✅ Sample 157/500 captured (Left hand)
# ✅ Sample 158/500 captured (Left hand)
# ✅ Sample 159/500 captured (Left hand)
# ✅ Sample 160/500 captured (Left hand)
# ✅ Sample 161/500 captured (Left hand)
# ✅ Sample 162/500 captured (Left hand)
# ✅ Sample 163/500 captured (Left hand)
# ✅ Sample 164/500 captured (Left hand)
# ✅ Sample 165/500 captured (Left hand)
# ✅ Sample 166/500 captured (Left hand)
# ✅ Sample 167/500 captured (Left hand)
# ✅ Sample 168/500 captured (Left hand)
# ✅ Sample 169/500 captured (Left hand)
# ✅ Sample 170/500 captured (Left hand)
# ✅ Sample 171/500 captured (Left hand)
# ✅ Sample 172/500 captured (Left hand)
# ✅ Sample 173/500 captured (Left hand)
# ✅ Sample 174/500 captured (Left hand)
# ✅ Sample 175/500 captured (Left hand)
# ✅ Sample 176/500 captured (Left hand)
# ✅ Sample 177/500 captured (Left hand)
# ✅ Sample 178/500 captured (Left hand)
# ✅ Sample 179/500 captured (Left hand)
# ✅ Sample 180/500 captured (Left hand)
# ✅ Sample 181/500 captured (Left hand)
# ✅ Sample 182/500 captured (Left hand)
# ✅ Sample 183/500 captured (Left hand)
# ✅ Sample 184/500 captured (Left hand)
# ✅ Sample 185/500 captured (Left hand)
# ✅ Sample 186/500 captured (Left hand)
# ✅ Sample 187/500 captured (Left hand)
# ✅ Sample 188/500 captured (Left hand)
# ✅ Sample 189/500 captured (Left hand)
# ✅ Sample 190/500 captured (Left hand)
# ✅ Sample 191/500 captured (Left hand)
# ✅ Sample 192/500 captured (Left hand)
# ✅ Sample 193/500 captured (Left hand)
# ✅ Sample 194/500 captured (Left hand)
# ✅ Sample 195/500 captured (Left hand)
# ✅ Sample 196/500 captured (Left hand)
# ✅ Sample 197/500 captured (Left hand)
# ✅ Sample 198/500 captured (Left hand)
# ✅ Sample 199/500 captured (Left hand)
# ✅ Sample 200/500 captured (Left hand)
# ✅ Sample 201/500 captured (Left hand)
# ✅ Sample 202/500 captured (Left hand)
# ✅ Sample 203/500 captured (Left hand)
# ✅ Sample 204/500 captured (Left hand)
# ✅ Sample 205/500 captured (Left hand)
# ✅ Sample 206/500 captured (Left hand)
# ✅ Sample 207/500 captured (Left hand)
# ✅ Sample 208/500 captured (Left hand)
# ✅ Sample 209/500 captured (Left hand)
# ✅ Sample 210/500 captured (Left hand)
# ✅ Sample 211/500 captured (Left hand)
# ✅ Sample 212/500 captured (Left hand)
# ✅ Sample 213/500 captured (Left hand)
# ✅ Sample 214/500 captured (Left hand)
# ✅ Sample 215/500 captured (Left hand)
# ✅ Sample 216/500 captured (Left hand)
# ✅ Sample 217/500 captured (Left hand)
# ✅ Sample 218/500 captured (Left hand)
# ✅ Sample 219/500 captured (Left hand)
# ✅ Sample 220/500 captured (Left hand)
# ✅ Sample 221/500 captured (Left hand)
# ✅ Sample 222/500 captured (Left hand)
# ✅ Sample 223/500 captured (Left hand)
# ✅ Sample 224/500 captured (Left hand)
# ✅ Sample 225/500 captured (Left hand)
# ✅ Sample 226/500 captured (Left hand)
# ✅ Sample 227/500 captured (Left hand)
# ✅ Sample 228/500 captured (Left hand)
# ✅ Sample 229/500 captured (Left hand)
# ✅ Sample 230/500 captured (Left hand)
# ✅ Sample 231/500 captured (Left hand)
# ✅ Sample 232/500 captured (Left hand)
# ✅ Sample 233/500 captured (Left hand)
# ✅ Sample 234/500 captured (Left hand)
# ✅ Sample 235/500 captured (Left hand)
# ✅ Sample 236/500 captured (Left hand)
# ✅ Sample 237/500 captured (Left hand)
# ✅ Sample 238/500 captured (Left hand)
# ✅ Sample 239/500 captured (Left hand)
# ✅ Sample 240/500 captured (Left hand)
# ✅ Sample 241/500 captured (Left hand)
# ✅ Sample 242/500 captured (Left hand)
# ✅ Sample 243/500 captured (Left hand)
# ✅ Sample 244/500 captured (Left hand)
# ✅ Sample 245/500 captured (Left hand)
# ✅ Sample 246/500 captured (Left hand)
# ✅ Sample 247/500 captured (Left hand)
# ✅ Sample 248/500 captured (Left hand)
# ✅ Sample 249/500 captured (Left hand)
# ✅ Sample 250/500 captured (Left hand)
# ✅ Sample 251/500 captured (Left hand)
# ✅ Sample 252/500 captured (Left hand)
# ✅ Sample 253/500 captured (Left hand)
# ✅ Sample 254/500 captured (Left hand)
# ✅ Sample 255/500 captured (Left hand)
# ✅ Sample 256/500 captured (Left hand)
# ✅ Sample 257/500 captured (Left hand)
# ✅ Sample 258/500 captured (Left hand)
# ✅ Sample 259/500 captured (Left hand)
# ✅ Sample 260/500 captured (Left hand)
# ✅ Sample 261/500 captured (Left hand)
# ✅ Sample 262/500 captured (Left hand)
# ✅ Sample 263/500 captured (Left hand)
# ✅ Sample 264/500 captured (Left hand)
# ✅ Sample 265/500 captured (Left hand)
# ✅ Sample 266/500 captured (Left hand)
# ✅ Sample 267/500 captured (Left hand)
# ✅ Sample 268/500 captured (Left hand)
# ✅ Sample 269/500 captured (Left hand)
# ✅ Sample 270/500 captured (Left hand)
# ✅ Sample 271/500 captured (Left hand)
# ✅ Sample 272/500 captured (Left hand)
# ✅ Sample 273/500 captured (Left hand)
# ✅ Sample 274/500 captured (Left hand)
# ✅ Sample 275/500 captured (Left hand)
# ✅ Sample 276/500 captured (Left hand)
# ✅ Sample 277/500 captured (Left hand)
# ✅ Sample 278/500 captured (Left hand)
# ✅ Sample 279/500 captured (Left hand)
# ✅ Sample 280/500 captured (Left hand)
# ✅ Sample 281/500 captured (Left hand)
# ✅ Sample 282/500 captured (Left hand)
# ✅ Sample 283/500 captured (Left hand)
# ✅ Sample 284/500 captured (Left hand)
# ✅ Sample 285/500 captured (Left hand)
# ✅ Sample 286/500 captured (Left hand)
# ✅ Sample 287/500 captured (Left hand)
# ✅ Sample 288/500 captured (Left hand)
# ✅ Sample 289/500 captured (Left hand)
# ✅ Sample 290/500 captured (Left hand)
# ✅ Sample 291/500 captured (Left hand)
# ✅ Sample 292/500 captured (Left hand)
# ✅ Sample 293/500 captured (Left hand)
# ✅ Sample 294/500 captured (Left hand)
# ✅ Sample 295/500 captured (Left hand)
# ✅ Sample 296/500 captured (Left hand)
# ✅ Sample 297/500 captured (Left hand)
# ✅ Sample 298/500 captured (Left hand)
# ✅ Sample 299/500 captured (Left hand)
# ✅ Sample 300/500 captured (Left hand)
# ✅ Sample 301/500 captured (Left hand)
# ✅ Sample 302/500 captured (Left hand)
# ✅ Sample 303/500 captured (Left hand)
# ✅ Sample 304/500 captured (Left hand)
# ✅ Sample 305/500 captured (Left hand)
# ✅ Sample 306/500 captured (Left hand)
# ✅ Sample 307/500 captured (Left hand)
# ✅ Sample 308/500 captured (Left hand)
# ✅ Sample 309/500 captured (Left hand)
# ✅ Sample 310/500 captured (Left hand)
# ✅ Sample 311/500 captured (Left hand)
# ✅ Sample 312/500 captured (Left hand)
# ✅ Sample 313/500 captured (Left hand)
# ✅ Sample 314/500 captured (Left hand)
# ✅ Sample 315/500 captured (Left hand)
# ✅ Sample 316/500 captured (Left hand)
# ✅ Sample 317/500 captured (Right hand)
# ✅ Sample 318/500 captured (Left hand)
# ✅ Sample 319/500 captured (Left hand)
# ✅ Sample 320/500 captured (Left hand)
# ✅ Sample 321/500 captured (Left hand)
# ✅ Sample 322/500 captured (Left hand)
# ✅ Sample 323/500 captured (Left hand)
# ✅ Sample 324/500 captured (Left hand)
# ✅ Sample 325/500 captured (Left hand)
# ✅ Sample 326/500 captured (Left hand)
# ✅ Sample 327/500 captured (Left hand)
# ✅ Sample 328/500 captured (Left hand)
# ✅ Sample 329/500 captured (Left hand)
# ✅ Sample 330/500 captured (Left hand)
# ✅ Sample 331/500 captured (Left hand)
# ✅ Sample 332/500 captured (Left hand)
# ✅ Sample 333/500 captured (Left hand)
# ✅ Sample 334/500 captured (Left hand)
# ✅ Sample 335/500 captured (Left hand)
# ✅ Sample 336/500 captured (Left hand)
# ✅ Sample 337/500 captured (Left hand)
# ✅ Sample 338/500 captured (Left hand)
# ✅ Sample 339/500 captured (Left hand)
# ✅ Sample 340/500 captured (Left hand)
# ✅ Sample 341/500 captured (Left hand)
# ✅ Sample 342/500 captured (Left hand)
# ✅ Sample 343/500 captured (Left hand)
# ✅ Sample 344/500 captured (Left hand)
# ✅ Sample 345/500 captured (Left hand)
# ✅ Sample 346/500 captured (Left hand)
# ✅ Sample 347/500 captured (Left hand)
# ✅ Sample 348/500 captured (Left hand)
# ✅ Sample 349/500 captured (Left hand)
# ✅ Sample 350/500 captured (Left hand)
# ✅ Sample 351/500 captured (Left hand)
# ✅ Sample 352/500 captured (Left hand)
# ✅ Sample 353/500 captured (Left hand)
# ✅ Sample 354/500 captured (Left hand)
# ✅ Sample 355/500 captured (Left hand)
# ✅ Sample 356/500 captured (Left hand)
# ✅ Sample 357/500 captured (Left hand)
# ✅ Sample 358/500 captured (Left hand)
# ✅ Sample 359/500 captured (Left hand)
# ✅ Sample 360/500 captured (Left hand)
# ✅ Sample 361/500 captured (Left hand)
# ✅ Sample 362/500 captured (Left hand)
# ✅ Sample 363/500 captured (Left hand)
# ✅ Sample 364/500 captured (Left hand)
# ✅ Sample 365/500 captured (Left hand)
# ✅ Sample 366/500 captured (Left hand)
# ✅ Sample 367/500 captured (Left hand)
# ✅ Sample 368/500 captured (Left hand)
# ✅ Sample 369/500 captured (Left hand)
# ✅ Sample 370/500 captured (Left hand)
# ✅ Sample 371/500 captured (Left hand)
# ✅ Sample 372/500 captured (Left hand)
# ✅ Sample 373/500 captured (Left hand)
# ✅ Sample 374/500 captured (Left hand)
# ✅ Sample 375/500 captured (Left hand)
# ✅ Sample 376/500 captured (Left hand)
# ✅ Sample 377/500 captured (Left hand)
# ✅ Sample 378/500 captured (Left hand)
# ✅ Sample 379/500 captured (Left hand)
# ✅ Sample 380/500 captured (Left hand)
# ✅ Sample 381/500 captured (Left hand)
# ✅ Sample 382/500 captured (Left hand)
# ✅ Sample 383/500 captured (Left hand)
# ✅ Sample 384/500 captured (Left hand)
# ✅ Sample 385/500 captured (Left hand)
# ✅ Sample 386/500 captured (Left hand)
# ✅ Sample 387/500 captured (Left hand)
# ✅ Sample 388/500 captured (Left hand)
# ✅ Sample 389/500 captured (Left hand)
# ✅ Sample 390/500 captured (Left hand)
# ✅ Sample 391/500 captured (Left hand)
# ✅ Sample 392/500 captured (Left hand)
# ✅ Sample 393/500 captured (Left hand)
# ✅ Sample 394/500 captured (Left hand)
# ✅ Sample 395/500 captured (Left hand)
# ✅ Sample 396/500 captured (Left hand)
# ✅ Sample 397/500 captured (Left hand)
# ✅ Sample 398/500 captured (Left hand)
# ✅ Sample 399/500 captured (Left hand)
# ✅ Sample 400/500 captured (Left hand)
# ✅ Sample 401/500 captured (Left hand)
# ✅ Sample 402/500 captured (Left hand)
# ✅ Sample 403/500 captured (Left hand)
# ✅ Sample 404/500 captured (Left hand)
# ✅ Sample 405/500 captured (Left hand)
# ✅ Sample 406/500 captured (Left hand)
# ✅ Sample 407/500 captured (Left hand)
# ✅ Sample 408/500 captured (Left hand)
# ✅ Sample 409/500 captured (Left hand)
# ✅ Sample 410/500 captured (Left hand)
# ✅ Sample 411/500 captured (Left hand)
# ✅ Sample 412/500 captured (Left hand)
# ✅ Sample 413/500 captured (Left hand)
# ✅ Sample 414/500 captured (Left hand)
# ✅ Sample 415/500 captured (Left hand)
# ✅ Sample 416/500 captured (Left hand)
# ✅ Sample 417/500 captured (Left hand)
# ✅ Sample 418/500 captured (Left hand)
# ✅ Sample 419/500 captured (Left hand)
# ✅ Sample 420/500 captured (Left hand)
# ✅ Sample 421/500 captured (Left hand)
# ✅ Sample 422/500 captured (Left hand)
# ✅ Sample 423/500 captured (Left hand)
# ✅ Sample 424/500 captured (Left hand)
# ✅ Sample 425/500 captured (Left hand)
# ✅ Sample 426/500 captured (Left hand)
# ✅ Sample 427/500 captured (Left hand)
# ✅ Sample 428/500 captured (Left hand)
# ✅ Sample 429/500 captured (Left hand)
# ✅ Sample 430/500 captured (Left hand)
# ✅ Sample 431/500 captured (Left hand)
# ✅ Sample 432/500 captured (Left hand)
# ✅ Sample 433/500 captured (Left hand)
# ✅ Sample 434/500 captured (Left hand)
# ✅ Sample 435/500 captured (Left hand)
# ✅ Sample 436/500 captured (Left hand)
# ✅ Sample 437/500 captured (Left hand)
# ✅ Sample 438/500 captured (Left hand)
# ✅ Sample 439/500 captured (Left hand)
# ✅ Sample 440/500 captured (Left hand)
# ✅ Sample 441/500 captured (Left hand)
# ✅ Sample 442/500 captured (Left hand)
# ✅ Sample 443/500 captured (Left hand)
# ✅ Sample 444/500 captured (Left hand)
# ✅ Sample 445/500 captured (Left hand)
# ✅ Sample 446/500 captured (Left hand)
# ✅ Sample 447/500 captured (Left hand)
# ✅ Sample 448/500 captured (Left hand)
# ✅ Sample 449/500 captured (Left hand)
# ✅ Sample 450/500 captured (Left hand)
# ✅ Sample 451/500 captured (Left hand)
# ✅ Sample 452/500 captured (Left hand)
# ✅ Sample 453/500 captured (Left hand)
# ✅ Sample 454/500 captured (Left hand)
# ✅ Sample 455/500 captured (Left hand)
# ✅ Sample 456/500 captured (Left hand)
# ✅ Sample 457/500 captured (Left hand)
# ✅ Sample 458/500 captured (Left hand)
# ✅ Sample 459/500 captured (Left hand)
# ✅ Sample 460/500 captured (Left hand)
# ✅ Sample 461/500 captured (Left hand)
# ✅ Sample 462/500 captured (Left hand)
# ✅ Sample 463/500 captured (Left hand)
# ✅ Sample 464/500 captured (Left hand)
# ✅ Sample 465/500 captured (Left hand)
# ✅ Sample 466/500 captured (Left hand)
# ✅ Sample 467/500 captured (Left hand)
# ✅ Sample 468/500 captured (Left hand)
# ✅ Sample 469/500 captured (Left hand)
# ✅ Sample 470/500 captured (Left hand)
# ✅ Sample 471/500 captured (Left hand)
# ✅ Sample 472/500 captured (Left hand)
# ✅ Sample 473/500 captured (Left hand)
# ✅ Sample 474/500 captured (Left hand)
# ✅ Sample 475/500 captured (Left hand)
# ✅ Sample 476/500 captured (Left hand)
# ✅ Sample 477/500 captured (Left hand)
# ✅ Sample 478/500 captured (Left hand)
# ✅ Sample 479/500 captured (Left hand)
# ✅ Sample 480/500 captured (Left hand)
# ✅ Sample 481/500 captured (Left hand)
# ✅ Sample 482/500 captured (Left hand)
# ✅ Sample 483/500 captured (Left hand)
# ✅ Sample 484/500 captured (Left hand)
# ✅ Sample 485/500 captured (Left hand)
# ✅ Sample 486/500 captured (Left hand)
# ✅ Sample 487/500 captured (Left hand)
# ✅ Sample 488/500 captured (Left hand)
# ✅ Sample 489/500 captured (Left hand)
# ✅ Sample 490/500 captured (Left hand)
# ✅ Sample 491/500 captured (Left hand)
# ✅ Sample 492/500 captured (Left hand)
# ✅ Sample 493/500 captured (Left hand)
# ✅ Sample 494/500 captured (Left hand)
# ✅ Sample 495/500 captured (Left hand)
# ✅ Sample 496/500 captured (Left hand)
# ✅ Sample 497/500 captured (Left hand)
# ✅ Sample 498/500 captured (Left hand)
# ✅ Sample 499/500 captured (Left hand)
# ✅ Sample 500/500 captured (Left hand)
#
# CSV saved: ../data/raw/question_k.csv (1000 total rows)

# %%
# import pandas as pd 

# output_csv = '../data/raw/question_k.csv'

# q1 = pd.read_csv('../data/raw/question_k.csv')
# q1.describe()
# Out:
#                 x0           y0           x1           y1           x2  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.496899     0.628840     0.496949     0.585485     0.494742
# std       0.187793     0.174798     0.165382     0.168458     0.155490
# min       0.108517     0.225408     0.133582     0.202578     0.146073
# 25%       0.338634     0.477619     0.361597     0.448473     0.370342
# 50%       0.492048     0.641377     0.493196     0.599417     0.491363
# 75%       0.633567     0.779756     0.625887     0.728366     0.621956
# max       0.903648     0.962038     0.854976     0.914158     0.834095
#
#                 y2           x3           y3           x4           y4  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean      0.539847     0.489820     0.507724     0.483858     0.492071  ...
# std       0.165622     0.153945     0.164765     0.162539     0.167239  ...
# min       0.159947     0.145823     0.125665     0.128399     0.098287  ...
# 25%       0.408555     0.371966     0.380125     0.357179     0.360855  ...
# 50%       0.551510     0.485651     0.517277     0.477396     0.505187  ...
# 75%       0.678309     0.625306     0.644466     0.630654     0.633196  ...
# max       0.870978     0.824032     0.841082     0.834174     0.823749  ...
#
#                y16          x17          y17          x18          y18  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.551277     0.477771     0.526332     0.474120     0.530387
# std       0.173640     0.205625     0.183641     0.189133     0.182721
# min       0.161288     0.063355     0.094030     0.091004     0.088609
# 25%       0.411869     0.302466     0.373035     0.321385     0.373490
# 50%       0.562928     0.469880     0.541540     0.460400     0.545840
# 75%       0.697441     0.642113     0.687354     0.650196     0.692520
# max       0.886283     0.922594     0.855108     0.862460     0.865086
#
#                x19          y19          x20          y20  is_right_hand
# count  1000.000000  1000.000000  1000.000000  1000.000000    1000.000000
# mean      0.478428     0.556722     0.483029     0.569233       0.501000
# std       0.184745     0.180682     0.186662     0.178185       0.500249
# min       0.103515     0.124736     0.102138     0.153764       0.000000
# 25%       0.329530     0.401133     0.331068     0.415712       0.000000
# 50%       0.464723     0.574988     0.471375     0.584483       1.000000
# 75%       0.648581     0.716270     0.649887     0.725013       1.000000
# max       0.859038     0.890946     0.876064     0.901559       1.000000
#
# [8 rows x 43 columns]

# %%
# don
output_csv = '../data/raw/don_g.csv'
capture_hands_to_csv_auto(output_csv, "don", max_samples=500)
# Out:
# I0000 00:00:1762269994.051455  110229 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762269994.056463  110466 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-33-generic)
# W0000 00:00:1762269994.113418  110450 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762269994.151350  110462 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera is ready. Capturing every 0.1 seconds. Press 'q' to quit.
# ✅ Sample 1/500 captured (Left hand)
# ✅ Sample 2/500 captured (Left hand)
# ✅ Sample 3/500 captured (Left hand)
# ✅ Sample 4/500 captured (Left hand)
# ✅ Sample 5/500 captured (Left hand)
# ✅ Sample 6/500 captured (Left hand)
# ✅ Sample 7/500 captured (Left hand)
# ✅ Sample 8/500 captured (Left hand)
# ✅ Sample 9/500 captured (Left hand)
# ✅ Sample 10/500 captured (Left hand)
# ✅ Sample 11/500 captured (Left hand)
# ✅ Sample 12/500 captured (Left hand)
# ✅ Sample 13/500 captured (Left hand)
# ✅ Sample 14/500 captured (Left hand)
# ✅ Sample 15/500 captured (Left hand)
# ✅ Sample 16/500 captured (Left hand)
# ✅ Sample 17/500 captured (Left hand)
# ✅ Sample 18/500 captured (Left hand)
# ✅ Sample 19/500 captured (Left hand)
# ✅ Sample 20/500 captured (Left hand)
# ✅ Sample 21/500 captured (Left hand)
# ✅ Sample 22/500 captured (Left hand)
# ✅ Sample 23/500 captured (Left hand)
# ✅ Sample 24/500 captured (Left hand)
# ✅ Sample 25/500 captured (Left hand)
# ✅ Sample 26/500 captured (Left hand)
# ✅ Sample 27/500 captured (Left hand)
# ✅ Sample 28/500 captured (Left hand)
# ✅ Sample 29/500 captured (Left hand)
# ✅ Sample 30/500 captured (Left hand)
# ✅ Sample 31/500 captured (Left hand)
# ✅ Sample 32/500 captured (Left hand)
# ✅ Sample 33/500 captured (Left hand)
# ✅ Sample 34/500 captured (Left hand)
# ✅ Sample 35/500 captured (Left hand)
# ✅ Sample 36/500 captured (Left hand)
# ✅ Sample 37/500 captured (Left hand)
# ✅ Sample 38/500 captured (Left hand)
# ✅ Sample 39/500 captured (Left hand)
# ✅ Sample 40/500 captured (Left hand)
# ✅ Sample 41/500 captured (Left hand)
# ✅ Sample 42/500 captured (Left hand)
# ✅ Sample 43/500 captured (Left hand)
# ✅ Sample 44/500 captured (Left hand)
# ✅ Sample 45/500 captured (Left hand)
# ✅ Sample 46/500 captured (Left hand)
# ✅ Sample 47/500 captured (Left hand)
# ✅ Sample 48/500 captured (Left hand)
# ✅ Sample 49/500 captured (Left hand)
# ✅ Sample 50/500 captured (Left hand)
# ✅ Sample 51/500 captured (Left hand)
# ✅ Sample 52/500 captured (Left hand)
# ✅ Sample 53/500 captured (Left hand)
# ✅ Sample 54/500 captured (Left hand)
# ✅ Sample 55/500 captured (Left hand)
# ✅ Sample 56/500 captured (Left hand)
# ✅ Sample 57/500 captured (Left hand)
# ✅ Sample 58/500 captured (Left hand)
# ✅ Sample 59/500 captured (Left hand)
# ✅ Sample 60/500 captured (Left hand)
# ✅ Sample 61/500 captured (Left hand)
# ✅ Sample 62/500 captured (Left hand)
# ✅ Sample 63/500 captured (Left hand)
# ✅ Sample 64/500 captured (Left hand)
# ✅ Sample 65/500 captured (Left hand)
# ✅ Sample 66/500 captured (Left hand)
# ✅ Sample 67/500 captured (Left hand)
# ✅ Sample 68/500 captured (Left hand)
# ✅ Sample 69/500 captured (Left hand)
# ✅ Sample 70/500 captured (Left hand)
# ✅ Sample 71/500 captured (Left hand)
# ✅ Sample 72/500 captured (Left hand)
# ✅ Sample 73/500 captured (Left hand)
# ✅ Sample 74/500 captured (Left hand)
# ✅ Sample 75/500 captured (Left hand)
# ✅ Sample 76/500 captured (Left hand)
# ✅ Sample 77/500 captured (Left hand)
# ✅ Sample 78/500 captured (Left hand)
# ✅ Sample 79/500 captured (Left hand)
# ✅ Sample 80/500 captured (Left hand)
# ✅ Sample 81/500 captured (Left hand)
# ✅ Sample 82/500 captured (Left hand)
# ✅ Sample 83/500 captured (Left hand)
# ✅ Sample 84/500 captured (Left hand)
# ✅ Sample 85/500 captured (Left hand)
# ✅ Sample 86/500 captured (Left hand)
# ✅ Sample 87/500 captured (Left hand)
# ✅ Sample 88/500 captured (Left hand)
# ✅ Sample 89/500 captured (Left hand)
# ✅ Sample 90/500 captured (Left hand)
# ✅ Sample 91/500 captured (Left hand)
# ✅ Sample 92/500 captured (Left hand)
# ✅ Sample 93/500 captured (Left hand)
# ✅ Sample 94/500 captured (Left hand)
# ✅ Sample 95/500 captured (Left hand)
# ✅ Sample 96/500 captured (Left hand)
# ✅ Sample 97/500 captured (Left hand)
# ✅ Sample 98/500 captured (Left hand)
# ✅ Sample 99/500 captured (Left hand)
# ✅ Sample 100/500 captured (Left hand)
# ✅ Sample 101/500 captured (Left hand)
# ✅ Sample 102/500 captured (Left hand)
# ✅ Sample 103/500 captured (Left hand)
# ✅ Sample 104/500 captured (Left hand)
# ✅ Sample 105/500 captured (Left hand)
# ✅ Sample 106/500 captured (Left hand)
# ✅ Sample 107/500 captured (Left hand)
# ✅ Sample 108/500 captured (Left hand)
# ✅ Sample 109/500 captured (Left hand)
# ✅ Sample 110/500 captured (Left hand)
# ✅ Sample 111/500 captured (Left hand)
# ✅ Sample 112/500 captured (Left hand)
# ✅ Sample 113/500 captured (Left hand)
# ✅ Sample 114/500 captured (Left hand)
# ✅ Sample 115/500 captured (Left hand)
# ✅ Sample 116/500 captured (Left hand)
# ✅ Sample 117/500 captured (Left hand)
# ✅ Sample 118/500 captured (Left hand)
# ✅ Sample 119/500 captured (Left hand)
# ✅ Sample 120/500 captured (Left hand)
# ✅ Sample 121/500 captured (Left hand)
# ✅ Sample 122/500 captured (Left hand)
# ✅ Sample 123/500 captured (Left hand)
# ✅ Sample 124/500 captured (Left hand)
# ✅ Sample 125/500 captured (Left hand)
# ✅ Sample 126/500 captured (Left hand)
# ✅ Sample 127/500 captured (Left hand)
# ✅ Sample 128/500 captured (Left hand)
# ✅ Sample 129/500 captured (Left hand)
# ✅ Sample 130/500 captured (Left hand)
# ✅ Sample 131/500 captured (Left hand)
# ✅ Sample 132/500 captured (Left hand)
# ✅ Sample 133/500 captured (Left hand)
# ✅ Sample 134/500 captured (Left hand)
# ✅ Sample 135/500 captured (Left hand)
# ✅ Sample 136/500 captured (Left hand)
# ✅ Sample 137/500 captured (Left hand)
# ✅ Sample 138/500 captured (Left hand)
# ✅ Sample 139/500 captured (Left hand)
# ✅ Sample 140/500 captured (Left hand)
# ✅ Sample 141/500 captured (Left hand)
# ✅ Sample 142/500 captured (Left hand)
# ✅ Sample 143/500 captured (Left hand)
# ✅ Sample 144/500 captured (Left hand)
# ✅ Sample 145/500 captured (Left hand)
# ✅ Sample 146/500 captured (Left hand)
# ✅ Sample 147/500 captured (Left hand)
# ✅ Sample 148/500 captured (Left hand)
# ✅ Sample 149/500 captured (Left hand)
# ✅ Sample 150/500 captured (Left hand)
# ✅ Sample 151/500 captured (Left hand)
# ✅ Sample 152/500 captured (Left hand)
# ✅ Sample 153/500 captured (Left hand)
# ✅ Sample 154/500 captured (Left hand)
# ✅ Sample 155/500 captured (Left hand)
# ✅ Sample 156/500 captured (Left hand)
# ✅ Sample 157/500 captured (Left hand)
# ✅ Sample 158/500 captured (Left hand)
# ✅ Sample 159/500 captured (Left hand)
# ✅ Sample 160/500 captured (Left hand)
# ✅ Sample 161/500 captured (Left hand)
# ✅ Sample 162/500 captured (Left hand)
# ✅ Sample 163/500 captured (Left hand)
# ✅ Sample 164/500 captured (Left hand)
# ✅ Sample 165/500 captured (Left hand)
# ✅ Sample 166/500 captured (Left hand)
# ✅ Sample 167/500 captured (Left hand)
# ✅ Sample 168/500 captured (Left hand)
# ✅ Sample 169/500 captured (Left hand)
# ✅ Sample 170/500 captured (Left hand)
# ✅ Sample 171/500 captured (Left hand)
# ✅ Sample 172/500 captured (Right hand)
# ✅ Sample 173/500 captured (Left hand)
# ✅ Sample 174/500 captured (Left hand)
# ✅ Sample 175/500 captured (Left hand)
# ✅ Sample 176/500 captured (Left hand)
# ✅ Sample 177/500 captured (Left hand)
# ✅ Sample 178/500 captured (Left hand)
# ✅ Sample 179/500 captured (Left hand)
# ✅ Sample 180/500 captured (Left hand)
# ✅ Sample 181/500 captured (Left hand)
# ✅ Sample 182/500 captured (Left hand)
# ✅ Sample 183/500 captured (Left hand)
# ✅ Sample 184/500 captured (Left hand)
# ✅ Sample 185/500 captured (Left hand)
# ✅ Sample 186/500 captured (Left hand)
# ✅ Sample 187/500 captured (Left hand)
# ✅ Sample 188/500 captured (Left hand)
# ✅ Sample 189/500 captured (Left hand)
# ✅ Sample 190/500 captured (Left hand)
# ✅ Sample 191/500 captured (Left hand)
# ✅ Sample 192/500 captured (Left hand)
# ✅ Sample 193/500 captured (Left hand)
# ✅ Sample 194/500 captured (Left hand)
# ✅ Sample 195/500 captured (Left hand)
# ✅ Sample 196/500 captured (Left hand)
# ✅ Sample 197/500 captured (Left hand)
# ✅ Sample 198/500 captured (Left hand)
# ✅ Sample 199/500 captured (Left hand)
# ✅ Sample 200/500 captured (Left hand)
# ✅ Sample 201/500 captured (Left hand)
# ✅ Sample 202/500 captured (Left hand)
# ✅ Sample 203/500 captured (Left hand)
# ✅ Sample 204/500 captured (Left hand)
# ✅ Sample 205/500 captured (Left hand)
# ✅ Sample 206/500 captured (Left hand)
# ✅ Sample 207/500 captured (Left hand)
# ✅ Sample 208/500 captured (Left hand)
# ✅ Sample 209/500 captured (Left hand)
# ✅ Sample 210/500 captured (Left hand)
# ✅ Sample 211/500 captured (Left hand)
# ✅ Sample 212/500 captured (Left hand)
# ✅ Sample 213/500 captured (Left hand)
# ✅ Sample 214/500 captured (Left hand)
# ✅ Sample 215/500 captured (Left hand)
# ✅ Sample 216/500 captured (Left hand)
# ✅ Sample 217/500 captured (Left hand)
# ✅ Sample 218/500 captured (Left hand)
# ✅ Sample 219/500 captured (Left hand)
# ✅ Sample 220/500 captured (Left hand)
# ✅ Sample 221/500 captured (Left hand)
# ✅ Sample 222/500 captured (Left hand)
# ✅ Sample 223/500 captured (Left hand)
# ✅ Sample 224/500 captured (Left hand)
# ✅ Sample 225/500 captured (Left hand)
# ✅ Sample 226/500 captured (Left hand)
# ✅ Sample 227/500 captured (Left hand)
# ✅ Sample 228/500 captured (Left hand)
# ✅ Sample 229/500 captured (Left hand)
# ✅ Sample 230/500 captured (Left hand)
# ✅ Sample 231/500 captured (Left hand)
# ✅ Sample 232/500 captured (Left hand)
# ✅ Sample 233/500 captured (Left hand)
# ✅ Sample 234/500 captured (Left hand)
# ✅ Sample 235/500 captured (Left hand)
# ✅ Sample 236/500 captured (Left hand)
# ✅ Sample 237/500 captured (Left hand)
# ✅ Sample 238/500 captured (Left hand)
# ✅ Sample 239/500 captured (Left hand)
# ✅ Sample 240/500 captured (Left hand)
# ✅ Sample 241/500 captured (Left hand)
# ✅ Sample 242/500 captured (Left hand)
# ✅ Sample 243/500 captured (Left hand)
# ✅ Sample 244/500 captured (Left hand)
# ✅ Sample 245/500 captured (Left hand)
# ✅ Sample 246/500 captured (Left hand)
# ✅ Sample 247/500 captured (Left hand)
# ✅ Sample 248/500 captured (Left hand)
# ✅ Sample 249/500 captured (Left hand)
# ✅ Sample 250/500 captured (Left hand)
# ✅ Sample 251/500 captured (Left hand)
# ✅ Sample 252/500 captured (Left hand)
# ✅ Sample 253/500 captured (Left hand)
# ✅ Sample 254/500 captured (Left hand)
# ✅ Sample 255/500 captured (Left hand)
# ✅ Sample 256/500 captured (Left hand)
# ✅ Sample 257/500 captured (Left hand)
# ✅ Sample 258/500 captured (Left hand)
# ✅ Sample 259/500 captured (Left hand)
# ✅ Sample 260/500 captured (Left hand)
# ✅ Sample 261/500 captured (Left hand)
# ✅ Sample 262/500 captured (Left hand)
# ✅ Sample 263/500 captured (Left hand)
# ✅ Sample 264/500 captured (Left hand)
# ✅ Sample 265/500 captured (Left hand)
# ✅ Sample 266/500 captured (Left hand)
# ✅ Sample 267/500 captured (Left hand)
# ✅ Sample 268/500 captured (Left hand)
# ✅ Sample 269/500 captured (Left hand)
# ✅ Sample 270/500 captured (Left hand)
# ✅ Sample 271/500 captured (Left hand)
# ✅ Sample 272/500 captured (Left hand)
# ✅ Sample 273/500 captured (Left hand)
# ✅ Sample 274/500 captured (Left hand)
# ✅ Sample 275/500 captured (Left hand)
# ✅ Sample 276/500 captured (Left hand)
# ✅ Sample 277/500 captured (Left hand)
# ✅ Sample 278/500 captured (Left hand)
# ✅ Sample 279/500 captured (Left hand)
# ✅ Sample 280/500 captured (Left hand)
# ✅ Sample 281/500 captured (Left hand)
# ✅ Sample 282/500 captured (Left hand)
# ✅ Sample 283/500 captured (Left hand)
# ✅ Sample 284/500 captured (Left hand)
# ✅ Sample 285/500 captured (Left hand)
# ✅ Sample 286/500 captured (Left hand)
# ✅ Sample 287/500 captured (Left hand)
# ✅ Sample 288/500 captured (Left hand)
# ✅ Sample 289/500 captured (Left hand)
# ✅ Sample 290/500 captured (Left hand)
# ✅ Sample 291/500 captured (Left hand)
# ✅ Sample 292/500 captured (Left hand)
# ✅ Sample 293/500 captured (Left hand)
# ✅ Sample 294/500 captured (Left hand)
# ✅ Sample 295/500 captured (Left hand)
# ✅ Sample 296/500 captured (Left hand)
# ✅ Sample 297/500 captured (Left hand)
# ✅ Sample 298/500 captured (Left hand)
# ✅ Sample 299/500 captured (Left hand)
# ✅ Sample 300/500 captured (Left hand)
# ✅ Sample 301/500 captured (Left hand)
# ✅ Sample 302/500 captured (Left hand)
# ✅ Sample 303/500 captured (Left hand)
# ✅ Sample 304/500 captured (Left hand)
# ✅ Sample 305/500 captured (Left hand)
# ✅ Sample 306/500 captured (Left hand)
# ✅ Sample 307/500 captured (Left hand)
# ✅ Sample 308/500 captured (Left hand)
# ✅ Sample 309/500 captured (Left hand)
# ✅ Sample 310/500 captured (Left hand)
# ✅ Sample 311/500 captured (Left hand)
# ✅ Sample 312/500 captured (Left hand)
# ✅ Sample 313/500 captured (Left hand)
# ✅ Sample 314/500 captured (Left hand)
# ✅ Sample 315/500 captured (Left hand)
# ✅ Sample 316/500 captured (Left hand)
# ✅ Sample 317/500 captured (Left hand)
# ✅ Sample 318/500 captured (Left hand)
# ✅ Sample 319/500 captured (Left hand)
# ✅ Sample 320/500 captured (Left hand)
# ✅ Sample 321/500 captured (Left hand)
# ✅ Sample 322/500 captured (Left hand)
# ✅ Sample 323/500 captured (Left hand)
# ✅ Sample 324/500 captured (Left hand)
# ✅ Sample 325/500 captured (Left hand)
# ✅ Sample 326/500 captured (Left hand)
# ✅ Sample 327/500 captured (Left hand)
# ✅ Sample 328/500 captured (Left hand)
# ✅ Sample 329/500 captured (Left hand)
# ✅ Sample 330/500 captured (Left hand)
# ✅ Sample 331/500 captured (Left hand)
# ✅ Sample 332/500 captured (Left hand)
# ✅ Sample 333/500 captured (Left hand)
# ✅ Sample 334/500 captured (Left hand)
# ✅ Sample 335/500 captured (Left hand)
# ✅ Sample 336/500 captured (Left hand)
# ✅ Sample 337/500 captured (Left hand)
# ✅ Sample 338/500 captured (Left hand)
# ✅ Sample 339/500 captured (Left hand)
# ✅ Sample 340/500 captured (Left hand)
# ✅ Sample 341/500 captured (Left hand)
# ✅ Sample 342/500 captured (Left hand)
# ✅ Sample 343/500 captured (Left hand)
# ✅ Sample 344/500 captured (Left hand)
# ✅ Sample 345/500 captured (Left hand)
# ✅ Sample 346/500 captured (Left hand)
# ✅ Sample 347/500 captured (Left hand)
# ✅ Sample 348/500 captured (Left hand)
# ✅ Sample 349/500 captured (Left hand)
# ✅ Sample 350/500 captured (Left hand)
# ✅ Sample 351/500 captured (Left hand)
# ✅ Sample 352/500 captured (Left hand)
# ✅ Sample 353/500 captured (Left hand)
# ✅ Sample 354/500 captured (Left hand)
# ✅ Sample 355/500 captured (Left hand)
# ✅ Sample 356/500 captured (Left hand)
# ✅ Sample 357/500 captured (Left hand)
# ✅ Sample 358/500 captured (Left hand)
# ✅ Sample 359/500 captured (Left hand)
# ✅ Sample 360/500 captured (Left hand)
# ✅ Sample 361/500 captured (Left hand)
# ✅ Sample 362/500 captured (Left hand)
# ✅ Sample 363/500 captured (Left hand)
# ✅ Sample 364/500 captured (Left hand)
# ✅ Sample 365/500 captured (Left hand)
# ✅ Sample 366/500 captured (Left hand)
# ✅ Sample 367/500 captured (Left hand)
# ✅ Sample 368/500 captured (Left hand)
# ✅ Sample 369/500 captured (Left hand)
# ✅ Sample 370/500 captured (Left hand)
# ✅ Sample 371/500 captured (Left hand)
# ✅ Sample 372/500 captured (Left hand)
# ✅ Sample 373/500 captured (Left hand)
# ✅ Sample 374/500 captured (Left hand)
# ✅ Sample 375/500 captured (Left hand)
# ✅ Sample 376/500 captured (Left hand)
# ✅ Sample 377/500 captured (Left hand)
# ✅ Sample 378/500 captured (Left hand)
# ✅ Sample 379/500 captured (Left hand)
# ✅ Sample 380/500 captured (Left hand)
# ✅ Sample 381/500 captured (Left hand)
# ✅ Sample 382/500 captured (Left hand)
# ✅ Sample 383/500 captured (Left hand)
# ✅ Sample 384/500 captured (Left hand)
# ✅ Sample 385/500 captured (Left hand)
# ✅ Sample 386/500 captured (Left hand)
# ✅ Sample 387/500 captured (Left hand)
# ✅ Sample 388/500 captured (Left hand)
# ✅ Sample 389/500 captured (Left hand)
# ✅ Sample 390/500 captured (Left hand)
# ✅ Sample 391/500 captured (Left hand)
# ✅ Sample 392/500 captured (Left hand)
# ✅ Sample 393/500 captured (Left hand)
# ✅ Sample 394/500 captured (Left hand)
# ✅ Sample 395/500 captured (Left hand)
# ✅ Sample 396/500 captured (Left hand)
# ✅ Sample 397/500 captured (Left hand)
# ✅ Sample 398/500 captured (Left hand)
# ✅ Sample 399/500 captured (Left hand)
# ✅ Sample 400/500 captured (Left hand)
# ✅ Sample 401/500 captured (Left hand)
# ✅ Sample 402/500 captured (Left hand)
# ✅ Sample 403/500 captured (Left hand)
# ✅ Sample 404/500 captured (Left hand)
# ✅ Sample 405/500 captured (Left hand)
# ✅ Sample 406/500 captured (Left hand)
# ✅ Sample 407/500 captured (Left hand)
# ✅ Sample 408/500 captured (Left hand)
# ✅ Sample 409/500 captured (Left hand)
# ✅ Sample 410/500 captured (Left hand)
# ✅ Sample 411/500 captured (Left hand)
# ✅ Sample 412/500 captured (Left hand)
# ✅ Sample 413/500 captured (Left hand)
# ✅ Sample 414/500 captured (Left hand)
# ✅ Sample 415/500 captured (Left hand)
# ✅ Sample 416/500 captured (Left hand)
# ✅ Sample 417/500 captured (Left hand)
# ✅ Sample 418/500 captured (Left hand)
# ✅ Sample 419/500 captured (Left hand)
# ✅ Sample 420/500 captured (Left hand)
# ✅ Sample 421/500 captured (Left hand)
# ✅ Sample 422/500 captured (Left hand)
# ✅ Sample 423/500 captured (Left hand)
# ✅ Sample 424/500 captured (Left hand)
# ✅ Sample 425/500 captured (Left hand)
# ✅ Sample 426/500 captured (Left hand)
# ✅ Sample 427/500 captured (Left hand)
# ✅ Sample 428/500 captured (Left hand)
# ✅ Sample 429/500 captured (Left hand)
# ✅ Sample 430/500 captured (Left hand)
# ✅ Sample 431/500 captured (Left hand)
# ✅ Sample 432/500 captured (Left hand)
# ✅ Sample 433/500 captured (Left hand)
# ✅ Sample 434/500 captured (Left hand)
# ✅ Sample 435/500 captured (Left hand)
# ✅ Sample 436/500 captured (Left hand)
# ✅ Sample 437/500 captured (Left hand)
# ✅ Sample 438/500 captured (Left hand)
# ✅ Sample 439/500 captured (Left hand)
# ✅ Sample 440/500 captured (Left hand)
# ✅ Sample 441/500 captured (Left hand)
# ✅ Sample 442/500 captured (Left hand)
# ✅ Sample 443/500 captured (Left hand)
# ✅ Sample 444/500 captured (Left hand)
# ✅ Sample 445/500 captured (Left hand)
# ✅ Sample 446/500 captured (Left hand)
# ✅ Sample 447/500 captured (Left hand)
# ✅ Sample 448/500 captured (Left hand)
# ✅ Sample 449/500 captured (Left hand)
# ✅ Sample 450/500 captured (Left hand)
# ✅ Sample 451/500 captured (Left hand)
# ✅ Sample 452/500 captured (Left hand)
# ✅ Sample 453/500 captured (Left hand)
# ✅ Sample 454/500 captured (Left hand)
# ✅ Sample 455/500 captured (Left hand)
# ✅ Sample 456/500 captured (Left hand)
# ✅ Sample 457/500 captured (Left hand)
# ✅ Sample 458/500 captured (Left hand)
# ✅ Sample 459/500 captured (Left hand)
# ✅ Sample 460/500 captured (Left hand)
# ✅ Sample 461/500 captured (Left hand)
# ✅ Sample 462/500 captured (Left hand)
# ✅ Sample 463/500 captured (Left hand)
# ✅ Sample 464/500 captured (Left hand)
# ✅ Sample 465/500 captured (Left hand)
# ✅ Sample 466/500 captured (Left hand)
# ✅ Sample 467/500 captured (Left hand)
# ✅ Sample 468/500 captured (Left hand)
# ✅ Sample 469/500 captured (Left hand)
# ✅ Sample 470/500 captured (Left hand)
# ✅ Sample 471/500 captured (Left hand)
# ✅ Sample 472/500 captured (Left hand)
# ✅ Sample 473/500 captured (Left hand)
# ✅ Sample 474/500 captured (Left hand)
# ✅ Sample 475/500 captured (Left hand)
# ✅ Sample 476/500 captured (Left hand)
# ✅ Sample 477/500 captured (Left hand)
# ✅ Sample 478/500 captured (Left hand)
# ✅ Sample 479/500 captured (Left hand)
# ✅ Sample 480/500 captured (Left hand)
# ✅ Sample 481/500 captured (Left hand)
# ✅ Sample 482/500 captured (Left hand)
# ✅ Sample 483/500 captured (Left hand)
# ✅ Sample 484/500 captured (Left hand)
# ✅ Sample 485/500 captured (Left hand)
# ✅ Sample 486/500 captured (Left hand)
# ✅ Sample 487/500 captured (Left hand)
# ✅ Sample 488/500 captured (Left hand)
# ✅ Sample 489/500 captured (Left hand)
# ✅ Sample 490/500 captured (Left hand)
# ✅ Sample 491/500 captured (Left hand)
# ✅ Sample 492/500 captured (Left hand)
# ✅ Sample 493/500 captured (Left hand)
# ✅ Sample 494/500 captured (Left hand)
# ✅ Sample 495/500 captured (Left hand)
# ✅ Sample 496/500 captured (Left hand)
# ✅ Sample 497/500 captured (Left hand)
# ✅ Sample 498/500 captured (Left hand)
# ✅ Sample 499/500 captured (Left hand)
# ✅ Sample 500/500 captured (Left hand)
#
# CSV saved: ../data/raw/don_g.csv (1000 total rows)

# %%
# don
output_csv = '../data/raw/don_k.csv'
capture_hands_to_csv_auto(output_csv, "don", max_samples=500)
# Out:
# I0000 00:00:1762270184.400809  110229 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762270184.404853  110778 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-33-generic)
# W0000 00:00:1762270184.463085  110762 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762270184.479360  110770 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera is ready. Capturing every 0.1 seconds. Press 'q' to quit.
# ✅ Sample 1/500 captured (Left hand)
# ✅ Sample 2/500 captured (Left hand)
# ✅ Sample 3/500 captured (Left hand)
# ✅ Sample 4/500 captured (Left hand)
# ✅ Sample 5/500 captured (Left hand)
# ✅ Sample 6/500 captured (Left hand)
# ✅ Sample 7/500 captured (Left hand)
# ✅ Sample 8/500 captured (Left hand)
# ✅ Sample 9/500 captured (Left hand)
# ✅ Sample 10/500 captured (Left hand)
# ✅ Sample 11/500 captured (Left hand)
# ✅ Sample 12/500 captured (Left hand)
# ✅ Sample 13/500 captured (Left hand)
# ✅ Sample 14/500 captured (Left hand)
# ✅ Sample 15/500 captured (Left hand)
# ✅ Sample 16/500 captured (Left hand)
# ✅ Sample 17/500 captured (Left hand)
# ✅ Sample 18/500 captured (Left hand)
# ✅ Sample 19/500 captured (Left hand)
# ✅ Sample 20/500 captured (Left hand)
# ✅ Sample 21/500 captured (Left hand)
# ✅ Sample 22/500 captured (Left hand)
# ✅ Sample 23/500 captured (Left hand)
# ✅ Sample 24/500 captured (Left hand)
# ✅ Sample 25/500 captured (Left hand)
# ✅ Sample 26/500 captured (Left hand)
# ✅ Sample 27/500 captured (Left hand)
# ✅ Sample 28/500 captured (Left hand)
# ✅ Sample 29/500 captured (Left hand)
# ✅ Sample 30/500 captured (Left hand)
# ✅ Sample 31/500 captured (Left hand)
# ✅ Sample 32/500 captured (Left hand)
# ✅ Sample 33/500 captured (Left hand)
# ✅ Sample 34/500 captured (Left hand)
# ✅ Sample 35/500 captured (Left hand)
# ✅ Sample 36/500 captured (Left hand)
# ✅ Sample 37/500 captured (Left hand)
# ✅ Sample 38/500 captured (Left hand)
# ✅ Sample 39/500 captured (Left hand)
# ✅ Sample 40/500 captured (Left hand)
# ✅ Sample 41/500 captured (Left hand)
# ✅ Sample 42/500 captured (Left hand)
# ✅ Sample 43/500 captured (Left hand)
# ✅ Sample 44/500 captured (Left hand)
# ✅ Sample 45/500 captured (Left hand)
# ✅ Sample 46/500 captured (Left hand)
# ✅ Sample 47/500 captured (Left hand)
# ✅ Sample 48/500 captured (Left hand)
# ✅ Sample 49/500 captured (Left hand)
# ✅ Sample 50/500 captured (Left hand)
# ✅ Sample 51/500 captured (Left hand)
# ✅ Sample 52/500 captured (Left hand)
# ✅ Sample 53/500 captured (Left hand)
# ✅ Sample 54/500 captured (Left hand)
# ✅ Sample 55/500 captured (Left hand)
# ✅ Sample 56/500 captured (Left hand)
# ✅ Sample 57/500 captured (Left hand)
# ✅ Sample 58/500 captured (Left hand)
# ✅ Sample 59/500 captured (Left hand)
# ✅ Sample 60/500 captured (Left hand)
# ✅ Sample 61/500 captured (Left hand)
# ✅ Sample 62/500 captured (Left hand)
# ✅ Sample 63/500 captured (Left hand)
# ✅ Sample 64/500 captured (Left hand)
# ✅ Sample 65/500 captured (Left hand)
# ✅ Sample 66/500 captured (Left hand)
# ✅ Sample 67/500 captured (Left hand)
# ✅ Sample 68/500 captured (Left hand)
# ✅ Sample 69/500 captured (Left hand)
# ✅ Sample 70/500 captured (Left hand)
# ✅ Sample 71/500 captured (Left hand)
# ✅ Sample 72/500 captured (Left hand)
# ✅ Sample 73/500 captured (Left hand)
# ✅ Sample 74/500 captured (Left hand)
# ✅ Sample 75/500 captured (Left hand)
# ✅ Sample 76/500 captured (Left hand)
# ✅ Sample 77/500 captured (Left hand)
# ✅ Sample 78/500 captured (Left hand)
# ✅ Sample 79/500 captured (Left hand)
# ✅ Sample 80/500 captured (Left hand)
# ✅ Sample 81/500 captured (Left hand)
# ✅ Sample 82/500 captured (Left hand)
# ✅ Sample 83/500 captured (Left hand)
# ✅ Sample 84/500 captured (Left hand)
# ✅ Sample 85/500 captured (Left hand)
# ✅ Sample 86/500 captured (Left hand)
# ✅ Sample 87/500 captured (Left hand)
# ✅ Sample 88/500 captured (Left hand)
# ✅ Sample 89/500 captured (Left hand)
# ✅ Sample 90/500 captured (Left hand)
# ✅ Sample 91/500 captured (Left hand)
# ✅ Sample 92/500 captured (Left hand)
# ✅ Sample 93/500 captured (Left hand)
# ✅ Sample 94/500 captured (Left hand)
# ✅ Sample 95/500 captured (Left hand)
# ✅ Sample 96/500 captured (Left hand)
# ✅ Sample 97/500 captured (Left hand)
# ✅ Sample 98/500 captured (Left hand)
# ✅ Sample 99/500 captured (Left hand)
# ✅ Sample 100/500 captured (Left hand)
# ✅ Sample 101/500 captured (Left hand)
# ✅ Sample 102/500 captured (Left hand)
# ✅ Sample 103/500 captured (Left hand)
# ✅ Sample 104/500 captured (Left hand)
# ✅ Sample 105/500 captured (Left hand)
# ✅ Sample 106/500 captured (Left hand)
# ✅ Sample 107/500 captured (Left hand)
# ✅ Sample 108/500 captured (Left hand)
# ✅ Sample 109/500 captured (Left hand)
# ✅ Sample 110/500 captured (Left hand)
# ✅ Sample 111/500 captured (Left hand)
# ✅ Sample 112/500 captured (Left hand)
# ✅ Sample 113/500 captured (Left hand)
# ✅ Sample 114/500 captured (Left hand)
# ✅ Sample 115/500 captured (Left hand)
# ✅ Sample 116/500 captured (Left hand)
# ✅ Sample 117/500 captured (Left hand)
# ✅ Sample 118/500 captured (Left hand)
# ✅ Sample 119/500 captured (Left hand)
# ✅ Sample 120/500 captured (Left hand)
# ✅ Sample 121/500 captured (Left hand)
# ✅ Sample 122/500 captured (Left hand)
# ✅ Sample 123/500 captured (Left hand)
# ✅ Sample 124/500 captured (Left hand)
# ✅ Sample 125/500 captured (Left hand)
# ✅ Sample 126/500 captured (Left hand)
# ✅ Sample 127/500 captured (Left hand)
# ✅ Sample 128/500 captured (Left hand)
# ✅ Sample 129/500 captured (Left hand)
# ✅ Sample 130/500 captured (Left hand)
# ✅ Sample 131/500 captured (Left hand)
# ✅ Sample 132/500 captured (Left hand)
# ✅ Sample 133/500 captured (Left hand)
# ✅ Sample 134/500 captured (Left hand)
# ✅ Sample 135/500 captured (Left hand)
# ✅ Sample 136/500 captured (Left hand)
# ✅ Sample 137/500 captured (Left hand)
# ✅ Sample 138/500 captured (Left hand)
# ✅ Sample 139/500 captured (Left hand)
# ✅ Sample 140/500 captured (Left hand)
# ✅ Sample 141/500 captured (Left hand)
# ✅ Sample 142/500 captured (Left hand)
# ✅ Sample 143/500 captured (Left hand)
# ✅ Sample 144/500 captured (Left hand)
# ✅ Sample 145/500 captured (Left hand)
# ✅ Sample 146/500 captured (Left hand)
# ✅ Sample 147/500 captured (Left hand)
# ✅ Sample 148/500 captured (Left hand)
# ✅ Sample 149/500 captured (Left hand)
# ✅ Sample 150/500 captured (Left hand)
# ✅ Sample 151/500 captured (Left hand)
# ✅ Sample 152/500 captured (Left hand)
# ✅ Sample 153/500 captured (Left hand)
# ✅ Sample 154/500 captured (Left hand)
# ✅ Sample 155/500 captured (Left hand)
# ✅ Sample 156/500 captured (Left hand)
# ✅ Sample 157/500 captured (Left hand)
# ✅ Sample 158/500 captured (Left hand)
# ✅ Sample 159/500 captured (Left hand)
# ✅ Sample 160/500 captured (Left hand)
# ✅ Sample 161/500 captured (Left hand)
# ✅ Sample 162/500 captured (Left hand)
# ✅ Sample 163/500 captured (Left hand)
# ✅ Sample 164/500 captured (Left hand)
# ✅ Sample 165/500 captured (Left hand)
# ✅ Sample 166/500 captured (Left hand)
# ✅ Sample 167/500 captured (Left hand)
# ✅ Sample 168/500 captured (Left hand)
# ✅ Sample 169/500 captured (Left hand)
# ✅ Sample 170/500 captured (Left hand)
# ✅ Sample 171/500 captured (Left hand)
# ✅ Sample 172/500 captured (Left hand)
# ✅ Sample 173/500 captured (Left hand)
# ✅ Sample 174/500 captured (Left hand)
# ✅ Sample 175/500 captured (Left hand)
# ✅ Sample 176/500 captured (Left hand)
# ✅ Sample 177/500 captured (Left hand)
# ✅ Sample 178/500 captured (Left hand)
# ✅ Sample 179/500 captured (Left hand)
# ✅ Sample 180/500 captured (Left hand)
# ✅ Sample 181/500 captured (Left hand)
# ✅ Sample 182/500 captured (Left hand)
# ✅ Sample 183/500 captured (Left hand)
# ✅ Sample 184/500 captured (Left hand)
# ✅ Sample 185/500 captured (Left hand)
# ✅ Sample 186/500 captured (Left hand)
# ✅ Sample 187/500 captured (Left hand)
# ✅ Sample 188/500 captured (Left hand)
# ✅ Sample 189/500 captured (Left hand)
# ✅ Sample 190/500 captured (Left hand)
# ✅ Sample 191/500 captured (Left hand)
# ✅ Sample 192/500 captured (Left hand)
# ✅ Sample 193/500 captured (Left hand)
# ✅ Sample 194/500 captured (Left hand)
# ✅ Sample 195/500 captured (Left hand)
# ✅ Sample 196/500 captured (Left hand)
# ✅ Sample 197/500 captured (Left hand)
# ✅ Sample 198/500 captured (Left hand)
# ✅ Sample 199/500 captured (Left hand)
# ✅ Sample 200/500 captured (Left hand)
# ✅ Sample 201/500 captured (Left hand)
# ✅ Sample 202/500 captured (Left hand)
# ✅ Sample 203/500 captured (Left hand)
# ✅ Sample 204/500 captured (Left hand)
# ✅ Sample 205/500 captured (Left hand)
# ✅ Sample 206/500 captured (Left hand)
# ✅ Sample 207/500 captured (Left hand)
# ✅ Sample 208/500 captured (Left hand)
# ✅ Sample 209/500 captured (Left hand)
# ✅ Sample 210/500 captured (Left hand)
# ✅ Sample 211/500 captured (Left hand)
# ✅ Sample 212/500 captured (Left hand)
# ✅ Sample 213/500 captured (Left hand)
# ✅ Sample 214/500 captured (Left hand)
# ✅ Sample 215/500 captured (Left hand)
# ✅ Sample 216/500 captured (Left hand)
# ✅ Sample 217/500 captured (Left hand)
# ✅ Sample 218/500 captured (Left hand)
# ✅ Sample 219/500 captured (Left hand)
# ✅ Sample 220/500 captured (Left hand)
# ✅ Sample 221/500 captured (Left hand)
# ✅ Sample 222/500 captured (Left hand)
# ✅ Sample 223/500 captured (Left hand)
# ✅ Sample 224/500 captured (Left hand)
# ✅ Sample 225/500 captured (Left hand)
# ✅ Sample 226/500 captured (Left hand)
# ✅ Sample 227/500 captured (Left hand)
# ✅ Sample 228/500 captured (Left hand)
# ✅ Sample 229/500 captured (Left hand)
# ✅ Sample 230/500 captured (Left hand)
# ✅ Sample 231/500 captured (Left hand)
# ✅ Sample 232/500 captured (Left hand)
# ✅ Sample 233/500 captured (Left hand)
# ✅ Sample 234/500 captured (Left hand)
# ✅ Sample 235/500 captured (Left hand)
# ✅ Sample 236/500 captured (Left hand)
# ✅ Sample 237/500 captured (Left hand)
# ✅ Sample 238/500 captured (Left hand)
# ✅ Sample 239/500 captured (Left hand)
# ✅ Sample 240/500 captured (Left hand)
# ✅ Sample 241/500 captured (Left hand)
# ✅ Sample 242/500 captured (Left hand)
# ✅ Sample 243/500 captured (Left hand)
# ✅ Sample 244/500 captured (Left hand)
# ✅ Sample 245/500 captured (Left hand)
# ✅ Sample 246/500 captured (Left hand)
# ✅ Sample 247/500 captured (Left hand)
# ✅ Sample 248/500 captured (Left hand)
# ✅ Sample 249/500 captured (Left hand)
# ✅ Sample 250/500 captured (Left hand)
# ✅ Sample 251/500 captured (Left hand)
# ✅ Sample 252/500 captured (Left hand)
# ✅ Sample 253/500 captured (Left hand)
# ✅ Sample 254/500 captured (Left hand)
# ✅ Sample 255/500 captured (Left hand)
# ✅ Sample 256/500 captured (Left hand)
# ✅ Sample 257/500 captured (Left hand)
# ✅ Sample 258/500 captured (Left hand)
# ✅ Sample 259/500 captured (Left hand)
# ✅ Sample 260/500 captured (Left hand)
# ✅ Sample 261/500 captured (Left hand)
# ✅ Sample 262/500 captured (Left hand)
# ✅ Sample 263/500 captured (Left hand)
# ✅ Sample 264/500 captured (Left hand)
# ✅ Sample 265/500 captured (Left hand)
# ✅ Sample 266/500 captured (Left hand)
# ✅ Sample 267/500 captured (Left hand)
# ✅ Sample 268/500 captured (Left hand)
# ✅ Sample 269/500 captured (Left hand)
# ✅ Sample 270/500 captured (Left hand)
# ✅ Sample 271/500 captured (Left hand)
# ✅ Sample 272/500 captured (Left hand)
# ✅ Sample 273/500 captured (Left hand)
# ✅ Sample 274/500 captured (Left hand)
# ✅ Sample 275/500 captured (Left hand)
# ✅ Sample 276/500 captured (Left hand)
# ✅ Sample 277/500 captured (Left hand)
# ✅ Sample 278/500 captured (Left hand)
# ✅ Sample 279/500 captured (Left hand)
# ✅ Sample 280/500 captured (Left hand)
# ✅ Sample 281/500 captured (Left hand)
# ✅ Sample 282/500 captured (Left hand)
# ✅ Sample 283/500 captured (Left hand)
# ✅ Sample 284/500 captured (Left hand)
# ✅ Sample 285/500 captured (Left hand)
# ✅ Sample 286/500 captured (Left hand)
# ✅ Sample 287/500 captured (Left hand)
# ✅ Sample 288/500 captured (Left hand)
# ✅ Sample 289/500 captured (Left hand)
# ✅ Sample 290/500 captured (Left hand)
# ✅ Sample 291/500 captured (Left hand)
# ✅ Sample 292/500 captured (Left hand)
# ✅ Sample 293/500 captured (Left hand)
# ✅ Sample 294/500 captured (Left hand)
# ✅ Sample 295/500 captured (Left hand)
# ✅ Sample 296/500 captured (Left hand)
# ✅ Sample 297/500 captured (Left hand)
# ✅ Sample 298/500 captured (Left hand)
# ✅ Sample 299/500 captured (Left hand)
# ✅ Sample 300/500 captured (Left hand)
# ✅ Sample 301/500 captured (Left hand)
# ✅ Sample 302/500 captured (Left hand)
# ✅ Sample 303/500 captured (Left hand)
# ✅ Sample 304/500 captured (Left hand)
# ✅ Sample 305/500 captured (Left hand)
# ✅ Sample 306/500 captured (Left hand)
# ✅ Sample 307/500 captured (Left hand)
# ✅ Sample 308/500 captured (Left hand)
# ✅ Sample 309/500 captured (Left hand)
# ✅ Sample 310/500 captured (Left hand)
# ✅ Sample 311/500 captured (Left hand)
# ✅ Sample 312/500 captured (Left hand)
# ✅ Sample 313/500 captured (Left hand)
# ✅ Sample 314/500 captured (Left hand)
# ✅ Sample 315/500 captured (Left hand)
# ✅ Sample 316/500 captured (Left hand)
# ✅ Sample 317/500 captured (Left hand)
# ✅ Sample 318/500 captured (Left hand)
# ✅ Sample 319/500 captured (Left hand)
# ✅ Sample 320/500 captured (Left hand)
# ✅ Sample 321/500 captured (Left hand)
# ✅ Sample 322/500 captured (Left hand)
# ✅ Sample 323/500 captured (Left hand)
# ✅ Sample 324/500 captured (Left hand)
# ✅ Sample 325/500 captured (Left hand)
# ✅ Sample 326/500 captured (Left hand)
# ✅ Sample 327/500 captured (Left hand)
# ✅ Sample 328/500 captured (Left hand)
# ✅ Sample 329/500 captured (Left hand)
# ✅ Sample 330/500 captured (Left hand)
# ✅ Sample 331/500 captured (Left hand)
# ✅ Sample 332/500 captured (Left hand)
# ✅ Sample 333/500 captured (Left hand)
# ✅ Sample 334/500 captured (Left hand)
# ✅ Sample 335/500 captured (Left hand)
# ✅ Sample 336/500 captured (Left hand)
# ✅ Sample 337/500 captured (Left hand)
# ✅ Sample 338/500 captured (Left hand)
# ✅ Sample 339/500 captured (Left hand)
# ✅ Sample 340/500 captured (Left hand)
# ✅ Sample 341/500 captured (Left hand)
# ✅ Sample 342/500 captured (Left hand)
# ✅ Sample 343/500 captured (Left hand)
# ✅ Sample 344/500 captured (Left hand)
# ✅ Sample 345/500 captured (Left hand)
# ✅ Sample 346/500 captured (Left hand)
# ✅ Sample 347/500 captured (Left hand)
# ✅ Sample 348/500 captured (Left hand)
# ✅ Sample 349/500 captured (Left hand)
# ✅ Sample 350/500 captured (Left hand)
# ✅ Sample 351/500 captured (Left hand)
# ✅ Sample 352/500 captured (Left hand)
# ✅ Sample 353/500 captured (Left hand)
# ✅ Sample 354/500 captured (Left hand)
# ✅ Sample 355/500 captured (Left hand)
# ✅ Sample 356/500 captured (Left hand)
# ✅ Sample 357/500 captured (Left hand)
# ✅ Sample 358/500 captured (Left hand)
# ✅ Sample 359/500 captured (Left hand)
# ✅ Sample 360/500 captured (Left hand)
# ✅ Sample 361/500 captured (Left hand)
# ✅ Sample 362/500 captured (Left hand)
# ✅ Sample 363/500 captured (Left hand)
# ✅ Sample 364/500 captured (Left hand)
# ✅ Sample 365/500 captured (Left hand)
# ✅ Sample 366/500 captured (Left hand)
# ✅ Sample 367/500 captured (Left hand)
# ✅ Sample 368/500 captured (Left hand)
# ✅ Sample 369/500 captured (Left hand)
# ✅ Sample 370/500 captured (Left hand)
# ✅ Sample 371/500 captured (Left hand)
# ✅ Sample 372/500 captured (Left hand)
# ✅ Sample 373/500 captured (Left hand)
# ✅ Sample 374/500 captured (Left hand)
# ✅ Sample 375/500 captured (Left hand)
# ✅ Sample 376/500 captured (Left hand)
# ✅ Sample 377/500 captured (Left hand)
# ✅ Sample 378/500 captured (Left hand)
# ✅ Sample 379/500 captured (Left hand)
# ✅ Sample 380/500 captured (Left hand)
# ✅ Sample 381/500 captured (Left hand)
# ✅ Sample 382/500 captured (Left hand)
# ✅ Sample 383/500 captured (Left hand)
# ✅ Sample 384/500 captured (Left hand)
# ✅ Sample 385/500 captured (Left hand)
# ✅ Sample 386/500 captured (Left hand)
# ✅ Sample 387/500 captured (Left hand)
# ✅ Sample 388/500 captured (Left hand)
# ✅ Sample 389/500 captured (Left hand)
# ✅ Sample 390/500 captured (Left hand)
# ✅ Sample 391/500 captured (Left hand)
# ✅ Sample 392/500 captured (Left hand)
# ✅ Sample 393/500 captured (Left hand)
# ✅ Sample 394/500 captured (Left hand)
# ✅ Sample 395/500 captured (Left hand)
# ✅ Sample 396/500 captured (Left hand)
# ✅ Sample 397/500 captured (Left hand)
# ✅ Sample 398/500 captured (Left hand)
# ✅ Sample 399/500 captured (Left hand)
# ✅ Sample 400/500 captured (Left hand)
# ✅ Sample 401/500 captured (Left hand)
# ✅ Sample 402/500 captured (Left hand)
# ✅ Sample 403/500 captured (Left hand)
# ✅ Sample 404/500 captured (Left hand)
# ✅ Sample 405/500 captured (Left hand)
# ✅ Sample 406/500 captured (Left hand)
# ✅ Sample 407/500 captured (Left hand)
# ✅ Sample 408/500 captured (Left hand)
# ✅ Sample 409/500 captured (Left hand)
# ✅ Sample 410/500 captured (Left hand)
# ✅ Sample 411/500 captured (Left hand)
# ✅ Sample 412/500 captured (Left hand)
# ✅ Sample 413/500 captured (Left hand)
# ✅ Sample 414/500 captured (Left hand)
# ✅ Sample 415/500 captured (Left hand)
# ✅ Sample 416/500 captured (Left hand)
# ✅ Sample 417/500 captured (Left hand)
# ✅ Sample 418/500 captured (Left hand)
# ✅ Sample 419/500 captured (Left hand)
# ✅ Sample 420/500 captured (Left hand)
# ✅ Sample 421/500 captured (Left hand)
# ✅ Sample 422/500 captured (Left hand)
# ✅ Sample 423/500 captured (Left hand)
# ✅ Sample 424/500 captured (Left hand)
# ✅ Sample 425/500 captured (Left hand)
# ✅ Sample 426/500 captured (Left hand)
# ✅ Sample 427/500 captured (Left hand)
# ✅ Sample 428/500 captured (Left hand)
# ✅ Sample 429/500 captured (Left hand)
# ✅ Sample 430/500 captured (Left hand)
# ✅ Sample 431/500 captured (Left hand)
# ✅ Sample 432/500 captured (Left hand)
# ✅ Sample 433/500 captured (Left hand)
# ✅ Sample 434/500 captured (Left hand)
# ✅ Sample 435/500 captured (Left hand)
# ✅ Sample 436/500 captured (Left hand)
# ✅ Sample 437/500 captured (Left hand)
# ✅ Sample 438/500 captured (Left hand)
# ✅ Sample 439/500 captured (Left hand)
# ✅ Sample 440/500 captured (Left hand)
# ✅ Sample 441/500 captured (Left hand)
# ✅ Sample 442/500 captured (Left hand)
# ✅ Sample 443/500 captured (Left hand)
# ✅ Sample 444/500 captured (Left hand)
# ✅ Sample 445/500 captured (Left hand)
# ✅ Sample 446/500 captured (Left hand)
# ✅ Sample 447/500 captured (Left hand)
# ✅ Sample 448/500 captured (Left hand)
# ✅ Sample 449/500 captured (Left hand)
# ✅ Sample 450/500 captured (Left hand)
# ✅ Sample 451/500 captured (Left hand)
# ✅ Sample 452/500 captured (Left hand)
# ✅ Sample 453/500 captured (Left hand)
# ✅ Sample 454/500 captured (Left hand)
# ✅ Sample 455/500 captured (Left hand)
# ✅ Sample 456/500 captured (Left hand)
# ✅ Sample 457/500 captured (Left hand)
# ✅ Sample 458/500 captured (Left hand)
# ✅ Sample 459/500 captured (Left hand)
# ✅ Sample 460/500 captured (Left hand)
# ✅ Sample 461/500 captured (Left hand)
# ✅ Sample 462/500 captured (Left hand)
# ✅ Sample 463/500 captured (Left hand)
# ✅ Sample 464/500 captured (Left hand)
# ✅ Sample 465/500 captured (Left hand)
# ✅ Sample 466/500 captured (Left hand)
# ✅ Sample 467/500 captured (Left hand)
# ✅ Sample 468/500 captured (Left hand)
# ✅ Sample 469/500 captured (Left hand)
# ✅ Sample 470/500 captured (Left hand)
# ✅ Sample 471/500 captured (Left hand)
# ✅ Sample 472/500 captured (Left hand)
# ✅ Sample 473/500 captured (Left hand)
# ✅ Sample 474/500 captured (Left hand)
# ✅ Sample 475/500 captured (Left hand)
# ✅ Sample 476/500 captured (Left hand)
# ✅ Sample 477/500 captured (Left hand)
# ✅ Sample 478/500 captured (Left hand)
# ✅ Sample 479/500 captured (Left hand)
# ✅ Sample 480/500 captured (Left hand)
# ✅ Sample 481/500 captured (Left hand)
# ✅ Sample 482/500 captured (Left hand)
# ✅ Sample 483/500 captured (Left hand)
# ✅ Sample 484/500 captured (Left hand)
# ✅ Sample 485/500 captured (Left hand)
# ✅ Sample 486/500 captured (Left hand)
# ✅ Sample 487/500 captured (Left hand)
# ✅ Sample 488/500 captured (Left hand)
# ✅ Sample 489/500 captured (Left hand)
# ✅ Sample 490/500 captured (Left hand)
# ✅ Sample 491/500 captured (Left hand)
# ✅ Sample 492/500 captured (Left hand)
# ✅ Sample 493/500 captured (Left hand)
# ✅ Sample 494/500 captured (Left hand)
# ✅ Sample 495/500 captured (Left hand)
# ✅ Sample 496/500 captured (Left hand)
# ✅ Sample 497/500 captured (Left hand)
# ✅ Sample 498/500 captured (Left hand)
# ✅ Sample 499/500 captured (Left hand)
# ✅ Sample 500/500 captured (Left hand)
#
# CSV saved: ../data/raw/don_k.csv (1000 total rows)

# %%
# don
output_csv = '../data/raw/don.csv'
capture_hands_to_csv_auto(output_csv, "don", max_samples=500)
# Out:
# I0000 00:00:1762270535.923803  110229 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762270535.927037  111216 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-33-generic)
# W0000 00:00:1762270535.977516  111199 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762270536.019999  111207 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Camera is ready. Capturing every 0.1 seconds. Press 'q' to quit.
# ✅ Sample 1/500 captured (Left hand)
# ✅ Sample 2/500 captured (Left hand)
# ✅ Sample 3/500 captured (Left hand)
# ✅ Sample 4/500 captured (Left hand)
# ✅ Sample 5/500 captured (Left hand)
# ✅ Sample 6/500 captured (Left hand)
# ✅ Sample 7/500 captured (Left hand)
# ✅ Sample 8/500 captured (Left hand)
# ✅ Sample 9/500 captured (Left hand)
# ✅ Sample 10/500 captured (Left hand)
# ✅ Sample 11/500 captured (Left hand)
# ✅ Sample 12/500 captured (Left hand)
# ✅ Sample 13/500 captured (Left hand)
# ✅ Sample 14/500 captured (Left hand)
# ✅ Sample 15/500 captured (Left hand)
# ✅ Sample 16/500 captured (Left hand)
# ✅ Sample 17/500 captured (Left hand)
# ✅ Sample 18/500 captured (Left hand)
# ✅ Sample 19/500 captured (Left hand)
# ✅ Sample 20/500 captured (Left hand)
# ✅ Sample 21/500 captured (Left hand)
# ✅ Sample 22/500 captured (Left hand)
# ✅ Sample 23/500 captured (Left hand)
# ✅ Sample 24/500 captured (Left hand)
# ✅ Sample 25/500 captured (Left hand)
# ✅ Sample 26/500 captured (Left hand)
# ✅ Sample 27/500 captured (Left hand)
# ✅ Sample 28/500 captured (Left hand)
# ✅ Sample 29/500 captured (Left hand)
# ✅ Sample 30/500 captured (Left hand)
# ✅ Sample 31/500 captured (Left hand)
# ✅ Sample 32/500 captured (Left hand)
# ✅ Sample 33/500 captured (Left hand)
# ✅ Sample 34/500 captured (Left hand)
# ✅ Sample 35/500 captured (Left hand)
# ✅ Sample 36/500 captured (Left hand)
# ✅ Sample 37/500 captured (Left hand)
# ✅ Sample 38/500 captured (Left hand)
# ✅ Sample 39/500 captured (Left hand)
# ✅ Sample 40/500 captured (Left hand)
# ✅ Sample 41/500 captured (Left hand)
# ✅ Sample 42/500 captured (Left hand)
# ✅ Sample 43/500 captured (Left hand)
# ✅ Sample 44/500 captured (Left hand)
# ✅ Sample 45/500 captured (Left hand)
# ✅ Sample 46/500 captured (Left hand)
# ✅ Sample 47/500 captured (Left hand)
# ✅ Sample 48/500 captured (Left hand)
# ✅ Sample 49/500 captured (Left hand)
# ✅ Sample 50/500 captured (Left hand)
# ✅ Sample 51/500 captured (Left hand)
# ✅ Sample 52/500 captured (Left hand)
# ✅ Sample 53/500 captured (Left hand)
# ✅ Sample 54/500 captured (Left hand)
# ✅ Sample 55/500 captured (Left hand)
# ✅ Sample 56/500 captured (Left hand)
# ✅ Sample 57/500 captured (Left hand)
# ✅ Sample 58/500 captured (Left hand)
# ✅ Sample 59/500 captured (Left hand)
# ✅ Sample 60/500 captured (Left hand)
# ✅ Sample 61/500 captured (Left hand)
# ✅ Sample 62/500 captured (Left hand)
# ✅ Sample 63/500 captured (Left hand)
# ✅ Sample 64/500 captured (Left hand)
# ✅ Sample 65/500 captured (Left hand)
# ✅ Sample 66/500 captured (Left hand)
# ✅ Sample 67/500 captured (Left hand)
# ✅ Sample 68/500 captured (Left hand)
# ✅ Sample 69/500 captured (Left hand)
# ✅ Sample 70/500 captured (Left hand)
# ✅ Sample 71/500 captured (Left hand)
# ✅ Sample 72/500 captured (Left hand)
# ✅ Sample 73/500 captured (Left hand)
# ✅ Sample 74/500 captured (Left hand)
# ✅ Sample 75/500 captured (Left hand)
# ✅ Sample 76/500 captured (Left hand)
# ✅ Sample 77/500 captured (Left hand)
# ✅ Sample 78/500 captured (Left hand)
# ✅ Sample 79/500 captured (Left hand)
# ✅ Sample 80/500 captured (Left hand)
# ✅ Sample 81/500 captured (Left hand)
# ✅ Sample 82/500 captured (Left hand)
# ✅ Sample 83/500 captured (Left hand)
# ✅ Sample 84/500 captured (Left hand)
# ✅ Sample 85/500 captured (Left hand)
# ✅ Sample 86/500 captured (Left hand)
# ✅ Sample 87/500 captured (Left hand)
# ✅ Sample 88/500 captured (Left hand)
# ✅ Sample 89/500 captured (Left hand)
# ✅ Sample 90/500 captured (Left hand)
# ✅ Sample 91/500 captured (Left hand)
# ✅ Sample 92/500 captured (Left hand)
# ✅ Sample 93/500 captured (Left hand)
# ✅ Sample 94/500 captured (Left hand)
# ✅ Sample 95/500 captured (Left hand)
# ✅ Sample 96/500 captured (Left hand)
# ✅ Sample 97/500 captured (Left hand)
# ✅ Sample 98/500 captured (Left hand)
# ✅ Sample 99/500 captured (Left hand)
# ✅ Sample 100/500 captured (Left hand)
# ✅ Sample 101/500 captured (Left hand)
# ✅ Sample 102/500 captured (Left hand)
# ✅ Sample 103/500 captured (Left hand)
# ✅ Sample 104/500 captured (Left hand)
# ✅ Sample 105/500 captured (Left hand)
# ✅ Sample 106/500 captured (Left hand)
# ✅ Sample 107/500 captured (Left hand)
# ✅ Sample 108/500 captured (Left hand)
# ✅ Sample 109/500 captured (Left hand)
# ✅ Sample 110/500 captured (Left hand)
# ✅ Sample 111/500 captured (Left hand)
# ✅ Sample 112/500 captured (Left hand)
# ✅ Sample 113/500 captured (Left hand)
# ✅ Sample 114/500 captured (Left hand)
# ✅ Sample 115/500 captured (Left hand)
# ✅ Sample 116/500 captured (Left hand)
# ✅ Sample 117/500 captured (Left hand)
# ✅ Sample 118/500 captured (Left hand)
# ✅ Sample 119/500 captured (Left hand)
# ✅ Sample 120/500 captured (Left hand)
# ✅ Sample 121/500 captured (Left hand)
# ✅ Sample 122/500 captured (Left hand)
# ✅ Sample 123/500 captured (Left hand)
# ✅ Sample 124/500 captured (Left hand)
# ✅ Sample 125/500 captured (Left hand)
# ✅ Sample 126/500 captured (Left hand)
# ✅ Sample 127/500 captured (Left hand)
# ✅ Sample 128/500 captured (Left hand)
# ✅ Sample 129/500 captured (Left hand)
# ✅ Sample 130/500 captured (Left hand)
# ✅ Sample 131/500 captured (Left hand)
# ✅ Sample 132/500 captured (Left hand)
# ✅ Sample 133/500 captured (Left hand)
# ✅ Sample 134/500 captured (Left hand)
# ✅ Sample 135/500 captured (Left hand)
# ✅ Sample 136/500 captured (Left hand)
# ✅ Sample 137/500 captured (Left hand)
# ✅ Sample 138/500 captured (Left hand)
# ✅ Sample 139/500 captured (Left hand)
# ✅ Sample 140/500 captured (Left hand)
# ✅ Sample 141/500 captured (Left hand)
# ✅ Sample 142/500 captured (Left hand)
# ✅ Sample 143/500 captured (Left hand)
# ✅ Sample 144/500 captured (Left hand)
# ✅ Sample 145/500 captured (Left hand)
# ✅ Sample 146/500 captured (Left hand)
# ✅ Sample 147/500 captured (Left hand)
# ✅ Sample 148/500 captured (Left hand)
# ✅ Sample 149/500 captured (Left hand)
# ✅ Sample 150/500 captured (Left hand)
# ✅ Sample 151/500 captured (Left hand)
# ✅ Sample 152/500 captured (Left hand)
# ✅ Sample 153/500 captured (Left hand)
# ✅ Sample 154/500 captured (Left hand)
# ✅ Sample 155/500 captured (Left hand)
# ✅ Sample 156/500 captured (Left hand)
# ✅ Sample 157/500 captured (Left hand)
# ✅ Sample 158/500 captured (Left hand)
# ✅ Sample 159/500 captured (Left hand)
# ✅ Sample 160/500 captured (Left hand)
# ✅ Sample 161/500 captured (Left hand)
# ✅ Sample 162/500 captured (Left hand)
# ✅ Sample 163/500 captured (Left hand)
# ✅ Sample 164/500 captured (Left hand)
# ✅ Sample 165/500 captured (Left hand)
# ✅ Sample 166/500 captured (Left hand)
# ✅ Sample 167/500 captured (Left hand)
# ✅ Sample 168/500 captured (Left hand)
# ✅ Sample 169/500 captured (Left hand)
# ✅ Sample 170/500 captured (Left hand)
# ✅ Sample 171/500 captured (Left hand)
# ✅ Sample 172/500 captured (Left hand)
# ✅ Sample 173/500 captured (Left hand)
# ✅ Sample 174/500 captured (Left hand)
# ✅ Sample 175/500 captured (Left hand)
# ✅ Sample 176/500 captured (Left hand)
# ✅ Sample 177/500 captured (Left hand)
# ✅ Sample 178/500 captured (Left hand)
# ✅ Sample 179/500 captured (Left hand)
# ✅ Sample 180/500 captured (Left hand)
# ✅ Sample 181/500 captured (Left hand)
# ✅ Sample 182/500 captured (Left hand)
# ✅ Sample 183/500 captured (Left hand)
# ✅ Sample 184/500 captured (Left hand)
# ✅ Sample 185/500 captured (Left hand)
# ✅ Sample 186/500 captured (Left hand)
# ✅ Sample 187/500 captured (Left hand)
# ✅ Sample 188/500 captured (Left hand)
# ✅ Sample 189/500 captured (Left hand)
# ✅ Sample 190/500 captured (Left hand)
# ✅ Sample 191/500 captured (Left hand)
# ✅ Sample 192/500 captured (Left hand)
# ✅ Sample 193/500 captured (Left hand)
# ✅ Sample 194/500 captured (Left hand)
# ✅ Sample 195/500 captured (Left hand)
# ✅ Sample 196/500 captured (Left hand)
# ✅ Sample 197/500 captured (Left hand)
# ✅ Sample 198/500 captured (Left hand)
# ✅ Sample 199/500 captured (Left hand)
# ✅ Sample 200/500 captured (Left hand)
# ✅ Sample 201/500 captured (Left hand)
# ✅ Sample 202/500 captured (Left hand)
# ✅ Sample 203/500 captured (Left hand)
# ✅ Sample 204/500 captured (Left hand)
# ✅ Sample 205/500 captured (Left hand)
# ✅ Sample 206/500 captured (Left hand)
# ✅ Sample 207/500 captured (Left hand)
# ✅ Sample 208/500 captured (Left hand)
# ✅ Sample 209/500 captured (Left hand)
# ✅ Sample 210/500 captured (Left hand)
# ✅ Sample 211/500 captured (Left hand)
# ✅ Sample 212/500 captured (Left hand)
# ✅ Sample 213/500 captured (Left hand)
# ✅ Sample 214/500 captured (Left hand)
# ✅ Sample 215/500 captured (Left hand)
# ✅ Sample 216/500 captured (Left hand)
# ✅ Sample 217/500 captured (Left hand)
# ✅ Sample 218/500 captured (Left hand)
# ✅ Sample 219/500 captured (Left hand)
# ✅ Sample 220/500 captured (Left hand)
# ✅ Sample 221/500 captured (Left hand)
# ✅ Sample 222/500 captured (Left hand)
# ✅ Sample 223/500 captured (Left hand)
# ✅ Sample 224/500 captured (Left hand)
# ✅ Sample 225/500 captured (Left hand)
# ✅ Sample 226/500 captured (Left hand)
# ✅ Sample 227/500 captured (Left hand)
# ✅ Sample 228/500 captured (Left hand)
# ✅ Sample 229/500 captured (Left hand)
# ✅ Sample 230/500 captured (Left hand)
# ✅ Sample 231/500 captured (Left hand)
# ✅ Sample 232/500 captured (Left hand)
# ✅ Sample 233/500 captured (Left hand)
# ✅ Sample 234/500 captured (Left hand)
# ✅ Sample 235/500 captured (Left hand)
# ✅ Sample 236/500 captured (Left hand)
# ✅ Sample 237/500 captured (Left hand)
# ✅ Sample 238/500 captured (Left hand)
# ✅ Sample 239/500 captured (Left hand)
# ✅ Sample 240/500 captured (Left hand)
# ✅ Sample 241/500 captured (Left hand)
# ✅ Sample 242/500 captured (Left hand)
# ✅ Sample 243/500 captured (Left hand)
# ✅ Sample 244/500 captured (Left hand)
# ✅ Sample 245/500 captured (Left hand)
# ✅ Sample 246/500 captured (Left hand)
# ✅ Sample 247/500 captured (Left hand)
# ✅ Sample 248/500 captured (Left hand)
# ✅ Sample 249/500 captured (Left hand)
# ✅ Sample 250/500 captured (Left hand)
# ✅ Sample 251/500 captured (Left hand)
# ✅ Sample 252/500 captured (Left hand)
# ✅ Sample 253/500 captured (Left hand)
# ✅ Sample 254/500 captured (Left hand)
# ✅ Sample 255/500 captured (Left hand)
# ✅ Sample 256/500 captured (Left hand)
# ✅ Sample 257/500 captured (Left hand)
# ✅ Sample 258/500 captured (Left hand)
# ✅ Sample 259/500 captured (Left hand)
# ✅ Sample 260/500 captured (Left hand)
# ✅ Sample 261/500 captured (Left hand)
# ✅ Sample 262/500 captured (Left hand)
# ✅ Sample 263/500 captured (Left hand)
# ✅ Sample 264/500 captured (Left hand)
# ✅ Sample 265/500 captured (Left hand)
# ✅ Sample 266/500 captured (Left hand)
# ✅ Sample 267/500 captured (Left hand)
# ✅ Sample 268/500 captured (Left hand)
# ✅ Sample 269/500 captured (Left hand)
# ✅ Sample 270/500 captured (Left hand)
# ✅ Sample 271/500 captured (Left hand)
# ✅ Sample 272/500 captured (Left hand)
# ✅ Sample 273/500 captured (Left hand)
# ✅ Sample 274/500 captured (Left hand)
# ✅ Sample 275/500 captured (Left hand)
# ✅ Sample 276/500 captured (Left hand)
# ✅ Sample 277/500 captured (Left hand)
# ✅ Sample 278/500 captured (Left hand)
# ✅ Sample 279/500 captured (Left hand)
# ✅ Sample 280/500 captured (Left hand)
# ✅ Sample 281/500 captured (Left hand)
# ✅ Sample 282/500 captured (Left hand)
# ✅ Sample 283/500 captured (Left hand)
# ✅ Sample 284/500 captured (Left hand)
# ✅ Sample 285/500 captured (Left hand)
# ✅ Sample 286/500 captured (Left hand)
# ✅ Sample 287/500 captured (Left hand)
# ✅ Sample 288/500 captured (Left hand)
# ✅ Sample 289/500 captured (Left hand)
# ✅ Sample 290/500 captured (Left hand)
# ✅ Sample 291/500 captured (Left hand)
# ✅ Sample 292/500 captured (Left hand)
# ✅ Sample 293/500 captured (Left hand)
# ✅ Sample 294/500 captured (Left hand)
# ✅ Sample 295/500 captured (Left hand)
# ✅ Sample 296/500 captured (Left hand)
# ✅ Sample 297/500 captured (Left hand)
# ✅ Sample 298/500 captured (Left hand)
# ✅ Sample 299/500 captured (Left hand)
# ✅ Sample 300/500 captured (Left hand)
# ✅ Sample 301/500 captured (Left hand)
# ✅ Sample 302/500 captured (Left hand)
# ✅ Sample 303/500 captured (Left hand)
# ✅ Sample 304/500 captured (Left hand)
# ✅ Sample 305/500 captured (Left hand)
# ✅ Sample 306/500 captured (Left hand)
# ✅ Sample 307/500 captured (Left hand)
# ✅ Sample 308/500 captured (Left hand)
# ✅ Sample 309/500 captured (Left hand)
# ✅ Sample 310/500 captured (Left hand)
# ✅ Sample 311/500 captured (Left hand)
# ✅ Sample 312/500 captured (Left hand)
# ✅ Sample 313/500 captured (Left hand)
# ✅ Sample 314/500 captured (Left hand)
# ✅ Sample 315/500 captured (Left hand)
# ✅ Sample 316/500 captured (Left hand)
# ✅ Sample 317/500 captured (Left hand)
# ✅ Sample 318/500 captured (Left hand)
# ✅ Sample 319/500 captured (Left hand)
# ✅ Sample 320/500 captured (Left hand)
# ✅ Sample 321/500 captured (Left hand)
# ✅ Sample 322/500 captured (Left hand)
# ✅ Sample 323/500 captured (Left hand)
# ✅ Sample 324/500 captured (Left hand)
# ✅ Sample 325/500 captured (Left hand)
# ✅ Sample 326/500 captured (Left hand)
# ✅ Sample 327/500 captured (Left hand)
# ✅ Sample 328/500 captured (Left hand)
# ✅ Sample 329/500 captured (Left hand)
# ✅ Sample 330/500 captured (Left hand)
# ✅ Sample 331/500 captured (Left hand)
# ✅ Sample 332/500 captured (Left hand)
# ✅ Sample 333/500 captured (Left hand)
# ✅ Sample 334/500 captured (Left hand)
# ✅ Sample 335/500 captured (Left hand)
# ✅ Sample 336/500 captured (Left hand)
# ✅ Sample 337/500 captured (Left hand)
# ✅ Sample 338/500 captured (Left hand)
# ✅ Sample 339/500 captured (Left hand)
# ✅ Sample 340/500 captured (Left hand)
# ✅ Sample 341/500 captured (Left hand)
# ✅ Sample 342/500 captured (Left hand)
# ✅ Sample 343/500 captured (Left hand)
# ✅ Sample 344/500 captured (Left hand)
# ✅ Sample 345/500 captured (Left hand)
# ✅ Sample 346/500 captured (Left hand)
# ✅ Sample 347/500 captured (Left hand)
# ✅ Sample 348/500 captured (Left hand)
# ✅ Sample 349/500 captured (Left hand)
# ✅ Sample 350/500 captured (Left hand)
# ✅ Sample 351/500 captured (Left hand)
# ✅ Sample 352/500 captured (Left hand)
# ✅ Sample 353/500 captured (Left hand)
# ✅ Sample 354/500 captured (Left hand)
# ✅ Sample 355/500 captured (Left hand)
# ✅ Sample 356/500 captured (Left hand)
# ✅ Sample 357/500 captured (Left hand)
# ✅ Sample 358/500 captured (Left hand)
# ✅ Sample 359/500 captured (Left hand)
# ✅ Sample 360/500 captured (Left hand)
# ✅ Sample 361/500 captured (Left hand)
# ✅ Sample 362/500 captured (Left hand)
# ✅ Sample 363/500 captured (Left hand)
# ✅ Sample 364/500 captured (Left hand)
# ✅ Sample 365/500 captured (Left hand)
# ✅ Sample 366/500 captured (Left hand)
# ✅ Sample 367/500 captured (Left hand)
# ✅ Sample 368/500 captured (Left hand)
# ✅ Sample 369/500 captured (Left hand)
# ✅ Sample 370/500 captured (Left hand)
# ✅ Sample 371/500 captured (Left hand)
# ✅ Sample 372/500 captured (Left hand)
# ✅ Sample 373/500 captured (Left hand)
# ✅ Sample 374/500 captured (Left hand)
# ✅ Sample 375/500 captured (Left hand)
# ✅ Sample 376/500 captured (Left hand)
# ✅ Sample 377/500 captured (Left hand)
# ✅ Sample 378/500 captured (Left hand)
# ✅ Sample 379/500 captured (Left hand)
# ✅ Sample 380/500 captured (Left hand)
# ✅ Sample 381/500 captured (Left hand)
# ✅ Sample 382/500 captured (Left hand)
# ✅ Sample 383/500 captured (Left hand)
# ✅ Sample 384/500 captured (Left hand)
# ✅ Sample 385/500 captured (Left hand)
# ✅ Sample 386/500 captured (Left hand)
# ✅ Sample 387/500 captured (Left hand)
# ✅ Sample 388/500 captured (Left hand)
# ✅ Sample 389/500 captured (Left hand)
# ✅ Sample 390/500 captured (Left hand)
# ✅ Sample 391/500 captured (Left hand)
# ✅ Sample 392/500 captured (Left hand)
# ✅ Sample 393/500 captured (Left hand)
# ✅ Sample 394/500 captured (Left hand)
# ✅ Sample 395/500 captured (Left hand)
# ✅ Sample 396/500 captured (Left hand)
# ✅ Sample 397/500 captured (Left hand)
# ✅ Sample 398/500 captured (Left hand)
# ✅ Sample 399/500 captured (Left hand)
# ✅ Sample 400/500 captured (Left hand)
# ✅ Sample 401/500 captured (Left hand)
# ✅ Sample 402/500 captured (Left hand)
# ✅ Sample 403/500 captured (Left hand)
# ✅ Sample 404/500 captured (Left hand)
# ✅ Sample 405/500 captured (Left hand)
# ✅ Sample 406/500 captured (Left hand)
# ✅ Sample 407/500 captured (Left hand)
# ✅ Sample 408/500 captured (Left hand)
# ✅ Sample 409/500 captured (Left hand)
# ✅ Sample 410/500 captured (Left hand)
# ✅ Sample 411/500 captured (Left hand)
# ✅ Sample 412/500 captured (Left hand)
# ✅ Sample 413/500 captured (Left hand)
# ✅ Sample 414/500 captured (Left hand)
# ✅ Sample 415/500 captured (Left hand)
# ✅ Sample 416/500 captured (Left hand)
# ✅ Sample 417/500 captured (Left hand)
# ✅ Sample 418/500 captured (Left hand)
# ✅ Sample 419/500 captured (Left hand)
# ✅ Sample 420/500 captured (Left hand)
# ✅ Sample 421/500 captured (Left hand)
# ✅ Sample 422/500 captured (Left hand)
# ✅ Sample 423/500 captured (Left hand)
# ✅ Sample 424/500 captured (Left hand)
# ✅ Sample 425/500 captured (Left hand)
# ✅ Sample 426/500 captured (Left hand)
# ✅ Sample 427/500 captured (Left hand)
# ✅ Sample 428/500 captured (Left hand)
# ✅ Sample 429/500 captured (Left hand)
# ✅ Sample 430/500 captured (Left hand)
# ✅ Sample 431/500 captured (Left hand)
# ✅ Sample 432/500 captured (Left hand)
# ✅ Sample 433/500 captured (Left hand)
# ✅ Sample 434/500 captured (Left hand)
# ✅ Sample 435/500 captured (Left hand)
# ✅ Sample 436/500 captured (Left hand)
# ✅ Sample 437/500 captured (Left hand)
# ✅ Sample 438/500 captured (Left hand)
# ✅ Sample 439/500 captured (Left hand)
# ✅ Sample 440/500 captured (Left hand)
# ✅ Sample 441/500 captured (Left hand)
# ✅ Sample 442/500 captured (Left hand)
# ✅ Sample 443/500 captured (Left hand)
# ✅ Sample 444/500 captured (Left hand)
# ✅ Sample 445/500 captured (Left hand)
# ✅ Sample 446/500 captured (Left hand)
# ✅ Sample 447/500 captured (Left hand)
# ✅ Sample 448/500 captured (Left hand)
# ✅ Sample 449/500 captured (Left hand)
# ✅ Sample 450/500 captured (Left hand)
# ✅ Sample 451/500 captured (Left hand)
# ✅ Sample 452/500 captured (Left hand)
# ✅ Sample 453/500 captured (Left hand)
# ✅ Sample 454/500 captured (Left hand)
# ✅ Sample 455/500 captured (Left hand)
# ✅ Sample 456/500 captured (Left hand)
# ✅ Sample 457/500 captured (Left hand)
# ✅ Sample 458/500 captured (Left hand)
# ✅ Sample 459/500 captured (Left hand)
# ✅ Sample 460/500 captured (Left hand)
# ✅ Sample 461/500 captured (Left hand)
# ✅ Sample 462/500 captured (Left hand)
# ✅ Sample 463/500 captured (Left hand)
# ✅ Sample 464/500 captured (Left hand)
# ✅ Sample 465/500 captured (Left hand)
# ✅ Sample 466/500 captured (Left hand)
# ✅ Sample 467/500 captured (Left hand)
# ✅ Sample 468/500 captured (Left hand)
# ✅ Sample 469/500 captured (Left hand)
# ✅ Sample 470/500 captured (Left hand)
# ✅ Sample 471/500 captured (Left hand)
# ✅ Sample 472/500 captured (Left hand)
# ✅ Sample 473/500 captured (Left hand)
# ✅ Sample 474/500 captured (Left hand)
# ✅ Sample 475/500 captured (Left hand)
# ✅ Sample 476/500 captured (Left hand)
# ✅ Sample 477/500 captured (Left hand)
# ✅ Sample 478/500 captured (Left hand)
# ✅ Sample 479/500 captured (Left hand)
# ✅ Sample 480/500 captured (Left hand)
# ✅ Sample 481/500 captured (Left hand)
# ✅ Sample 482/500 captured (Left hand)
# ✅ Sample 483/500 captured (Left hand)
# ✅ Sample 484/500 captured (Left hand)
# ✅ Sample 485/500 captured (Left hand)
# ✅ Sample 486/500 captured (Left hand)
# ✅ Sample 487/500 captured (Left hand)
# ✅ Sample 488/500 captured (Left hand)
# ✅ Sample 489/500 captured (Left hand)
# ✅ Sample 490/500 captured (Left hand)
# ✅ Sample 491/500 captured (Left hand)
# ✅ Sample 492/500 captured (Left hand)
# ✅ Sample 493/500 captured (Left hand)
# ✅ Sample 494/500 captured (Left hand)
# ✅ Sample 495/500 captured (Left hand)
# ✅ Sample 496/500 captured (Left hand)
# ✅ Sample 497/500 captured (Left hand)
# ✅ Sample 498/500 captured (Left hand)
# ✅ Sample 499/500 captured (Left hand)
# ✅ Sample 500/500 captured (Left hand)
#
# CSV saved: ../data/raw/don.csv (1000 total rows)
